# %%
import subprocess
import sys
sys.path.insert(0,'..')
from pathlib import Path
import os
import random

import torch
import torch.nn as nn
from torch.nn.functional import one_hot
from torch import Tensor
from typing import Union

import matplotlib.pylab as plt

import time
import numpy as np
import torch as th
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler

# from focal_loss import FocalLoss
from utils import _axat, _atxa, _mvmt
import seaborn as sns


def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package],
                         stdout=subprocess.DEVNULL,
                         stderr=subprocess.DEVNULL
                         )
required_packages = [
    "geoopt",
    "pyriemann",
]
for package in required_packages:
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"{package} is not installed. Installing...")
        install(package)

import geoopt
from pyriemann.utils.covariance import covariances, normalize


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.manifold import TSNE
import pandas as pd


use_cuda = th.cuda.is_available()
device = th.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# geoopt is not installed. Installing...
# pyriemann is not installed. Installing...
# cpu

# %%
class FocalLoss(nn.Module):
    """Computes the focal loss between input and target
    as described here https://arxiv.org/abs/1708.02002v2

    Args:
        gamma (float):  The focal loss focusing parameter.
        weights (Union[None, Tensor]): Rescaling weight given to each class.
        If given, has to be a Tensor of size C. optional.
        reduction (str): Specifies the reduction to apply to the output.
        it should be one of the following 'none', 'mean', or 'sum'.
        default 'mean'.
        ignore_index (int): Specifies a target value that is ignored and
        does not contribute to the input gradient. optional.
        eps (float): smoothing to prevent log from returning inf.
    """
    def __init__(
            self,
            gamma,
            weights: Union[None, Tensor] = None,
            reduction: str = 'mean',
            ignore_index=-100,
            eps=1e-16
            ) -> None:
        super().__init__()
        if reduction not in ['mean', 'none', 'sum']:
            raise NotImplementedError(
                'Reduction {} not implemented.'.format(reduction)
                )
        assert weights is None or isinstance(weights, Tensor), \
            'weights should be of type Tensor or None, but {} given'.format(
                type(weights))
        self.reduction = reduction
        self.gamma = gamma
        self.ignore_index = ignore_index
        self.eps = eps
        self.weights = weights

    def _get_weights(self, target: Tensor) -> Tensor:
        if self.weights is None:
            return torch.ones(target.shape[0])
        weights = target * self.weights
        return weights.sum(dim=-1)

    def _process_target(
            self, target: Tensor, num_classes: int, mask: Tensor
            ) -> Tensor:
        
        #convert all ignore_index elements to zero to avoid error in one_hot
        #note - the choice of value 0 is arbitrary, but it should not matter as these elements will be ignored in the loss calculation
        target = target * (target!=self.ignore_index) 
        target = target.view(-1)
        return one_hot(target, num_classes=num_classes)

    def _process_preds(self, x: Tensor) -> Tensor:
        if x.dim() == 1:
            x = torch.vstack([1 - x, x])
            x = x.permute(1, 0)
            return x
        return x.view(-1, x.shape[-1])

    def _calc_pt(
            self, target: Tensor, x: Tensor, mask: Tensor
            ) -> Tensor:
        p = target * x
        p = p.sum(dim=-1)
        p = p * ~mask
        return p

    def forward(self, x: Tensor, target: Tensor) -> Tensor:
        assert torch.all((x >= 0.0) & (x <= 1.0)), ValueError(
            'The predictions values should be between 0 and 1, \
                make sure to pass the values to sigmoid for binary \
                classification or softmax for multi-class classification'
        )
        mask = target == self.ignore_index
        mask = mask.view(-1)
        x = self._process_preds(x)
        num_classes = x.shape[-1]
        target = self._process_target(target, num_classes, mask)
        weights = self._get_weights(target).to(x.device)
        pt = self._calc_pt(target, x, mask)
        focal = 1 - pt
        nll = -torch.log(self.eps + pt)
        nll = nll.masked_fill(mask, 0)
        loss = weights * (focal ** self.gamma) * nll
        return self._reduce(loss, mask, weights)

    def _reduce(self, x: Tensor, mask: Tensor, weights: Tensor) -> Tensor:
        if self.reduction == 'mean':
            return x.sum() / (~mask * weights).sum()
        elif self.reduction == 'sum':
            return x.sum()
        else:
            return x

# %%
class BusemanSimilarityClassifier(nn.Module):
    def busemann_spd(self, logM):
        """
        Compute the Busemann similarity for Symmetric Positive Definite (SPD) matrices.
        
        :param logM: Logarithm of SPD matrices, shape (b, n, n)
        :return: Similarity scores, shape (b, n_proto)
        """
        return logM.reshape(logM.shape[0], -1) @ self.proto.reshape(self.proto.shape[0], -1).T
    def __init__(self,dim1,n_proto,n_classes,optim_proto=True):
        super().__init__()
        self.n_proto = n_proto
        self.n_classes = n_classes
        self.dim1 = dim1
        
        self.manifold = geoopt.Stiefel()

        # Random projection directions, shape (d-1, num_projections)
        theta = np.random.normal(size=(self.n_proto, self.dim1))
        theta = th.nn.functional.normalize(th.from_numpy(theta), p=2, dim=-1).type(th.float64).to(device)
        #self.D = theta[:,None] * th.eye(theta.shape[-1],dtype=th.float64, device=device)
        self.register_parameter("theta_proto", geoopt.ManifoldParameter(theta, geoopt.Sphere()))
        #self.theta_proto=theta

        ## Random orthogonal matrices
        Z = th.randn((self.n_proto, self.dim1, self.dim1), dtype=th.float64, device=device)
        self.Q = th.svd(Z)[0]
        self.manifold.assert_check_point_on_manifold(self.Q)
        self.register_parameter("Q_proto", geoopt.ManifoldParameter(self.Q, self.manifold))
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        # linear layer
        self.linear = nn.Linear(self.n_proto, self.n_classes).double()

    def forward(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        y = self.linear(self.busemann_spd(x))#.view(sim_embedding.shape[0], -1))
        return y
    
    def embed(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        return self.busemann_spd(x)

# %% [markdown]
# # Model definition

# %%
class LogEucRResNet(nn.Module):
    def __init__(self, inputdim=10, dim1=7, n_proto=12, classes=11, embed_only=False):
        super().__init__()
        self.inputdim = inputdim
        self.dim1 = dim1
        self.n_proto = n_proto
        self.classes = classes
        self.embed_only = embed_only

        self.manifold_Stiefel = geoopt.Stiefel()
        self.manifold_SPD = geoopt.SymmetricPositiveDefinite("LEM")
        
        # init first bimap
        bm1 = th.randn((1, self.inputdim, self.dim1), dtype=th.float64)
        bm1 = th.svd(bm1)[0]
        self.register_parameter("bimap1", geoopt.ManifoldParameter(bm1, self.manifold_Stiefel))
        
        P = th.randn((1, self.dim1, self.dim1), dtype=th.float64)
        P = th.svd(P)[0]

        self.register_parameter("P1", geoopt.ManifoldParameter(P, self.manifold_Stiefel))

        self.classiflayer=BusemanSimilarityClassifier(self.dim1,self.n_proto, classes)
        self.fc_layer = nn.Linear(self.dim1 * self.dim1, self.classes).double()
        self.softmax =  nn.Softmax(dim=-1)

        self.spectrum_map = nn.Sequential(
            nn.Conv1d(1, 10, 5, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(10).double(),
            nn.Conv1d(10, 5, 3, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(5).double(),
            nn.Conv1d(5, 1, 3, padding="same").double(),
        )
        
    def forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs) # spectral map
        v1 = _mvmt(self.P1, f_eigs, self.P1)            
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)     
        x = log_x + v1
        if self.embed_only:
            return x.reshape(x.shape[0],-1)
        return self.softmax(self.fc_layer(x.reshape(x.shape[0],-1)))
        #return self.softmax(self.classiflayer(x)) # Buseman Similarity Classifier when single modality is used
            
class LogEucRResNet_Combo(nn.Module):
    def __init__(self, inputdim_temp=36, dim1_temp=24, inputdim_spec=10, dim1_spec=7, n_proto=12, classes=11, buseman_classif=True):
        super().__init__()
        self.classes = classes
        self.buseman_classif = buseman_classif
        self.model_temp = LogEucRResNet(inputdim_temp, dim1_temp, n_proto, embed_only=True)
        self.model_spectral = LogEucRResNet(inputdim_spec, dim1_spec, n_proto, embed_only=True)
        
        self.classiflayer = BusemanSimilarityClassifier(dim1_temp+1,n_proto,classes)
        self.fc_layer = nn.Linear(dim1_temp*dim1_temp+dim1_spec*dim1_spec,classes).double()        
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, x1, x2):
        out_1 = self.model_temp(x1) # probabilities
        out_2 = self.model_spectral(x2) # probabilities
        x = th.concat((out_1, out_2), dim=1)
        #print(x.shape)
        if self.buseman_classif:
            return self.softmax(self.classiflayer(x))
        else:
            return self.softmax(self.fc_layer(x))

# %% [markdown]
# Create model and load it from file

# %%
model = LogEucRResNet_Combo(buseman_classif=True).to(device)
model.eval()
# get number of trainable parameters
trainable_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(trainable_total_params)
# Out:
# 31965

# %% [markdown]
# ## visualize dataset embedding

# %% [markdown]
# load dataset

# %%
class TS_COV(Dataset):
    def __init__(self, root_dir, np_file, estimator='scm'):
        self.root_dir = root_dir
        self.np_file = np_file
        self.estimator = estimator
        self.x, self.y, self.class_names = self.load_data()
        #self.cov = normalize(self.calculate_covariances(),'corr')
        self.x1 = self.calculate_covariances_36()
        self.x2 = self.calculate_covariances_10()
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x1, x2= self.x1[idx], self.x2[idx]
        y_sample = self.y[idx]
        class_name = self.class_names[y_sample]
        x1 = th.from_numpy(np.asarray([x1])).double()
        x2 = th.from_numpy(np.asarray([x2])).double()
        x1,x2 = x1.reshape(1, 36, 36), x2.reshape(1, 10, 10)
        y = th.from_numpy(np.array(y_sample)).long()
        return x1,x2, y#, class_name

    def load_data(self):
        file_path = os.path.join(self.root_dir, self.np_file)
        data = np.load(file_path, allow_pickle= True)
        x = data['series']
        y = data['labels']
        class_names = data['class_names']
        return x, y, class_names

    def calculate_covariances_10(self):
        x_transposed = np.transpose(self.x, (0, 2, 1))
        cov = covariances(x_transposed, estimator=self.estimator)
        return cov
    def calculate_covariances_36(self):
        cov = covariances(self.x, estimator=self.estimator)
        return cov

# %%
# %matplotlib inline

root_dir = r"/kaggle/input/normalized-data/"
npz_file = "98_p_norm_data.npz"
batch_size = 64  # batch size

def calculate_class_weights(labels):
    class_sample_count = np.array([len(np.where(labels == t)[0]) for t in np.unique(labels)])
    weight = 1 - class_sample_count / len(labels)
    return th.from_numpy(weight).double()

def create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size):
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(train_indices))
    val_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(val_indices))
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(test_indices), shuffle=False)
    return train_loader, val_loader, test_loader

def plot_class_distribution(train_loader, val_loader, test_loader, n_classes):
    train_counts = np.zeros(n_classes)
    for _, _, labels in train_loader:
        for l in labels:
            train_counts[l] += 1

    val_counts = np.zeros(n_classes)
    for _, _, labels in val_loader:
        for l in labels:
            val_counts[l] += 1

    test_counts = np.zeros(n_classes)
    for _, _, labels in test_loader:
        for l in labels:
            test_counts[l] += 1

    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes), train_counts, alpha=0.5, label='Train')
    plt.bar(np.arange(n_classes), val_counts, alpha=0.5, label='Validation')
    plt.bar(np.arange(n_classes), test_counts, alpha=0.5, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    plt.title('Class Distribution in Train, Validation, and Test Sets')
    plt.legend(loc='best')
    plt.show()

# Initialize dataset
dataset = TS_COV(root_dir=root_dir, np_file=npz_file, estimator='scm')

# Split data into train, validation, and test sets
train_indices, test_indices = train_test_split(list(range(len(dataset))), test_size=0.2, stratify=dataset.y, random_state=42)
train_indices, val_indices = train_test_split(train_indices, test_size=0.2, stratify=dataset.y[train_indices], random_state=42)

# Calculate class weights
weights = calculate_class_weights(dataset.y)
weights = weights.to(device)


# Create data loaders
train_loader, val_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size)

# Plot class distribution
plot_class_distribution(train_loader, val_loader, test_loader, n_classes=11)

# %%
# access one matri
for x1,x2, y in train_loader:
    print(x1.shape)
    print(x2.shape)
    print(y.shape)
    break

# %%
lr=1e-2
epochs=200
gamma_value=0.95
step_size=30
#setup loss and optimizer
#loss_fn = nn.CrossEntropyLoss()
loss_fn = FocalLoss(gamma=1,weights=weights)
#opti = MixOptimizer(model.parameters(),lr=lr)
opti = geoopt.optim.RiemannianAdam(model.parameters(), lr=lr)
scheduler = lr_scheduler.ExponentialLR(opti, gamma=gamma_value)
#scheduler = lr_scheduler.StepLR(opti, step_size, gamma_value)

# %%
def train_model(model, train_loader, val_loader, loss_fn, optimizer, scheduler, epochs, combo=False, temp=False):
    t1, t2, t3, t4, t5 = [], [], [], [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    for epoch in range(epochs):
        start_time = time.time()  # Start time of the epoch
        model.train()

        # Training phase
        loss_train, acc_train = [], []
        for x1, x2, y in train_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)
            y = y.to(device).long()
            optimizer.zero_grad()
            
            # Conditional forward pass
            if combo:
                out = model(x1, x2)
            elif temp:
                out = model(x1)
            else:
                out = model(x2)
                
            l = loss_fn(out, y)
            
            acc, loss = (out.argmax(1) == y).cpu().numpy().sum() / out.shape[0], l.cpu().data.numpy()
            loss_train.append(loss)
            acc_train.append(acc)
            l.backward()
            optimizer.step()
        scheduler.step()

        acc_train = np.asarray(acc_train).mean()
        loss_train = np.asarray(loss_train).mean()
        t1.append(loss_train)
        t2.append(100 * acc_train)

        # Validation phase
        loss_val, acc_val_list = [], []
        y_true, y_pred = [], []
        model.eval()
        for x1, x2, y in val_loader:
            x1 = x1.to(device)
            x2 = x2.to(device)
            y = y.to(device).long()
            with th.no_grad():
                # Conditional forward pass
                if combo:
                    out = model(x1, x2)
                elif temp:
                    out = model(x1)
                else:
                    out = model(x2)
                    
                l = loss_fn(out, y)
                
            loss_val.append(l.cpu().data.numpy())
            predicted_labels = out.argmax(1)
            y_true.extend(list(y.cpu().numpy()))
            y_pred.extend(list(predicted_labels.cpu().numpy()))
            acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
            
            acc_val_list.append(acc)
        acc_val = np.asarray(acc_val_list).mean()
        loss_val = np.asarray(loss_val).mean()    
   
        t3.append(100 * acc_val)
        t4.append(loss_val)
        f1_test = f1_score(y_true, y_pred, average='macro')
        t5.append(100 * f1_test)
        print('Epoch {}/{} - Train loss: {:.4f} - Val loss: {:.4f} - Train acc: {:.2f}% - Val acc: {:.2f}% - Test F1-score: {:.2f}'.format(
            epoch + 1, epochs, loss_train, loss_val, 100 * acc_train, 100 * acc_val, 100 * f1_test))

        elapsed_time = time.time() - start_time
        print('Elapsed time: {:.2f} seconds'.format(elapsed_time))

    return t1, t2, t3, t4, t5

# %%
def evaluate_model(model, data_loader, loss_fn, model_name, figure_name, combo=True, temp=False):
    loss_val, acc_val = [], []
    y_true, y_pred = [], []

    model.eval()
    for x1, x2, y in data_loader:
        x1 = x1.to(device)
        x2 = x2.to(device)
        y = y.to(device).long()
        with th.no_grad():
            # Conditional forward pass
            if combo:
                out = model(x1, x2)
            elif temp:
                out = model(x1)
            else:
                out = model(x2)
                
            l = loss_fn(out, y)
        
        predicted_labels = out.argmax(1)
        y_true.extend(list(y.cpu().numpy()))
        y_pred.extend(list(predicted_labels.cpu().numpy()))
        acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
        loss_val.append(l.cpu().data.numpy())
        acc_val.append(acc)

    acc_val = np.asarray(acc_val).mean()
    loss_val = np.asarray(loss_val).mean()

    print('Validation loss: {:.4f}'.format(loss_val))
    print('Validation accuracy: {:.2f}%'.format(100 * acc_val))

    # Save the model
    th.save(model.state_dict(), f'{model_name}.ckpt')
    print(f'Model saved as {model_name}.ckpt')

    # Print classification report
    print(classification_report(y_true, y_pred, digits=2, target_names=data_loader.dataset.class_names))
    cmatrix = confusion_matrix(y_true, y_pred)
    Ncmatrix = cmatrix.astype('float') / cmatrix.sum(axis=1)[:, np.newaxis]

    group_counts = ['{0:0.0f}'.format(value) for value in cmatrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in Ncmatrix.flatten()]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(11, 11)

    # Plot and save the confusion matrix figure
    plt.figure(figsize=(10, 8))
    sns.heatmap(Ncmatrix, annot=labels, fmt='', cmap='Reds', xticklabels=data_loader.dataset.class_names, yticklabels=data_loader.dataset.class_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label\n Acc={:.2f}%'.format(100 * acc_val))
    plt.title('Normalized Confusion Matrix')
    
    plt.savefig(f'{figure_name}.png')
    plt.show()
    print(f'Figure saved as {figure_name}.png')

    return 100 * acc_val

# %%
t1, t2, t3, t4, t5 = train_model(model, train_loader, val_loader, loss_fn, opti, scheduler, epochs, combo=True, temp=False)
# Out:
# Epoch 1/200 - Train loss: 0.4525 - Val loss: 0.2382 - Train acc: 85.16% - Val acc: 91.70% - Test F1-score: 57.03
# Elapsed time: 34.33 seconds
# Epoch 2/200 - Train loss: 0.2049 - Val loss: 0.1853 - Train acc: 92.85% - Val acc: 93.77% - Test F1-score: 66.03
# Elapsed time: 34.28 seconds
# Epoch 3/200 - Train loss: 0.1703 - Val loss: 0.1702 - Train acc: 93.93% - Val acc: 94.15% - Test F1-score: 69.09
# Elapsed time: 34.73 seconds
# Epoch 4/200 - Train loss: 0.1524 - Val loss: 0.1664 - Train acc: 94.45% - Val acc: 94.39% - Test F1-score: 71.87
# Elapsed time: 34.31 seconds
# Epoch 5/200 - Train loss: 0.1415 - Val loss: 0.1485 - Train acc: 94.95% - Val acc: 95.12% - Test F1-score: 72.28
# Elapsed time: 34.42 seconds
# Epoch 6/200 - Train loss: 0.1326 - Val loss: 0.1437 - Train acc: 95.15% - Val acc: 94.94% - Test F1-score: 73.79
# Elapsed time: 34.95 seconds
# Epoch 7/200 - Train loss: 0.1253 - Val loss: 0.1369 - Train acc: 95.38% - Val acc: 95.34% - Test F1-score: 74.92
# Elapsed time: 34.78 seconds
# Epoch 8/200 - Train loss: 0.1203 - Val loss: 0.1356 - Train acc: 95.57% - Val acc: 95.14% - Test F1-score: 74.44
# Elapsed time: 35.00 seconds
# Epoch 9/200 - Train loss: 0.1165 - Val loss: 0.1416 - Train acc: 95.67% - Val acc: 95.03% - Test F1-score: 74.79
# Elapsed time: 34.43 seconds
# Epoch 10/200 - Train loss: 0.1126 - Val loss: 0.1425 - Train acc: 95.86% - Val acc: 94.96% - Test F1-score: 75.11
# Elapsed time: 34.55 seconds
# Epoch 11/200 - Train loss: 0.1096 - Val loss: 0.1351 - Train acc: 96.00% - Val acc: 95.46% - Test F1-score: 74.51
# Elapsed time: 34.77 seconds
# Epoch 12/200 - Train loss: 0.1071 - Val loss: 0.1341 - Train acc: 96.06% - Val acc: 95.46% - Test F1-score: 75.61
# Elapsed time: 34.60 seconds
# Epoch 13/200 - Train loss: 0.1039 - Val loss: 0.1270 - Train acc: 96.21% - Val acc: 95.77% - Test F1-score: 76.64
# Elapsed time: 34.13 seconds
# Epoch 14/200 - Train loss: 0.1019 - Val loss: 0.1248 - Train acc: 96.18% - Val acc: 95.89% - Test F1-score: 77.50
# Elapsed time: 34.77 seconds
# Epoch 15/200 - Train loss: 0.0994 - Val loss: 0.1224 - Train acc: 96.33% - Val acc: 96.04% - Test F1-score: 76.16
# Elapsed time: 34.34 seconds
# Epoch 16/200 - Train loss: 0.0981 - Val loss: 0.1222 - Train acc: 96.39% - Val acc: 95.95% - Test F1-score: 77.38
# Elapsed time: 34.59 seconds
# Epoch 17/200 - Train loss: 0.0959 - Val loss: 0.1272 - Train acc: 96.39% - Val acc: 95.88% - Test F1-score: 76.18
# Elapsed time: 34.67 seconds
# Epoch 18/200 - Train loss: 0.0932 - Val loss: 0.1287 - Train acc: 96.53% - Val acc: 95.69% - Test F1-score: 77.17
# Elapsed time: 34.77 seconds
# Epoch 19/200 - Train loss: 0.0921 - Val loss: 0.1249 - Train acc: 96.54% - Val acc: 95.81% - Test F1-score: 77.36
# Elapsed time: 34.31 seconds
# Epoch 20/200 - Train loss: 0.0907 - Val loss: 0.1241 - Train acc: 96.58% - Val acc: 95.79% - Test F1-score: 76.36
# Elapsed time: 34.54 seconds
# Epoch 21/200 - Train loss: 0.0900 - Val loss: 0.1199 - Train acc: 96.63% - Val acc: 96.04% - Test F1-score: 77.76
# Elapsed time: 34.21 seconds
# Epoch 22/200 - Train loss: 0.0887 - Val loss: 0.1212 - Train acc: 96.67% - Val acc: 95.98% - Test F1-score: 78.04
# Elapsed time: 34.31 seconds
# Epoch 23/200 - Train loss: 0.0877 - Val loss: 0.1209 - Train acc: 96.73% - Val acc: 95.96% - Test F1-score: 77.35
# Elapsed time: 34.12 seconds
# Epoch 24/200 - Train loss: 0.0863 - Val loss: 0.1208 - Train acc: 96.72% - Val acc: 95.92% - Test F1-score: 78.14
# Elapsed time: 34.51 seconds
# Epoch 25/200 - Train loss: 0.0848 - Val loss: 0.1346 - Train acc: 96.81% - Val acc: 95.47% - Test F1-score: 75.57
# Elapsed time: 34.10 seconds
# Epoch 26/200 - Train loss: 0.0844 - Val loss: 0.1191 - Train acc: 96.81% - Val acc: 95.91% - Test F1-score: 78.10
# Elapsed time: 34.09 seconds
# Epoch 27/200 - Train loss: 0.0829 - Val loss: 0.1213 - Train acc: 96.84% - Val acc: 95.91% - Test F1-score: 77.96
# Elapsed time: 33.92 seconds
# Epoch 28/200 - Train loss: 0.0821 - Val loss: 0.1179 - Train acc: 96.93% - Val acc: 96.10% - Test F1-score: 77.24
# Elapsed time: 33.94 seconds
# Epoch 29/200 - Train loss: 0.0816 - Val loss: 0.1180 - Train acc: 96.96% - Val acc: 96.15% - Test F1-score: 78.10
# Elapsed time: 34.05 seconds
# Epoch 30/200 - Train loss: 0.0808 - Val loss: 0.1198 - Train acc: 96.96% - Val acc: 95.94% - Test F1-score: 77.73
# Elapsed time: 34.17 seconds
# Epoch 31/200 - Train loss: 0.0799 - Val loss: 0.1189 - Train acc: 97.02% - Val acc: 96.23% - Test F1-score: 77.67
# Elapsed time: 33.94 seconds
# Epoch 32/200 - Train loss: 0.0790 - Val loss: 0.1199 - Train acc: 97.04% - Val acc: 96.16% - Test F1-score: 78.31
# Elapsed time: 34.28 seconds
# Epoch 33/200 - Train loss: 0.0785 - Val loss: 0.1198 - Train acc: 97.06% - Val acc: 96.04% - Test F1-score: 78.17
# Elapsed time: 34.17 seconds
# Epoch 34/200 - Train loss: 0.0780 - Val loss: 0.1190 - Train acc: 97.10% - Val acc: 96.05% - Test F1-score: 78.88
# Elapsed time: 33.91 seconds
# Epoch 35/200 - Train loss: 0.0776 - Val loss: 0.1206 - Train acc: 97.07% - Val acc: 96.22% - Test F1-score: 78.26
# Elapsed time: 34.18 seconds
# Epoch 36/200 - Train loss: 0.0765 - Val loss: 0.1177 - Train acc: 97.13% - Val acc: 96.30% - Test F1-score: 78.43
# Elapsed time: 34.07 seconds
# Epoch 37/200 - Train loss: 0.0763 - Val loss: 0.1194 - Train acc: 97.14% - Val acc: 96.21% - Test F1-score: 78.79
# Elapsed time: 34.04 seconds
# Epoch 38/200 - Train loss: 0.0755 - Val loss: 0.1209 - Train acc: 97.13% - Val acc: 95.85% - Test F1-score: 77.26
# Elapsed time: 34.29 seconds
# Epoch 39/200 - Train loss: 0.0748 - Val loss: 0.1186 - Train acc: 97.19% - Val acc: 96.27% - Test F1-score: 78.89
# Elapsed time: 34.14 seconds
# Epoch 40/200 - Train loss: 0.0748 - Val loss: 0.1177 - Train acc: 97.18% - Val acc: 96.27% - Test F1-score: 78.44
# Elapsed time: 33.97 seconds
# Epoch 41/200 - Train loss: 0.0745 - Val loss: 0.1173 - Train acc: 97.19% - Val acc: 95.98% - Test F1-score: 78.58
# Elapsed time: 34.01 seconds
# Epoch 42/200 - Train loss: 0.0738 - Val loss: 0.1188 - Train acc: 97.26% - Val acc: 96.02% - Test F1-score: 77.94
# Elapsed time: 34.03 seconds
# Epoch 43/200 - Train loss: 0.0733 - Val loss: 0.1162 - Train acc: 97.22% - Val acc: 96.21% - Test F1-score: 78.31
# Elapsed time: 34.02 seconds
# Epoch 44/200 - Train loss: 0.0732 - Val loss: 0.1199 - Train acc: 97.20% - Val acc: 96.14% - Test F1-score: 78.20
# Elapsed time: 33.83 seconds
# Epoch 45/200 - Train loss: 0.0724 - Val loss: 0.1172 - Train acc: 97.27% - Val acc: 96.05% - Test F1-score: 78.62
# Elapsed time: 34.26 seconds
# Epoch 46/200 - Train loss: 0.0725 - Val loss: 0.1176 - Train acc: 97.26% - Val acc: 96.19% - Test F1-score: 78.69
# Elapsed time: 34.20 seconds
# Epoch 47/200 - Train loss: 0.0718 - Val loss: 0.1176 - Train acc: 97.30% - Val acc: 96.19% - Test F1-score: 78.47
# Elapsed time: 34.38 seconds
# Epoch 48/200 - Train loss: 0.0717 - Val loss: 0.1177 - Train acc: 97.30% - Val acc: 96.18% - Test F1-score: 78.45
# Elapsed time: 34.25 seconds
# Epoch 49/200 - Train loss: 0.0713 - Val loss: 0.1167 - Train acc: 97.33% - Val acc: 96.39% - Test F1-score: 79.12
# Elapsed time: 33.89 seconds
# Epoch 50/200 - Train loss: 0.0709 - Val loss: 0.1171 - Train acc: 97.32% - Val acc: 96.28% - Test F1-score: 78.56
# Elapsed time: 33.97 seconds
# Epoch 51/200 - Train loss: 0.0707 - Val loss: 0.1180 - Train acc: 97.35% - Val acc: 96.29% - Test F1-score: 78.54
# Elapsed time: 34.72 seconds
# Epoch 52/200 - Train loss: 0.0706 - Val loss: 0.1176 - Train acc: 97.34% - Val acc: 96.31% - Test F1-score: 78.84
# Elapsed time: 34.00 seconds
# Epoch 53/200 - Train loss: 0.0701 - Val loss: 0.1171 - Train acc: 97.39% - Val acc: 96.31% - Test F1-score: 78.70
# Elapsed time: 33.84 seconds
# Epoch 54/200 - Train loss: 0.0697 - Val loss: 0.1167 - Train acc: 97.38% - Val acc: 96.28% - Test F1-score: 78.80
# Elapsed time: 33.67 seconds
# Epoch 55/200 - Train loss: 0.0693 - Val loss: 0.1171 - Train acc: 97.41% - Val acc: 96.38% - Test F1-score: 78.85
# Elapsed time: 33.66 seconds
# Epoch 56/200 - Train loss: 0.0696 - Val loss: 0.1199 - Train acc: 97.41% - Val acc: 96.28% - Test F1-score: 78.98
# Elapsed time: 33.84 seconds
# Epoch 57/200 - Train loss: 0.0693 - Val loss: 0.1176 - Train acc: 97.40% - Val acc: 96.37% - Test F1-score: 78.94
# Elapsed time: 33.73 seconds
# Epoch 58/200 - Train loss: 0.0690 - Val loss: 0.1194 - Train acc: 97.41% - Val acc: 96.23% - Test F1-score: 79.03
# Elapsed time: 34.12 seconds
# Epoch 59/200 - Train loss: 0.0688 - Val loss: 0.1178 - Train acc: 97.42% - Val acc: 96.35% - Test F1-score: 79.06
# Elapsed time: 34.00 seconds
# Epoch 60/200 - Train loss: 0.0686 - Val loss: 0.1174 - Train acc: 97.44% - Val acc: 96.37% - Test F1-score: 78.70
# Elapsed time: 33.82 seconds
# Epoch 61/200 - Train loss: 0.0686 - Val loss: 0.1173 - Train acc: 97.44% - Val acc: 96.13% - Test F1-score: 78.50
# Elapsed time: 33.83 seconds
# Epoch 62/200 - Train loss: 0.0687 - Val loss: 0.1181 - Train acc: 97.45% - Val acc: 96.34% - Test F1-score: 79.25
# Elapsed time: 34.36 seconds
# Epoch 63/200 - Train loss: 0.0682 - Val loss: 0.1175 - Train acc: 97.40% - Val acc: 96.21% - Test F1-score: 78.47
# Elapsed time: 33.76 seconds
# Epoch 64/200 - Train loss: 0.0680 - Val loss: 0.1172 - Train acc: 97.45% - Val acc: 96.28% - Test F1-score: 78.80
# Elapsed time: 33.63 seconds
# Epoch 65/200 - Train loss: 0.0681 - Val loss: 0.1178 - Train acc: 97.44% - Val acc: 96.07% - Test F1-score: 78.56
# Elapsed time: 34.20 seconds
# Epoch 66/200 - Train loss: 0.0679 - Val loss: 0.1175 - Train acc: 97.46% - Val acc: 96.25% - Test F1-score: 78.92
# Elapsed time: 34.07 seconds
# Epoch 67/200 - Train loss: 0.0679 - Val loss: 0.1176 - Train acc: 97.43% - Val acc: 96.26% - Test F1-score: 78.95
# Elapsed time: 34.33 seconds
# Epoch 68/200 - Train loss: 0.0675 - Val loss: 0.1240 - Train acc: 97.45% - Val acc: 96.07% - Test F1-score: 78.55
# Elapsed time: 34.61 seconds
# Epoch 69/200 - Train loss: 0.0673 - Val loss: 0.1180 - Train acc: 97.46% - Val acc: 96.39% - Test F1-score: 79.74
# Elapsed time: 34.44 seconds
# Epoch 70/200 - Train loss: 0.0673 - Val loss: 0.1177 - Train acc: 97.47% - Val acc: 96.40% - Test F1-score: 79.78
# Elapsed time: 34.51 seconds
# Epoch 71/200 - Train loss: 0.0673 - Val loss: 0.1177 - Train acc: 97.45% - Val acc: 96.35% - Test F1-score: 78.87
# Elapsed time: 34.09 seconds
# Epoch 72/200 - Train loss: 0.0670 - Val loss: 0.1184 - Train acc: 97.51% - Val acc: 96.30% - Test F1-score: 79.26
# Elapsed time: 34.12 seconds
# Epoch 73/200 - Train loss: 0.0670 - Val loss: 0.1183 - Train acc: 97.47% - Val acc: 96.29% - Test F1-score: 78.89
# Elapsed time: 34.07 seconds
# Epoch 74/200 - Train loss: 0.0670 - Val loss: 0.1175 - Train acc: 97.46% - Val acc: 96.42% - Test F1-score: 79.98
# Elapsed time: 34.01 seconds
# Epoch 75/200 - Train loss: 0.0667 - Val loss: 0.1173 - Train acc: 97.47% - Val acc: 96.29% - Test F1-score: 79.12
# Elapsed time: 33.87 seconds
# Epoch 76/200 - Train loss: 0.0666 - Val loss: 0.1186 - Train acc: 97.51% - Val acc: 96.34% - Test F1-score: 79.50
# Elapsed time: 33.68 seconds
# Epoch 77/200 - Train loss: 0.0667 - Val loss: 0.1189 - Train acc: 97.52% - Val acc: 96.17% - Test F1-score: 79.27
# Elapsed time: 34.12 seconds
# Epoch 78/200 - Train loss: 0.0665 - Val loss: 0.1175 - Train acc: 97.53% - Val acc: 96.35% - Test F1-score: 79.51
# Elapsed time: 34.19 seconds
# Epoch 79/200 - Train loss: 0.0666 - Val loss: 0.1175 - Train acc: 97.49% - Val acc: 96.29% - Test F1-score: 78.84
# Elapsed time: 33.31 seconds
# Epoch 80/200 - Train loss: 0.0667 - Val loss: 0.1177 - Train acc: 97.49% - Val acc: 96.27% - Test F1-score: 78.97
# Elapsed time: 33.86 seconds
# Epoch 81/200 - Train loss: 0.0663 - Val loss: 0.1176 - Train acc: 97.50% - Val acc: 96.28% - Test F1-score: 79.26
# Elapsed time: 33.57 seconds
# Epoch 82/200 - Train loss: 0.0666 - Val loss: 0.1178 - Train acc: 97.48% - Val acc: 96.25% - Test F1-score: 79.09
# Elapsed time: 33.82 seconds
# Epoch 83/200 - Train loss: 0.0663 - Val loss: 0.1175 - Train acc: 97.50% - Val acc: 96.29% - Test F1-score: 78.96
# Elapsed time: 33.94 seconds
# Epoch 84/200 - Train loss: 0.0661 - Val loss: 0.1175 - Train acc: 97.53% - Val acc: 96.32% - Test F1-score: 79.04
# Elapsed time: 34.03 seconds
# Epoch 85/200 - Train loss: 0.0662 - Val loss: 0.1183 - Train acc: 97.51% - Val acc: 96.33% - Test F1-score: 78.90
# Elapsed time: 34.03 seconds
# Epoch 86/200 - Train loss: 0.0660 - Val loss: 0.1171 - Train acc: 97.51% - Val acc: 96.22% - Test F1-score: 78.94
# Elapsed time: 34.18 seconds
# Epoch 87/200 - Train loss: 0.0661 - Val loss: 0.1176 - Train acc: 97.51% - Val acc: 96.39% - Test F1-score: 79.58
# Elapsed time: 34.02 seconds
# Epoch 88/200 - Train loss: 0.0661 - Val loss: 0.1178 - Train acc: 97.50% - Val acc: 96.29% - Test F1-score: 79.17
# Elapsed time: 33.97 seconds
# Epoch 89/200 - Train loss: 0.0660 - Val loss: 0.1174 - Train acc: 97.56% - Val acc: 96.36% - Test F1-score: 79.44
# Elapsed time: 33.81 seconds
# Epoch 90/200 - Train loss: 0.0662 - Val loss: 0.1178 - Train acc: 97.53% - Val acc: 96.34% - Test F1-score: 79.25
# Elapsed time: 34.09 seconds
# Epoch 91/200 - Train loss: 0.0658 - Val loss: 0.1178 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 78.71
# Elapsed time: 34.26 seconds
# Epoch 92/200 - Train loss: 0.0658 - Val loss: 0.1208 - Train acc: 97.55% - Val acc: 96.27% - Test F1-score: 79.23
# Elapsed time: 33.93 seconds
# Epoch 93/200 - Train loss: 0.0663 - Val loss: 0.1176 - Train acc: 97.52% - Val acc: 96.31% - Test F1-score: 78.91
# Elapsed time: 34.04 seconds
# Epoch 94/200 - Train loss: 0.0660 - Val loss: 0.1177 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 78.79
# Elapsed time: 34.13 seconds
# Epoch 95/200 - Train loss: 0.0658 - Val loss: 0.1174 - Train acc: 97.52% - Val acc: 96.35% - Test F1-score: 79.45
# Elapsed time: 34.48 seconds
# Epoch 96/200 - Train loss: 0.0656 - Val loss: 0.1190 - Train acc: 97.54% - Val acc: 96.24% - Test F1-score: 78.77
# Elapsed time: 33.93 seconds
# Epoch 97/200 - Train loss: 0.0657 - Val loss: 0.1181 - Train acc: 97.53% - Val acc: 96.37% - Test F1-score: 79.50
# Elapsed time: 33.82 seconds
# Epoch 98/200 - Train loss: 0.0662 - Val loss: 0.1177 - Train acc: 97.52% - Val acc: 96.33% - Test F1-score: 79.51
# Elapsed time: 33.85 seconds
# Epoch 99/200 - Train loss: 0.0656 - Val loss: 0.1176 - Train acc: 97.54% - Val acc: 96.32% - Test F1-score: 79.35
# Elapsed time: 33.80 seconds
# Epoch 100/200 - Train loss: 0.0656 - Val loss: 0.1174 - Train acc: 97.55% - Val acc: 96.27% - Test F1-score: 78.80
# Elapsed time: 33.91 seconds
# Epoch 101/200 - Train loss: 0.0656 - Val loss: 0.1187 - Train acc: 97.54% - Val acc: 96.27% - Test F1-score: 79.37
# Elapsed time: 33.16 seconds
# Epoch 102/200 - Train loss: 0.0658 - Val loss: 0.1176 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.02
# Elapsed time: 33.43 seconds
# Epoch 103/200 - Train loss: 0.0656 - Val loss: 0.1183 - Train acc: 97.51% - Val acc: 96.26% - Test F1-score: 78.55
# Elapsed time: 32.90 seconds
# Epoch 104/200 - Train loss: 0.0655 - Val loss: 0.1176 - Train acc: 97.52% - Val acc: 96.35% - Test F1-score: 79.56
# Elapsed time: 32.70 seconds
# Epoch 105/200 - Train loss: 0.0656 - Val loss: 0.1177 - Train acc: 97.53% - Val acc: 96.35% - Test F1-score: 79.53
# Elapsed time: 33.26 seconds
# Epoch 106/200 - Train loss: 0.0655 - Val loss: 0.1176 - Train acc: 97.58% - Val acc: 96.32% - Test F1-score: 79.14
# Elapsed time: 33.31 seconds
# Epoch 107/200 - Train loss: 0.0655 - Val loss: 0.1186 - Train acc: 97.55% - Val acc: 96.26% - Test F1-score: 79.14
# Elapsed time: 33.15 seconds
# Epoch 108/200 - Train loss: 0.0656 - Val loss: 0.1177 - Train acc: 97.52% - Val acc: 96.35% - Test F1-score: 79.46
# Elapsed time: 33.29 seconds
# Epoch 109/200 - Train loss: 0.0655 - Val loss: 0.1175 - Train acc: 97.55% - Val acc: 96.31% - Test F1-score: 79.37
# Elapsed time: 33.26 seconds
# Epoch 110/200 - Train loss: 0.0655 - Val loss: 0.1174 - Train acc: 97.50% - Val acc: 96.31% - Test F1-score: 79.18
# Elapsed time: 33.41 seconds
# Epoch 111/200 - Train loss: 0.0654 - Val loss: 0.1195 - Train acc: 97.56% - Val acc: 96.25% - Test F1-score: 79.22
# Elapsed time: 32.72 seconds
# Epoch 112/200 - Train loss: 0.0654 - Val loss: 0.1180 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.07
# Elapsed time: 32.86 seconds
# Epoch 113/200 - Train loss: 0.0653 - Val loss: 0.1177 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.06
# Elapsed time: 33.04 seconds
# Epoch 114/200 - Train loss: 0.0654 - Val loss: 0.1181 - Train acc: 97.56% - Val acc: 96.29% - Test F1-score: 78.92
# Elapsed time: 33.17 seconds
# Epoch 115/200 - Train loss: 0.0654 - Val loss: 0.1174 - Train acc: 97.56% - Val acc: 96.28% - Test F1-score: 79.10
# Elapsed time: 33.00 seconds
# Epoch 116/200 - Train loss: 0.0653 - Val loss: 0.1174 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.09
# Elapsed time: 33.15 seconds
# Epoch 117/200 - Train loss: 0.0653 - Val loss: 0.1179 - Train acc: 97.54% - Val acc: 96.33% - Test F1-score: 79.38
# Elapsed time: 33.33 seconds
# Epoch 118/200 - Train loss: 0.0654 - Val loss: 0.1180 - Train acc: 97.53% - Val acc: 96.29% - Test F1-score: 78.84
# Elapsed time: 33.14 seconds
# Epoch 119/200 - Train loss: 0.0653 - Val loss: 0.1179 - Train acc: 97.53% - Val acc: 96.31% - Test F1-score: 79.18
# Elapsed time: 33.16 seconds
# Epoch 120/200 - Train loss: 0.0656 - Val loss: 0.1177 - Train acc: 97.52% - Val acc: 96.29% - Test F1-score: 79.15
# Elapsed time: 33.25 seconds
# Epoch 121/200 - Train loss: 0.0652 - Val loss: 0.1178 - Train acc: 97.57% - Val acc: 96.31% - Test F1-score: 79.10
# Elapsed time: 33.06 seconds
# Epoch 122/200 - Train loss: 0.0652 - Val loss: 0.1174 - Train acc: 97.53% - Val acc: 96.30% - Test F1-score: 79.13
# Elapsed time: 32.89 seconds
# Epoch 123/200 - Train loss: 0.0653 - Val loss: 0.1178 - Train acc: 97.53% - Val acc: 96.33% - Test F1-score: 79.14
# Elapsed time: 32.97 seconds
# Epoch 124/200 - Train loss: 0.0653 - Val loss: 0.1180 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 79.01
# Elapsed time: 33.06 seconds
# Epoch 125/200 - Train loss: 0.0654 - Val loss: 0.1179 - Train acc: 97.53% - Val acc: 96.31% - Test F1-score: 79.19
# Elapsed time: 33.07 seconds
# Epoch 126/200 - Train loss: 0.0652 - Val loss: 0.1181 - Train acc: 97.54% - Val acc: 96.33% - Test F1-score: 79.25
# Elapsed time: 33.10 seconds
# Epoch 127/200 - Train loss: 0.0653 - Val loss: 0.1180 - Train acc: 97.57% - Val acc: 96.32% - Test F1-score: 79.14
# Elapsed time: 33.60 seconds
# Epoch 128/200 - Train loss: 0.0654 - Val loss: 0.1178 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 78.90
# Elapsed time: 33.51 seconds
# Epoch 129/200 - Train loss: 0.0652 - Val loss: 0.1210 - Train acc: 97.53% - Val acc: 96.25% - Test F1-score: 79.17
# Elapsed time: 33.08 seconds
# Epoch 130/200 - Train loss: 0.0654 - Val loss: 0.1176 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.14
# Elapsed time: 33.42 seconds
# Epoch 131/200 - Train loss: 0.0653 - Val loss: 0.1176 - Train acc: 97.56% - Val acc: 96.33% - Test F1-score: 79.36
# Elapsed time: 33.30 seconds
# Epoch 132/200 - Train loss: 0.0655 - Val loss: 0.1182 - Train acc: 97.54% - Val acc: 96.33% - Test F1-score: 79.28
# Elapsed time: 32.94 seconds
# Epoch 133/200 - Train loss: 0.0655 - Val loss: 0.1175 - Train acc: 97.54% - Val acc: 96.32% - Test F1-score: 79.20
# Elapsed time: 32.97 seconds
# Epoch 134/200 - Train loss: 0.0653 - Val loss: 0.1175 - Train acc: 97.50% - Val acc: 96.29% - Test F1-score: 78.93
# Elapsed time: 33.13 seconds
# Epoch 135/200 - Train loss: 0.0653 - Val loss: 0.1189 - Train acc: 97.54% - Val acc: 96.24% - Test F1-score: 79.16
# Elapsed time: 33.22 seconds
# Epoch 136/200 - Train loss: 0.0654 - Val loss: 0.1178 - Train acc: 97.52% - Val acc: 96.31% - Test F1-score: 79.25
# Elapsed time: 33.18 seconds
# Epoch 137/200 - Train loss: 0.0652 - Val loss: 0.1180 - Train acc: 97.55% - Val acc: 96.32% - Test F1-score: 79.21
# Elapsed time: 33.42 seconds
# Epoch 138/200 - Train loss: 0.0651 - Val loss: 0.1179 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.18
# Elapsed time: 33.03 seconds
# Epoch 139/200 - Train loss: 0.0652 - Val loss: 0.1177 - Train acc: 97.53% - Val acc: 96.33% - Test F1-score: 79.42
# Elapsed time: 32.88 seconds
# Epoch 140/200 - Train loss: 0.0653 - Val loss: 0.1213 - Train acc: 97.52% - Val acc: 96.23% - Test F1-score: 79.27
# Elapsed time: 33.43 seconds
# Epoch 141/200 - Train loss: 0.0652 - Val loss: 0.1179 - Train acc: 97.57% - Val acc: 96.30% - Test F1-score: 79.04
# Elapsed time: 33.16 seconds
# Epoch 142/200 - Train loss: 0.0652 - Val loss: 0.1175 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.26
# Elapsed time: 33.15 seconds
# Epoch 143/200 - Train loss: 0.0651 - Val loss: 0.1176 - Train acc: 97.56% - Val acc: 96.30% - Test F1-score: 79.28
# Elapsed time: 33.09 seconds
# Epoch 144/200 - Train loss: 0.0652 - Val loss: 0.1180 - Train acc: 97.56% - Val acc: 96.32% - Test F1-score: 79.19
# Elapsed time: 33.01 seconds
# Epoch 145/200 - Train loss: 0.0651 - Val loss: 0.1178 - Train acc: 97.57% - Val acc: 96.32% - Test F1-score: 79.29
# Elapsed time: 33.27 seconds
# Epoch 146/200 - Train loss: 0.0652 - Val loss: 0.1176 - Train acc: 97.57% - Val acc: 96.30% - Test F1-score: 79.24
# Elapsed time: 32.88 seconds
# Epoch 147/200 - Train loss: 0.0655 - Val loss: 0.1227 - Train acc: 97.52% - Val acc: 96.14% - Test F1-score: 79.07
# Elapsed time: 33.29 seconds
# Epoch 148/200 - Train loss: 0.0655 - Val loss: 0.1185 - Train acc: 97.54% - Val acc: 96.22% - Test F1-score: 79.23
# Elapsed time: 33.20 seconds
# Epoch 149/200 - Train loss: 0.0651 - Val loss: 0.1179 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.14
# Elapsed time: 33.20 seconds
# Epoch 150/200 - Train loss: 0.0652 - Val loss: 0.1179 - Train acc: 97.54% - Val acc: 96.29% - Test F1-score: 79.04
# Elapsed time: 33.68 seconds
# Epoch 151/200 - Train loss: 0.0652 - Val loss: 0.1178 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.10
# Elapsed time: 33.34 seconds
# Epoch 152/200 - Train loss: 0.0652 - Val loss: 0.1182 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.14
# Elapsed time: 33.47 seconds
# Epoch 153/200 - Train loss: 0.0653 - Val loss: 0.1185 - Train acc: 97.57% - Val acc: 96.22% - Test F1-score: 79.06
# Elapsed time: 33.00 seconds
# Epoch 154/200 - Train loss: 0.0653 - Val loss: 0.1177 - Train acc: 97.58% - Val acc: 96.31% - Test F1-score: 79.41
# Elapsed time: 33.08 seconds
# Epoch 155/200 - Train loss: 0.0653 - Val loss: 0.1179 - Train acc: 97.53% - Val acc: 96.30% - Test F1-score: 79.08
# Elapsed time: 32.93 seconds
# Epoch 156/200 - Train loss: 0.0651 - Val loss: 0.1174 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.25
# Elapsed time: 33.02 seconds
# Epoch 157/200 - Train loss: 0.0651 - Val loss: 0.1180 - Train acc: 97.58% - Val acc: 96.29% - Test F1-score: 79.10
# Elapsed time: 33.07 seconds
# Epoch 158/200 - Train loss: 0.0654 - Val loss: 0.1175 - Train acc: 97.54% - Val acc: 96.28% - Test F1-score: 79.06
# Elapsed time: 32.95 seconds
# Epoch 159/200 - Train loss: 0.0651 - Val loss: 0.1180 - Train acc: 97.52% - Val acc: 96.28% - Test F1-score: 79.07
# Elapsed time: 33.15 seconds
# Epoch 160/200 - Train loss: 0.0650 - Val loss: 0.1180 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.25
# Elapsed time: 33.12 seconds
# Epoch 161/200 - Train loss: 0.0652 - Val loss: 0.1177 - Train acc: 97.54% - Val acc: 96.29% - Test F1-score: 79.32
# Elapsed time: 33.43 seconds
# Epoch 162/200 - Train loss: 0.0651 - Val loss: 0.1180 - Train acc: 97.55% - Val acc: 96.31% - Test F1-score: 79.22
# Elapsed time: 33.19 seconds
# Epoch 163/200 - Train loss: 0.0651 - Val loss: 0.1177 - Train acc: 97.54% - Val acc: 96.29% - Test F1-score: 79.05
# Elapsed time: 32.88 seconds
# Epoch 164/200 - Train loss: 0.0653 - Val loss: 0.1214 - Train acc: 97.56% - Val acc: 96.25% - Test F1-score: 79.25
# Elapsed time: 33.12 seconds
# Epoch 165/200 - Train loss: 0.0651 - Val loss: 0.1179 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 79.04
# Elapsed time: 33.48 seconds
# Epoch 166/200 - Train loss: 0.0653 - Val loss: 0.1176 - Train acc: 97.53% - Val acc: 96.30% - Test F1-score: 79.30
# Elapsed time: 32.69 seconds
# Epoch 167/200 - Train loss: 0.0652 - Val loss: 0.1182 - Train acc: 97.55% - Val acc: 96.28% - Test F1-score: 78.89
# Elapsed time: 33.36 seconds
# Epoch 168/200 - Train loss: 0.0653 - Val loss: 0.1174 - Train acc: 97.53% - Val acc: 96.29% - Test F1-score: 79.39
# Elapsed time: 32.84 seconds
# Epoch 169/200 - Train loss: 0.0653 - Val loss: 0.1179 - Train acc: 97.56% - Val acc: 96.29% - Test F1-score: 79.25
# Elapsed time: 33.15 seconds
# Epoch 170/200 - Train loss: 0.0651 - Val loss: 0.1180 - Train acc: 97.53% - Val acc: 96.31% - Test F1-score: 79.17
# Elapsed time: 33.04 seconds
# Epoch 171/200 - Train loss: 0.0651 - Val loss: 0.1176 - Train acc: 97.55% - Val acc: 96.31% - Test F1-score: 79.15
# Elapsed time: 32.77 seconds
# Epoch 172/200 - Train loss: 0.0652 - Val loss: 0.1198 - Train acc: 97.56% - Val acc: 96.24% - Test F1-score: 79.08
# Elapsed time: 33.07 seconds
# Epoch 173/200 - Train loss: 0.0652 - Val loss: 0.1177 - Train acc: 97.56% - Val acc: 96.32% - Test F1-score: 79.41
# Elapsed time: 33.17 seconds
# Epoch 174/200 - Train loss: 0.0654 - Val loss: 0.1182 - Train acc: 97.55% - Val acc: 96.31% - Test F1-score: 79.30
# Elapsed time: 33.26 seconds
# Epoch 175/200 - Train loss: 0.0654 - Val loss: 0.1177 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.11
# Elapsed time: 33.14 seconds
# Epoch 176/200 - Train loss: 0.0653 - Val loss: 0.1176 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.23
# Elapsed time: 33.36 seconds
# Epoch 177/200 - Train loss: 0.0653 - Val loss: 0.1178 - Train acc: 97.56% - Val acc: 96.32% - Test F1-score: 79.15
# Elapsed time: 33.28 seconds
# Epoch 178/200 - Train loss: 0.0651 - Val loss: 0.1176 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.31
# Elapsed time: 33.16 seconds
# Epoch 179/200 - Train loss: 0.0652 - Val loss: 0.1180 - Train acc: 97.56% - Val acc: 96.28% - Test F1-score: 78.95
# Elapsed time: 32.66 seconds
# Epoch 180/200 - Train loss: 0.0650 - Val loss: 0.1176 - Train acc: 97.53% - Val acc: 96.29% - Test F1-score: 79.27
# Elapsed time: 33.14 seconds
# Epoch 181/200 - Train loss: 0.0653 - Val loss: 0.1174 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 78.89
# Elapsed time: 33.09 seconds
# Epoch 182/200 - Train loss: 0.0653 - Val loss: 0.1178 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 79.22
# Elapsed time: 32.87 seconds
# Epoch 183/200 - Train loss: 0.0652 - Val loss: 0.1176 - Train acc: 97.55% - Val acc: 96.31% - Test F1-score: 79.18
# Elapsed time: 33.06 seconds
# Epoch 184/200 - Train loss: 0.0652 - Val loss: 0.1176 - Train acc: 97.55% - Val acc: 96.28% - Test F1-score: 79.10
# Elapsed time: 32.93 seconds
# Epoch 185/200 - Train loss: 0.0649 - Val loss: 0.1176 - Train acc: 97.54% - Val acc: 96.31% - Test F1-score: 79.08
# Elapsed time: 33.56 seconds
# Epoch 186/200 - Train loss: 0.0652 - Val loss: 0.1180 - Train acc: 97.57% - Val acc: 96.31% - Test F1-score: 79.24
# Elapsed time: 33.04 seconds
# Epoch 187/200 - Train loss: 0.0651 - Val loss: 0.1190 - Train acc: 97.52% - Val acc: 96.24% - Test F1-score: 79.12
# Elapsed time: 32.88 seconds
# Epoch 188/200 - Train loss: 0.0651 - Val loss: 0.1177 - Train acc: 97.56% - Val acc: 96.31% - Test F1-score: 79.31
# Elapsed time: 33.14 seconds
# Epoch 189/200 - Train loss: 0.0652 - Val loss: 0.1179 - Train acc: 97.53% - Val acc: 96.31% - Test F1-score: 79.29
# Elapsed time: 33.06 seconds
# Epoch 190/200 - Train loss: 0.0652 - Val loss: 0.1177 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 79.07
# Elapsed time: 32.93 seconds
# Epoch 191/200 - Train loss: 0.0651 - Val loss: 0.1179 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.10
# Elapsed time: 33.09 seconds
# Epoch 192/200 - Train loss: 0.0652 - Val loss: 0.1182 - Train acc: 97.55% - Val acc: 96.30% - Test F1-score: 79.36
# Elapsed time: 32.93 seconds
# Epoch 193/200 - Train loss: 0.0652 - Val loss: 0.1177 - Train acc: 97.54% - Val acc: 96.29% - Test F1-score: 78.95
# Elapsed time: 32.98 seconds
# Epoch 194/200 - Train loss: 0.0655 - Val loss: 0.1180 - Train acc: 97.54% - Val acc: 96.30% - Test F1-score: 79.06
# Elapsed time: 33.14 seconds
# Epoch 195/200 - Train loss: 0.0651 - Val loss: 0.1175 - Train acc: 97.55% - Val acc: 96.32% - Test F1-score: 79.41
# Elapsed time: 33.35 seconds
# Epoch 196/200 - Train loss: 0.0651 - Val loss: 0.1178 - Train acc: 97.55% - Val acc: 96.32% - Test F1-score: 79.16
# Elapsed time: 32.97 seconds
# Epoch 197/200 - Train loss: 0.0651 - Val loss: 0.1175 - Train acc: 97.54% - Val acc: 96.29% - Test F1-score: 79.04
# Elapsed time: 32.98 seconds
# Epoch 198/200 - Train loss: 0.0651 - Val loss: 0.1177 - Train acc: 97.55% - Val acc: 96.29% - Test F1-score: 79.04
# Elapsed time: 33.31 seconds
# Epoch 199/200 - Train loss: 0.0650 - Val loss: 0.1178 - Train acc: 97.57% - Val acc: 96.32% - Test F1-score: 79.35
# Elapsed time: 33.32 seconds
# Epoch 200/200 - Train loss: 0.0651 - Val loss: 0.1184 - Train acc: 97.54% - Val acc: 96.25% - Test F1-score: 79.31
# Elapsed time: 33.00 seconds

# %%
plt.figure(figsize=(12, 8))
plt.title(f"Training and Validation Loss and Accuracy")

# Plot training and validation loss
p1, = plt.plot(t1, label='Train loss', color='blue')
p2, = plt.plot(t4, label='Validation loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')

ax2 = plt.twinx()

# Plot training and validation accuracy
p3, = ax2.plot(t2, label='Train accuracy', color='orange')
p4, = ax2.plot(t3, label='Validation accuracy', color='green')
ax2.set_ylabel('Accuracy (%)')

# Plot test F1-score
p5, = ax2.plot(t5, label='F1-score', linestyle='dashed', color='purple')

# Combine legends
lines = [p1, p2, p3, p4, p5]
labels = [line.get_label() for line in lines]
plt.legend(lines, labels, loc='upper right')

plt.show()

# plt.figure(figsize=(12, 8))
# plt.title(f"Training and Validation Loss and Accuracy")

# # Plot training and validation loss
# plt.plot(t1, label='Train loss', color='blue')
# plt.plot(t4, label='Validation loss', color='red')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# ax2 = plt.twinx()

# # Plot training and validation accuracy
# ax2.plot(t2, label='Train accuracy', color='orange')
# ax2.plot(t3, label='Validation accuracy', color='green')
# ax2.set_ylabel('Accuracy (%)')

# # Plot test F1-score
# ax2.plot(t5, label='F1-score', linestyle='dashed', color='purple')

# plt.legend(loc='upper right')
# plt.show()

# %%
evaluate_model(model, test_loader, loss_fn, "LogEucResNet_combo_d1_7", "Confusion Matrix for LogEucResNet_combo_d1_7", combo=True, temp=False)
# Out:
# Validation loss: 0.1207
# Validation accuracy: 96.33%
# Model saved as LogEucResNet_combo_d1_7.ckpt
#                   precision    recall  f1-score   support
#
#             corn       0.98      0.98      0.98      3818
#       horsebeans       0.77      0.76      0.77        92
#           meadow       0.99      0.99      0.99     10508
#    spring_barley       0.73      0.58      0.64        78
#      spring_peas       0.75      0.78      0.77        55
#       sunflowers       0.93      0.89      0.91       254
#    winter_barley       0.91      0.93      0.92       817
#       winter_oat       0.43      0.22      0.29        87
#  winter_rapeseed       0.98      0.95      0.97       762
# winter_triticale       0.76      0.66      0.71       537
#     winter_wheat       0.94      0.96      0.95      4198
#
#         accuracy                           0.96     21206
#        macro avg       0.83      0.79      0.81     21206
#     weighted avg       0.96      0.96      0.96     21206
# Figure saved as Confusion Matrix for LogEucResNet_combo_d1_7.png
# 96.33377259036145

# %% [markdown]
# Compute some TSNE visualization of the embedding

# %%
def gen_features(net, dataloader, combo=False, temp=True):
    net.eval()
    targets_list = []
    outputs_list = []

    with th.no_grad():
        for idx, (x1, x2, targets) in enumerate(dataloader):
            x1 = x1.to(device)
            x2 = x2.to(device)
            targets = targets.to(device)
            targets_np = targets.data.cpu().numpy()

            # Conditional forward pass
            if combo:
                outputs = net(x1, x2)
            elif temp:
                outputs = net(x1)
            else:
                outputs = net(x2)

            outputs_np = outputs.data.cpu().numpy()
            
            targets_list.append(targets_np[:, np.newaxis])
            outputs_list.append(outputs_np)
            
            if ((idx + 1) % 10 == 0) or (idx + 1 == len(dataloader)):
                print(idx + 1, '/', len(dataloader))

    targets = np.concatenate(targets_list, axis=0)
    outputs = np.concatenate(outputs_list, axis=0).astype(np.float64)

    return targets, outputs

def tsne_plot(save_dir, targets, outputs):
    print('generating t-SNE plot...')
    # tsne_output = bh_sne(outputs)
    tsne = TSNE(random_state=42, perplexity=50)
    tsne_output = tsne.fit_transform(outputs)

    df = pd.DataFrame(tsne_output, columns=['x', 'y'])
    df['targets'] = targets

    plt.rcParams['figure.figsize'] = 10, 10
    sns.scatterplot(
        x='x', y='y',
        hue='targets',
        palette=sns.color_palette("Paired", 11),
        data=df,
        marker='o',
        legend="full",
        alpha=0.5
    )

    plt.xticks([])
    plt.yticks([])
    plt.xlabel('')
    plt.ylabel('')
    plt.legend(loc='best')
    plt.title('t-SNE plot of the embeddings: After training')

    #plt.savefig(os.path.join(save_dir,'tsne_mm_03.png'), bbox_inches='tight')
    print('done!')

# %%
targets, outputs = gen_features(model,test_loader, combo =True)
tsne_plot('.',targets, outputs)
# Out:
# 10 / 332
# 20 / 332
# 30 / 332
# 40 / 332
# 50 / 332
# 60 / 332
# 70 / 332
# 80 / 332
# 90 / 332
# 100 / 332
# 110 / 332
# 120 / 332
# 130 / 332
# 140 / 332
# 150 / 332
# 160 / 332
# 170 / 332
# 180 / 332
# 190 / 332
# 200 / 332
# 210 / 332
# 220 / 332
# 230 / 332
# 240 / 332
# 250 / 332
# 260 / 332
# 270 / 332
# 280 / 332
# 290 / 332
# 300 / 332
# 310 / 332
# 320 / 332
# 330 / 332
# 332 / 332
# generating t-SNE plot...
# done!
