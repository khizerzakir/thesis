# %%
import subprocess
import sys
sys.path.insert(0,'..')
from pathlib import Path
import os
import random

import torch
import torch.nn as nn
from torch.nn.functional import one_hot
from torch import Tensor
from typing import Union

import matplotlib.pylab as plt

import time
import numpy as np
import torch as th
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler

from focal_loss import FocalLoss
from utils import _axat, _atxa, _mvmt
import seaborn as sns


def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package],
                         stdout=subprocess.DEVNULL,
                         stderr=subprocess.DEVNULL
                         )
required_packages = [
    "geoopt",
    "pyriemann",
]
for package in required_packages:
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"{package} is not installed. Installing...")
        install(package)

import geoopt
from pyriemann.utils.covariance import covariances, normalize


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.manifold import TSNE
import pandas as pd


use_cuda = th.cuda.is_available()
device = th.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# geoopt is not installed. Installing...
# pyriemann is not installed. Installing...
# cuda:0

# %% [markdown]
# ## Defining Flags and Variables

# %%
# Flags and Parameters
root_dir = r"/kaggle/input/normalized-data/"
npz_file = "98_p_norm_data.npz"
folder_name = "mm_018"
os.makedirs(folder_name, exist_ok=True)
batch_size = 64  # batch size
n_classes = 11
random_seed = 42
test_size = 0.2
temp = True  # Whether the data is in temporal mode
val = True  # Whether to create a validation loader
combo = False  # Whether the data is in combo mode

model_name = "model_temp_bsm_mm_018"
figure_name = "CM_temp_bsm_mm_018"
tsne_fig_name ="Tsne_temp_bsm_mm_018"
plot_figure_name = "training_validation_results_temp_bsm_mm_018"
# for model

lr=1e-2
epochs=200
gamma_value=0.95
loss = "focal"
gamma_loss = 0.1
step_size=30
step_lr = False
linear_classif = False

# %% [markdown]
# ## Model, Dataset, and Classifier definition

# %%
class BusemanSimilarityClassifier(nn.Module):
    def busemann_spd(self, logM):
        """
        Compute the Busemann similarity for Symmetric Positive Definite (SPD) matrices.
        
        :param logM: Logarithm of SPD matrices, shape (b, n, n)
        :return: Similarity scores, shape (b, n_proto)
        """
        return logM.reshape(logM.shape[0], -1) @ self.proto.reshape(self.proto.shape[0], -1).T
    def __init__(self,dim1,n_proto,n_classes,optim_proto=True):
        super().__init__()
        self.n_proto = n_proto
        self.n_classes = n_classes
        self.dim1 = dim1
        
        self.manifold = geoopt.Stiefel()

        # Random projection directions, shape (d-1, num_projections)
        theta = np.random.normal(size=(self.n_proto, self.dim1))
        theta = th.nn.functional.normalize(th.from_numpy(theta), p=2, dim=-1).type(th.float64).to(device)
        #self.D = theta[:,None] * th.eye(theta.shape[-1],dtype=th.float64, device=device)
        self.register_parameter("theta_proto", geoopt.ManifoldParameter(theta, geoopt.Sphere()))
        #self.theta_proto=theta

        ## Random orthogonal matrices
        Z = th.randn((self.n_proto, self.dim1, self.dim1), dtype=th.float64, device=device)
        self.Q = th.svd(Z)[0]
        self.manifold.assert_check_point_on_manifold(self.Q)
        self.register_parameter("Q_proto", geoopt.ManifoldParameter(self.Q, self.manifold))
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        # linear layer
        self.linear = nn.Linear(self.n_proto, self.n_classes).double()

    def forward(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        y = self.linear(self.busemann_spd(x))#.view(sim_embedding.shape[0], -1))
        return y
    
    def embed(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        return self.busemann_spd(x)

# %%
class LogEucRResNet(nn.Module):
    def __init__(self, inputdim=10, dim1=7, n_proto=12, classes=11, embed_only=False, linear_classif=False):
        super().__init__()
        self.inputdim = inputdim
        self.dim1 = dim1
        self.n_proto = n_proto
        self.classes = classes
        self.embed_only = embed_only
        self.linear_classif = linear_classif

        self.manifold_Stiefel = geoopt.Stiefel()
        self.manifold_SPD = geoopt.SymmetricPositiveDefinite("LEM")
        
        # init first bimap
        bm1 = th.randn((1, self.inputdim, self.dim1), dtype=th.float64)
        bm1 = th.svd(bm1)[0]
        self.register_parameter("bimap1", geoopt.ManifoldParameter(bm1, self.manifold_Stiefel))
        
        P = th.randn((1, self.dim1, self.dim1), dtype=th.float64)
        P = th.svd(P)[0]

        self.register_parameter("P1", geoopt.ManifoldParameter(P, self.manifold_Stiefel))

        self.classiflayer=BusemanSimilarityClassifier(self.dim1,self.n_proto, classes)
        self.fc_layer = nn.Linear(self.dim1 * self.dim1, self.classes).double()
        self.softmax =  nn.Softmax(dim=-1)

        self.spectrum_map = nn.Sequential(
            nn.Conv1d(1, 128, 5, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(128).double(),
            nn.Conv1d(128, 64, 3, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(64).double(),
            nn.Conv1d(64, 1, 3, padding="same").double(),
        )
        
    def forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs) # spectral map
        v1 = _mvmt(self.P1, f_eigs, self.P1)            
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)     
        x = log_x + v1
        if self.embed_only:
            return x.reshape(x.shape[0],-1)
        elif self.linear_classif:
            return self.softmax(self.fc_layer(x.reshape(x.shape[0],-1)))
        else:
            return self.softmax(self.classiflayer(x)) # Buseman Similarity Classifier when single modality is used
    def partial_forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs)
        v1 = _mvmt(self.P1, f_eigs, self.P1)
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)
        x = log_x + v1
        return self.classiflayer.embed(x)
            
class LogEucRResNet_Combo(nn.Module):
    def __init__(self, inputdim_temp=36, dim1_temp=24, inputdim_spec=10, dim1_spec=7, n_proto=12, classes=11, buseman_classif=True):
        super().__init__()
        self.classes = classes
        self.buseman_classif = buseman_classif
        self.model_temp = LogEucRResNet(inputdim_temp, dim1_temp, n_proto, embed_only=True)
        self.model_spectral = LogEucRResNet(inputdim_spec, dim1_spec, n_proto, embed_only=True)
        
        self.classiflayer = BusemanSimilarityClassifier(dim1_temp+1,n_proto,classes)
        self.fc_layer = nn.Linear(dim1_temp*dim1_temp+dim1_spec*dim1_spec,classes).double()        
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, x1, x2):
        out_1 = self.model_temp(x1) # probabilities
        out_2 = self.model_spectral(x2) # probabilities
        x = th.concat((out_1, out_2), dim=1)
        #print(x.shape)
        if self.buseman_classif:
            return self.softmax(self.classiflayer(x))
        else:
            return self.softmax(self.fc_layer(x))
        
    def partial_forward(self, x1, x2):
        out_1 = self.model_temp.partial_forward(x1)
        out_2 = self.model_spectral.partial_forward(x2)
        x = th.concat((out_1, out_2), dim=1)
        return self.classiflayer.embed(x)

# %%
class TS_COV(Dataset):
    def __init__(self, root_dir, np_file, estimator='scm', combo=True, temp=False):
        self.root_dir = root_dir
        self.np_file = np_file
        self.estimator = estimator
        self.combo = combo
        self.temp = temp
        self.x, self.y, self.class_names = self.load_data()
        #self.cov = normalize(self.calculate_covariances(),'corr')
        self.x1 = self.calculate_covariances_36()
        self.x2 = self.calculate_covariances_10()
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x1, x2= self.x1[idx], self.x2[idx]
        y_sample = self.y[idx]
        class_name = self.class_names[y_sample]
        x1 = th.from_numpy(np.asarray([x1])).double()
        x2 = th.from_numpy(np.asarray([x2])).double()
        x1,x2 = x1.reshape(1, 36, 36), x2.reshape(1, 10, 10)
        y = th.from_numpy(np.array(y_sample)).long()
        if self.combo:
            return x1,x2, y
        elif self.temp:
            return x1, y
        else:
            return x2, y

    def load_data(self):
        file_path = os.path.join(self.root_dir, self.np_file)
        data = np.load(file_path, allow_pickle= True)
        x = data['series']
        y = data['labels']
        class_names = data['class_names']
        return x, y, class_names

    def calculate_covariances_10(self):
        x_transposed = np.transpose(self.x, (0, 2, 1))
        cov = covariances(x_transposed, estimator=self.estimator)
        return cov
    def calculate_covariances_36(self):
        cov = covariances(self.x, estimator=self.estimator)
        return cov

# %% [markdown]
# ## Helper functions

# %%
def initialize_model(combo=True, linear_classif=True, temp=False, device=device):
    if combo:
        if linear_classif:
            model = LogEucRResNet_Combo(buseman_classif=False).to(device)
            print("Combo model with linear classifier")
        else:
            model = LogEucRResNet_Combo(buseman_classif=True).to(device)
            print("Combo model with Buseman classifier")
    elif temp:
        if linear_classif:
            inputdim = 36
            dim1 = 24
            model = LogEucRResNet(inputdim, dim1, linear_classif=True).to(device)
            print("Single modality - Temp model with linear classifier")
        else:
            inputdim = 36
            dim1 = 24
            model = LogEucRResNet(inputdim, dim1, linear_classif=False).to(device)
            print("Single modality - Temp model with Buseman classifier")
    else:
        if linear_classif:
            inputdim = 10
            dim1 = 7
            model = LogEucRResNet(inputdim, dim1, linear_classif=True).to(device)
            print("Single modality - Spectral model with linear classifier")
        else:
            inputdim = 10
            dim1 = 7
            model = LogEucRResNet(inputdim, dim1, linear_classif=False).to(device)
            print("Single modality - Spectral model with Buseman classifier")

    # Get number of trainable parameters
    model.eval()
    trainable_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Trainable total parameters: {trainable_total_params}')
    return model

# calculate the weights for the classes
def calculate_class_weights(labels):
    class_sample_count = np.array([len(np.where(labels == t)[0]) for t in np.unique(labels)])
    weight = 1 - class_sample_count / len(labels)
    return th.from_numpy(weight).double()
# data loaders
def create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=True):
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(train_indices))
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(test_indices), shuffle=False)
    
    if val:
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(val_indices))
        return train_loader, val_loader, test_loader
    else:
        return train_loader, test_loader
    
# plotting data distribution
def plot_class_distribution(train_loader, val_loader, test_loader, n_classes, combo=False):
    class_names = train_loader.dataset.class_names
    
    def count_labels(loader, n_classes):
        counts = np.zeros(n_classes)
        for batch in loader:
            if combo:
                _, _, labels = batch  # x1, x2, labels
            else:
                _, labels = batch  # x, labels
            for l in labels:
                counts[l] += 1
        return counts

    train_counts = count_labels(train_loader, n_classes)
    
    if val_loader is not None:
        val_counts = count_labels(val_loader, n_classes)
    else:
        val_counts = np.zeros(n_classes)
    
    test_counts = count_labels(test_loader, n_classes)

    # Bar plot
    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes) - test_size, train_counts, 0.2, label='Train')
    if val_loader is not None:
        plt.bar(np.arange(n_classes), val_counts, 0.2, label='Validation')
    plt.bar(np.arange(n_classes) + 0.2, test_counts, 0.2, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes), train_counts, alpha=0.5, label='Train')
    plt.bar(np.arange(n_classes), val_counts, alpha=0.5, label='Validation')
    plt.bar(np.arange(n_classes), test_counts, alpha=0.5, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Histogram of Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Histogram of Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

# %%
# train the model
def train_model(model, train_loader, val_loader, loss_fn, optimizer, scheduler, epochs, combo=False):
    t1, t2, t3, t4, t5 = [], [], [], [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    for epoch in range(epochs):
        start_time = time.time()  # Start time of the epoch
        model.train()

        # Training phase
        loss_train, acc_train = [], []
        for batch in train_loader:
            if combo:
                x1, x2, y = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, y = batch
                x = x.to(device)
                inputs = (x,)
            y = y.to(device).long()
            optimizer.zero_grad()
            
            # Forward pass
            out = model(*inputs)
                
            l = loss_fn(out, y)
            
            acc, loss = (out.argmax(1) == y).cpu().numpy().sum() / out.shape[0], l.cpu().data.numpy()
            loss_train.append(loss)
            acc_train.append(acc)
            l.backward()
            optimizer.step()
        scheduler.step()

        acc_train = np.asarray(acc_train).mean()
        loss_train = np.asarray(loss_train).mean()
        t1.append(loss_train)
        t2.append(100 * acc_train)

        # Validation phase
        loss_val, acc_val_list = [], []
        y_true, y_pred = [], []
        model.eval()
        for batch in val_loader:
            if combo:
                x1, x2, y = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, y = batch
                x = x.to(device)
                inputs = (x,)
            y = y.to(device).long()
            with th.no_grad():
                # Forward pass
                out = model(*inputs)
                    
                l = loss_fn(out, y)
                
            loss_val.append(l.cpu().data.numpy())
            predicted_labels = out.argmax(1)
            y_true.extend(list(y.cpu().numpy()))
            y_pred.extend(list(predicted_labels.cpu().numpy()))
            acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
            
            acc_val_list.append(acc)
        acc_val = np.asarray(acc_val_list).mean()
        loss_val = np.asarray(loss_val).mean()    
   
        t3.append(100 * acc_val)
        t4.append(loss_val)
        f1_test = f1_score(y_true, y_pred, average='macro')
        t5.append(100 * f1_test)
        print('Epoch {}/{} - Train loss: {:.4f} - Val loss: {:.4f} - Train acc: {:.2f}% - Val acc: {:.2f}% - Test F1-score: {:.2f}'.format(
            epoch + 1, epochs, loss_train, loss_val, 100 * acc_train, 100 * acc_val, 100 * f1_test))

        elapsed_time = time.time() - start_time
        print('Elapsed time: {:.2f} seconds'.format(elapsed_time))

    return t1, t2, t3, t4, t5

# plot the training results
def plot_training_results(t1, t2, t3, t4, t5, figure_name):
    plt.figure(figsize=(12, 8))
    plt.title("Training and Validation Loss and Accuracy")

    # Plot training and validation loss
    p1, = plt.plot(t1, label='Train loss', color='blue')
    p2, = plt.plot(t4, label='Validation loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    ax2 = plt.twinx()

    # Plot training and validation accuracy
    p3, = ax2.plot(t2, label='Train accuracy', color='orange')
    p4, = ax2.plot(t3, label='Validation accuracy', color='green')
    ax2.set_ylabel('Accuracy (%)')

    # Plot test F1-score
    p5, = ax2.plot(t5, label='F1-score', linestyle='dashed', color='purple')

    # Combine legends
    lines = [p1, p2, p3, p4, p5]
    labels = [line.get_label() for line in lines]
    #plt.legend(lines, labels, loc='upper right')
    plt.legend(lines, labels, loc='center left', bbox_to_anchor=(1.1, 0.5))

    # Save the figure with the provided name
    plot_filename = os.path.join(folder_name, f'{figure_name}.png')
    plt.savefig(plot_filename, bbox_inches='tight', pad_inches=0.2, dpi=500)
    print(f'Figure saved as {figure_name}.png')
    plt.show()

# evaluate the model
def evaluate_model(model, data_loader, loss_fn, model_name, figure_name, combo=False):
    loss_val, acc_val = [], []
    y_true, y_pred = [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    model.eval()
    for batch in data_loader:
        if combo:
            x1, x2, y = batch
            x1 = x1.to(device)
            x2 = x2.to(device)
            inputs = (x1, x2)
        else:
            x, y = batch
            x = x.to(device)
            inputs = (x,)
        y = y.to(device).long()
        
        with th.no_grad():
            # Forward pass
            out = model(*inputs)
            l = loss_fn(out, y)
        
        predicted_labels = out.argmax(1)
        y_true.extend(list(y.cpu().numpy()))
        y_pred.extend(list(predicted_labels.cpu().numpy()))
        acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
        loss_val.append(l.cpu().data.numpy())
        acc_val.append(acc)

    acc_val = np.asarray(acc_val).mean()
    loss_val = np.asarray(loss_val).mean()

    print('Validation loss: {:.4f}'.format(loss_val))
    print('Validation accuracy: {:.2f}%'.format(100 * acc_val))

    # Save the model
    #save is a folder
    model_filename = os.path.join(folder_name, f'{model_name}.ckpt')
    th.save(model.state_dict(), model_filename)
    print(f'Model saved as {model_name}.ckpt')

    # Print classification report
    print(classification_report(y_true, y_pred, digits=2, target_names=data_loader.dataset.class_names))
    cmatrix = confusion_matrix(y_true, y_pred)
    Ncmatrix = cmatrix.astype('float') / cmatrix.sum(axis=1)[:, np.newaxis]

    group_counts = ['{0:0.0f}'.format(value) for value in cmatrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in Ncmatrix.flatten()]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(n_classes, n_classes)

    # Plot and save the confusion matrix figure
    plt.figure(figsize=(10, 8))
    sns.heatmap(Ncmatrix, annot=labels, fmt='', cmap='Reds', xticklabels=data_loader.dataset.class_names, yticklabels=data_loader.dataset.class_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label\n Acc={:.2f}%'.format(100 * acc_val))
    
    plot_name = os.path.join(folder_name, f'{figure_name}.png')
    plt.savefig(plot_name, bbox_inches='tight', pad_inches=0.2, dpi=500)
    plt.show()
    print(f'Figure saved as {figure_name}.png')

    return 100 * acc_val

# %%
# tsn-e plot

def gen_features(net, dataloader, combo=False, linear_classif = True):
    net.eval()
    targets_list = []
    outputs_list = []

    with th.no_grad():
        for idx, batch in enumerate(dataloader):
            if combo:
                x1, x2, targets = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, targets = batch
                x = x.to(device)
                inputs = (x,)
            targets = targets.to(device)
            targets_np = targets.cpu().numpy()
            
            if linear_classif:
                outputs = net.forward(*inputs)
                outputs_np = outputs.data.cpu().numpy()
            else:
                outputs = net.partial_forward(*inputs)
                outputs_np = outputs.data.cpu().numpy()
            
            targets_list.append(targets_np[:, np.newaxis])
            outputs_list.append(outputs_np)

            if ((idx + 1) % 10 == 0) or (idx + 1 == len(dataloader)):
                print(idx + 1, '/', len(dataloader))

    targets = np.concatenate(targets_list, axis=0)
    outputs = np.concatenate(outputs_list, axis=0).astype(np.float64)

    return targets, outputs

def tsne_plot(fig_name, targets, outputs):
    print('generating t-SNE plot...')
    # tsne_output = bh_sne(outputs)
    tsne = TSNE(random_state=42, perplexity=50)
    tsne_output = tsne.fit_transform(outputs)

    df = pd.DataFrame(tsne_output, columns=['x', 'y'])
    df['targets'] = targets

    plt.rcParams['figure.figsize'] = 10, 10
    sns.scatterplot(
        x='x', y='y',
        hue='targets',
        palette=sns.color_palette("Paired", 11),
        data=df,
        marker='o',
        legend="full",
        alpha=0.5
    )

    plt.xticks([])
    plt.yticks([])
    plt.xlabel('')
    plt.ylabel('')
    plt.legend(loc='best')
    plt.title('t-SNE plot of the embeddings: After training')


    plot_name = os.path.join(folder_name, f'{fig_name}.png')
    plt.savefig(plot_name, bbox_inches='tight', pad_inches=0.2, dpi=500)
    plt.show()
    print(f'Figure saved as {fig_name}.png')
    print('done!')

# %% [markdown]
# # Start

# %%
# %matplotlib inline
# Initialize dataset
dataset = TS_COV(root_dir=root_dir, np_file=npz_file, estimator='scm', combo=combo, temp=temp)

# Split data into train, validation, and test sets
if val is not None:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                    test_size=test_size, stratify=dataset.y, random_state=random_seed)
    train_indices, val_indices = train_test_split(train_indices,
                                                   test_size=test_size, stratify=dataset.y[train_indices], random_state=random_seed)
else:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                   test_size=test_size, stratify=dataset.y, random_state=random_seed)
    val_indices = None

# Calculate class weights
weights = calculate_class_weights(dataset.y)
weights = weights.to(device)

# Create data loaders
if val:
    train_loader, val_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
else:
    train_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
    val_loader = None

# Plot class distribution
plot_class_distribution(train_loader, val_loader, test_loader, n_classes=n_classes, combo=combo)

# %%
# access one matri
if combo:
    for x1,x2, y in train_loader:
        print(x1.shape)
        print(x2.shape)
        print(y.shape)
        break
else:
    for x, y in train_loader:
        print(x.shape)
        print(y.shape)
        break
# Out:
# torch.Size([64, 1, 36, 36])
# torch.Size([64])

# %%
# initialize the model
model = initialize_model(combo, linear_classif, temp, device)
# model.load_state_dict(th.load('model_temp_linear_mm_209.ckpt'))
model.eval()
# Out:
# /opt/conda/lib/python3.10/site-packages/geoopt/manifolds/symmetric_positive_definite.py:52: UserWarning: SPDMetric.LEM is not fully implemented and results may be not as you expect
#   warnings.warn(
# Single modality - Temp model with Buseman classifier
# Trainable total parameters: 41115
# LogEucRResNet(
#   (manifold_Stiefel): Stiefel(canonical) manifold
#   (manifold_SPD): SymmetricPositiveDefinite(default_metric=SPDMetric.LEM) manifold
#   (classiflayer): BusemanSimilarityClassifier(
#     (manifold): Stiefel(canonical) manifold
#     (linear): Linear(in_features=12, out_features=11, bias=True)
#   )
#   (fc_layer): Linear(in_features=576, out_features=11, bias=True)
#   (softmax): Softmax(dim=-1)
#   (spectrum_map): Sequential(
#     (0): Conv1d(1, 128, kernel_size=(5,), stride=(1,), padding=same)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=same)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv1d(64, 1, kernel_size=(3,), stride=(1,), padding=same)
#   )
# )

# %%
#setup loss and optimizer

if loss == "focal":
    loss_fn = FocalLoss(gamma=gamma_loss,weights=weights)
else:
    loss_fn = nn.CrossEntropyLoss(weights=weights)
#opti = MixOptimizer(model.parameters(),lr=lr)
opti = geoopt.optim.RiemannianAdam(model.parameters(), lr=lr)
if step_lr:
    scheduler = lr_scheduler.StepLR(opti, step_size, gamma_value)
else:
    scheduler = lr_scheduler.ExponentialLR(opti, gamma=gamma_value)

# %%
# %matplotlib inline

if val:
    t1, t2, t3, t4, t5 = train_model(model, train_loader, val_loader, loss_fn, opti, scheduler, epochs, combo=combo)
else:
    t1, t2, t3, t4, t5 = train_model(model, train_loader, test_loader, loss_fn, opti, scheduler, epochs, combo=combo)

plot_training_results(t1, t2, t3, t4, t5, plot_figure_name)
# Out:
# Epoch 1/200 - Train loss: 0.5224 - Val loss: 0.3189 - Train acc: 87.21% - Val acc: 92.37% - Test F1-score: 55.83
# Elapsed time: 23.71 seconds
# Epoch 2/200 - Train loss: 0.2840 - Val loss: 0.2786 - Train acc: 93.01% - Val acc: 93.16% - Test F1-score: 63.24
# Elapsed time: 22.62 seconds
# Epoch 3/200 - Train loss: 0.2460 - Val loss: 0.2484 - Train acc: 93.84% - Val acc: 93.80% - Test F1-score: 67.48
# Elapsed time: 22.15 seconds
# Epoch 4/200 - Train loss: 0.2252 - Val loss: 0.2344 - Train acc: 94.30% - Val acc: 94.17% - Test F1-score: 68.88
# Elapsed time: 22.13 seconds
# Epoch 5/200 - Train loss: 0.2108 - Val loss: 0.2298 - Train acc: 94.71% - Val acc: 94.47% - Test F1-score: 70.75
# Elapsed time: 22.23 seconds
# Epoch 6/200 - Train loss: 0.1997 - Val loss: 0.2445 - Train acc: 94.98% - Val acc: 93.68% - Test F1-score: 68.49
# Elapsed time: 22.20 seconds
# Epoch 7/200 - Train loss: 0.1919 - Val loss: 0.2104 - Train acc: 95.19% - Val acc: 95.12% - Test F1-score: 73.73
# Elapsed time: 22.11 seconds
# Epoch 8/200 - Train loss: 0.1854 - Val loss: 0.2055 - Train acc: 95.34% - Val acc: 95.18% - Test F1-score: 73.45
# Elapsed time: 21.97 seconds
# Epoch 9/200 - Train loss: 0.1802 - Val loss: 0.2060 - Train acc: 95.51% - Val acc: 95.33% - Test F1-score: 74.99
# Elapsed time: 22.37 seconds
# Epoch 10/200 - Train loss: 0.1744 - Val loss: 0.1970 - Train acc: 95.61% - Val acc: 95.30% - Test F1-score: 75.43
# Elapsed time: 22.20 seconds
# Epoch 11/200 - Train loss: 0.1709 - Val loss: 0.1980 - Train acc: 95.70% - Val acc: 95.10% - Test F1-score: 75.04
# Elapsed time: 22.24 seconds
# Epoch 12/200 - Train loss: 0.1668 - Val loss: 0.2079 - Train acc: 95.84% - Val acc: 94.92% - Test F1-score: 72.77
# Elapsed time: 22.22 seconds
# Epoch 13/200 - Train loss: 0.1654 - Val loss: 0.2066 - Train acc: 95.86% - Val acc: 95.22% - Test F1-score: 75.96
# Elapsed time: 22.31 seconds
# Epoch 14/200 - Train loss: 0.1611 - Val loss: 0.1926 - Train acc: 95.96% - Val acc: 95.55% - Test F1-score: 76.09
# Elapsed time: 22.12 seconds
# Epoch 15/200 - Train loss: 0.1586 - Val loss: 0.1922 - Train acc: 96.03% - Val acc: 95.48% - Test F1-score: 75.87
# Elapsed time: 22.09 seconds
# Epoch 16/200 - Train loss: 0.1564 - Val loss: 0.1901 - Train acc: 96.08% - Val acc: 95.43% - Test F1-score: 75.31
# Elapsed time: 22.23 seconds
# Epoch 17/200 - Train loss: 0.1529 - Val loss: 0.1910 - Train acc: 96.16% - Val acc: 95.59% - Test F1-score: 76.27
# Elapsed time: 22.30 seconds
# Epoch 18/200 - Train loss: 0.1515 - Val loss: 0.1963 - Train acc: 96.21% - Val acc: 95.31% - Test F1-score: 75.41
# Elapsed time: 22.24 seconds
# Epoch 19/200 - Train loss: 0.1502 - Val loss: 0.1918 - Train acc: 96.26% - Val acc: 95.55% - Test F1-score: 77.01
# Elapsed time: 22.16 seconds
# Epoch 20/200 - Train loss: 0.1478 - Val loss: 0.1896 - Train acc: 96.24% - Val acc: 95.35% - Test F1-score: 77.14
# Elapsed time: 22.43 seconds
# Epoch 21/200 - Train loss: 0.1466 - Val loss: 0.1881 - Train acc: 96.34% - Val acc: 95.75% - Test F1-score: 77.14
# Elapsed time: 22.21 seconds
# Epoch 22/200 - Train loss: 0.1450 - Val loss: 0.1832 - Train acc: 96.33% - Val acc: 95.79% - Test F1-score: 77.51
# Elapsed time: 22.19 seconds
# Epoch 23/200 - Train loss: 0.1430 - Val loss: 0.1874 - Train acc: 96.41% - Val acc: 95.73% - Test F1-score: 77.14
# Elapsed time: 22.24 seconds
# Epoch 24/200 - Train loss: 0.1418 - Val loss: 0.1833 - Train acc: 96.44% - Val acc: 95.70% - Test F1-score: 76.82
# Elapsed time: 22.27 seconds
# Epoch 25/200 - Train loss: 0.1399 - Val loss: 0.1823 - Train acc: 96.47% - Val acc: 95.75% - Test F1-score: 76.96
# Elapsed time: 22.05 seconds
# Epoch 26/200 - Train loss: 0.1396 - Val loss: 0.1836 - Train acc: 96.49% - Val acc: 95.76% - Test F1-score: 77.66
# Elapsed time: 22.22 seconds
# Epoch 27/200 - Train loss: 0.1380 - Val loss: 0.1852 - Train acc: 96.56% - Val acc: 95.69% - Test F1-score: 77.39
# Elapsed time: 22.35 seconds
# Epoch 28/200 - Train loss: 0.1369 - Val loss: 0.1849 - Train acc: 96.58% - Val acc: 95.82% - Test F1-score: 77.48
# Elapsed time: 22.40 seconds
# Epoch 29/200 - Train loss: 0.1360 - Val loss: 0.1853 - Train acc: 96.53% - Val acc: 95.78% - Test F1-score: 78.00
# Elapsed time: 22.27 seconds
# Epoch 30/200 - Train loss: 0.1353 - Val loss: 0.1829 - Train acc: 96.62% - Val acc: 95.71% - Test F1-score: 77.59
# Elapsed time: 22.22 seconds
# Epoch 31/200 - Train loss: 0.1346 - Val loss: 0.1811 - Train acc: 96.68% - Val acc: 95.80% - Test F1-score: 77.77
# Elapsed time: 22.38 seconds
# Epoch 32/200 - Train loss: 0.1334 - Val loss: 0.1851 - Train acc: 96.65% - Val acc: 95.69% - Test F1-score: 77.60
# Elapsed time: 22.24 seconds
# Epoch 33/200 - Train loss: 0.1323 - Val loss: 0.1871 - Train acc: 96.68% - Val acc: 95.61% - Test F1-score: 77.96
# Elapsed time: 22.28 seconds
# Epoch 34/200 - Train loss: 0.1317 - Val loss: 0.1909 - Train acc: 96.70% - Val acc: 95.73% - Test F1-score: 77.36
# Elapsed time: 22.28 seconds
# Epoch 35/200 - Train loss: 0.1315 - Val loss: 0.1812 - Train acc: 96.70% - Val acc: 95.79% - Test F1-score: 77.40
# Elapsed time: 22.20 seconds
# Epoch 36/200 - Train loss: 0.1305 - Val loss: 0.1826 - Train acc: 96.76% - Val acc: 95.69% - Test F1-score: 76.70
# Elapsed time: 21.98 seconds
# Epoch 37/200 - Train loss: 0.1299 - Val loss: 0.1811 - Train acc: 96.77% - Val acc: 95.82% - Test F1-score: 77.80
# Elapsed time: 22.26 seconds
# Epoch 38/200 - Train loss: 0.1286 - Val loss: 0.1825 - Train acc: 96.77% - Val acc: 95.74% - Test F1-score: 77.12
# Elapsed time: 22.23 seconds
# Epoch 39/200 - Train loss: 0.1286 - Val loss: 0.1826 - Train acc: 96.83% - Val acc: 95.65% - Test F1-score: 77.57
# Elapsed time: 22.31 seconds
# Epoch 40/200 - Train loss: 0.1280 - Val loss: 0.1876 - Train acc: 96.82% - Val acc: 95.73% - Test F1-score: 76.98
# Elapsed time: 22.09 seconds
# Epoch 41/200 - Train loss: 0.1275 - Val loss: 0.1811 - Train acc: 96.81% - Val acc: 95.85% - Test F1-score: 77.50
# Elapsed time: 22.11 seconds
# Epoch 42/200 - Train loss: 0.1266 - Val loss: 0.1821 - Train acc: 96.78% - Val acc: 95.76% - Test F1-score: 77.74
# Elapsed time: 22.19 seconds
# Epoch 43/200 - Train loss: 0.1268 - Val loss: 0.1804 - Train acc: 96.85% - Val acc: 95.88% - Test F1-score: 78.19
# Elapsed time: 22.16 seconds
# Epoch 44/200 - Train loss: 0.1263 - Val loss: 0.1839 - Train acc: 96.82% - Val acc: 95.62% - Test F1-score: 77.51
# Elapsed time: 22.29 seconds
# Epoch 45/200 - Train loss: 0.1252 - Val loss: 0.1846 - Train acc: 96.94% - Val acc: 95.57% - Test F1-score: 77.72
# Elapsed time: 22.27 seconds
# Epoch 46/200 - Train loss: 0.1249 - Val loss: 0.1846 - Train acc: 96.91% - Val acc: 95.72% - Test F1-score: 77.31
# Elapsed time: 22.19 seconds
# Epoch 47/200 - Train loss: 0.1246 - Val loss: 0.1860 - Train acc: 96.91% - Val acc: 95.66% - Test F1-score: 77.60
# Elapsed time: 22.06 seconds
# Epoch 48/200 - Train loss: 0.1240 - Val loss: 0.1824 - Train acc: 96.93% - Val acc: 95.76% - Test F1-score: 77.67
# Elapsed time: 22.26 seconds
# Epoch 49/200 - Train loss: 0.1241 - Val loss: 0.1816 - Train acc: 96.93% - Val acc: 95.85% - Test F1-score: 77.37
# Elapsed time: 22.28 seconds
# Epoch 50/200 - Train loss: 0.1235 - Val loss: 0.1840 - Train acc: 96.96% - Val acc: 95.76% - Test F1-score: 77.27
# Elapsed time: 22.14 seconds
# Epoch 51/200 - Train loss: 0.1236 - Val loss: 0.1823 - Train acc: 96.95% - Val acc: 95.85% - Test F1-score: 77.59
# Elapsed time: 22.22 seconds
# Epoch 52/200 - Train loss: 0.1229 - Val loss: 0.1818 - Train acc: 96.96% - Val acc: 95.86% - Test F1-score: 77.25
# Elapsed time: 22.04 seconds
# Epoch 53/200 - Train loss: 0.1226 - Val loss: 0.1810 - Train acc: 96.93% - Val acc: 95.83% - Test F1-score: 77.99
# Elapsed time: 22.20 seconds
# Epoch 54/200 - Train loss: 0.1225 - Val loss: 0.1817 - Train acc: 96.98% - Val acc: 95.84% - Test F1-score: 77.62
# Elapsed time: 22.32 seconds
# Epoch 55/200 - Train loss: 0.1222 - Val loss: 0.1835 - Train acc: 96.96% - Val acc: 95.80% - Test F1-score: 77.37
# Elapsed time: 22.28 seconds
# Epoch 56/200 - Train loss: 0.1218 - Val loss: 0.1826 - Train acc: 97.01% - Val acc: 95.72% - Test F1-score: 78.08
# Elapsed time: 22.25 seconds
# Epoch 57/200 - Train loss: 0.1214 - Val loss: 0.1823 - Train acc: 96.99% - Val acc: 95.86% - Test F1-score: 78.16
# Elapsed time: 22.21 seconds
# Epoch 58/200 - Train loss: 0.1214 - Val loss: 0.1825 - Train acc: 96.98% - Val acc: 95.65% - Test F1-score: 77.53
# Elapsed time: 22.16 seconds
# Epoch 59/200 - Train loss: 0.1214 - Val loss: 0.1823 - Train acc: 96.99% - Val acc: 95.84% - Test F1-score: 78.41
# Elapsed time: 22.39 seconds
# Epoch 60/200 - Train loss: 0.1211 - Val loss: 0.1818 - Train acc: 97.00% - Val acc: 95.86% - Test F1-score: 78.06
# Elapsed time: 22.31 seconds
# Epoch 61/200 - Train loss: 0.1211 - Val loss: 0.1819 - Train acc: 97.00% - Val acc: 95.76% - Test F1-score: 78.05
# Elapsed time: 22.33 seconds
# Epoch 62/200 - Train loss: 0.1208 - Val loss: 0.1836 - Train acc: 97.02% - Val acc: 95.80% - Test F1-score: 77.36
# Elapsed time: 22.27 seconds
# Epoch 63/200 - Train loss: 0.1204 - Val loss: 0.1819 - Train acc: 97.05% - Val acc: 95.90% - Test F1-score: 77.79
# Elapsed time: 22.12 seconds
# Epoch 64/200 - Train loss: 0.1200 - Val loss: 0.1825 - Train acc: 97.01% - Val acc: 95.84% - Test F1-score: 78.10
# Elapsed time: 22.25 seconds
# Epoch 65/200 - Train loss: 0.1199 - Val loss: 0.1825 - Train acc: 97.06% - Val acc: 95.78% - Test F1-score: 77.56
# Elapsed time: 22.36 seconds
# Epoch 66/200 - Train loss: 0.1201 - Val loss: 0.1824 - Train acc: 97.07% - Val acc: 95.78% - Test F1-score: 77.65
# Elapsed time: 22.42 seconds
# Epoch 67/200 - Train loss: 0.1200 - Val loss: 0.1822 - Train acc: 97.03% - Val acc: 95.78% - Test F1-score: 77.50
# Elapsed time: 22.25 seconds
# Epoch 68/200 - Train loss: 0.1195 - Val loss: 0.1819 - Train acc: 97.07% - Val acc: 95.82% - Test F1-score: 77.94
# Elapsed time: 22.35 seconds
# Epoch 69/200 - Train loss: 0.1199 - Val loss: 0.1825 - Train acc: 97.04% - Val acc: 95.82% - Test F1-score: 77.87
# Elapsed time: 22.11 seconds
# Epoch 70/200 - Train loss: 0.1192 - Val loss: 0.1823 - Train acc: 97.06% - Val acc: 95.79% - Test F1-score: 77.73
# Elapsed time: 22.18 seconds
# Epoch 71/200 - Train loss: 0.1191 - Val loss: 0.1827 - Train acc: 97.05% - Val acc: 95.82% - Test F1-score: 77.94
# Elapsed time: 22.19 seconds
# Epoch 72/200 - Train loss: 0.1189 - Val loss: 0.1823 - Train acc: 97.08% - Val acc: 95.81% - Test F1-score: 77.91
# Elapsed time: 22.30 seconds
# Epoch 73/200 - Train loss: 0.1188 - Val loss: 0.1826 - Train acc: 97.07% - Val acc: 95.84% - Test F1-score: 77.99
# Elapsed time: 22.48 seconds
# Epoch 74/200 - Train loss: 0.1187 - Val loss: 0.1826 - Train acc: 97.06% - Val acc: 95.81% - Test F1-score: 77.91
# Elapsed time: 22.09 seconds
# Epoch 75/200 - Train loss: 0.1187 - Val loss: 0.1822 - Train acc: 97.04% - Val acc: 95.84% - Test F1-score: 78.36
# Elapsed time: 22.35 seconds
# Epoch 76/200 - Train loss: 0.1185 - Val loss: 0.1828 - Train acc: 97.08% - Val acc: 95.88% - Test F1-score: 77.95
# Elapsed time: 22.29 seconds
# Epoch 77/200 - Train loss: 0.1189 - Val loss: 0.1820 - Train acc: 97.07% - Val acc: 95.81% - Test F1-score: 77.90
# Elapsed time: 22.23 seconds
# Epoch 78/200 - Train loss: 0.1184 - Val loss: 0.1825 - Train acc: 97.07% - Val acc: 95.81% - Test F1-score: 77.77
# Elapsed time: 22.20 seconds
# Epoch 79/200 - Train loss: 0.1185 - Val loss: 0.1830 - Train acc: 97.06% - Val acc: 95.82% - Test F1-score: 78.11
# Elapsed time: 22.34 seconds
# Epoch 80/200 - Train loss: 0.1182 - Val loss: 0.1827 - Train acc: 97.08% - Val acc: 95.84% - Test F1-score: 78.05
# Elapsed time: 22.04 seconds
# Epoch 81/200 - Train loss: 0.1179 - Val loss: 0.1830 - Train acc: 97.09% - Val acc: 95.82% - Test F1-score: 78.00
# Elapsed time: 22.24 seconds
# Epoch 82/200 - Train loss: 0.1178 - Val loss: 0.1830 - Train acc: 97.11% - Val acc: 95.79% - Test F1-score: 77.95
# Elapsed time: 22.27 seconds
# Epoch 83/200 - Train loss: 0.1181 - Val loss: 0.1831 - Train acc: 97.12% - Val acc: 95.79% - Test F1-score: 77.79
# Elapsed time: 22.28 seconds
# Epoch 84/200 - Train loss: 0.1178 - Val loss: 0.1831 - Train acc: 97.09% - Val acc: 95.75% - Test F1-score: 77.75
# Elapsed time: 22.29 seconds
# Epoch 85/200 - Train loss: 0.1179 - Val loss: 0.1865 - Train acc: 97.10% - Val acc: 95.76% - Test F1-score: 77.84
# Elapsed time: 22.22 seconds
# Epoch 86/200 - Train loss: 0.1176 - Val loss: 0.1831 - Train acc: 97.12% - Val acc: 95.79% - Test F1-score: 77.83
# Elapsed time: 22.21 seconds
# Epoch 87/200 - Train loss: 0.1183 - Val loss: 0.1832 - Train acc: 97.06% - Val acc: 95.80% - Test F1-score: 77.77
# Elapsed time: 22.23 seconds
# Epoch 88/200 - Train loss: 0.1179 - Val loss: 0.1829 - Train acc: 97.10% - Val acc: 95.84% - Test F1-score: 77.97
# Elapsed time: 22.30 seconds
# Epoch 89/200 - Train loss: 0.1174 - Val loss: 0.1833 - Train acc: 97.09% - Val acc: 95.78% - Test F1-score: 78.03
# Elapsed time: 22.43 seconds
# Epoch 90/200 - Train loss: 0.1174 - Val loss: 0.1829 - Train acc: 97.11% - Val acc: 95.81% - Test F1-score: 78.14
# Elapsed time: 22.31 seconds
# Epoch 91/200 - Train loss: 0.1176 - Val loss: 0.1831 - Train acc: 97.12% - Val acc: 95.79% - Test F1-score: 77.74
# Elapsed time: 22.02 seconds
# Epoch 92/200 - Train loss: 0.1174 - Val loss: 0.1828 - Train acc: 97.12% - Val acc: 95.79% - Test F1-score: 77.93
# Elapsed time: 22.31 seconds
# Epoch 93/200 - Train loss: 0.1174 - Val loss: 0.1851 - Train acc: 97.08% - Val acc: 95.73% - Test F1-score: 77.99
# Elapsed time: 22.32 seconds
# Epoch 94/200 - Train loss: 0.1176 - Val loss: 0.1834 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.70
# Elapsed time: 22.29 seconds
# Epoch 95/200 - Train loss: 0.1171 - Val loss: 0.1829 - Train acc: 97.12% - Val acc: 95.82% - Test F1-score: 77.90
# Elapsed time: 22.38 seconds
# Epoch 96/200 - Train loss: 0.1172 - Val loss: 0.1829 - Train acc: 97.10% - Val acc: 95.78% - Test F1-score: 77.77
# Elapsed time: 22.14 seconds
# Epoch 97/200 - Train loss: 0.1170 - Val loss: 0.1834 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.85
# Elapsed time: 22.29 seconds
# Epoch 98/200 - Train loss: 0.1173 - Val loss: 0.1830 - Train acc: 97.11% - Val acc: 95.76% - Test F1-score: 77.91
# Elapsed time: 22.41 seconds
# Epoch 99/200 - Train loss: 0.1170 - Val loss: 0.1832 - Train acc: 97.14% - Val acc: 95.81% - Test F1-score: 77.89
# Elapsed time: 22.18 seconds
# Epoch 100/200 - Train loss: 0.1173 - Val loss: 0.1830 - Train acc: 97.15% - Val acc: 95.79% - Test F1-score: 77.83
# Elapsed time: 22.38 seconds
# Epoch 101/200 - Train loss: 0.1173 - Val loss: 0.1830 - Train acc: 97.10% - Val acc: 95.84% - Test F1-score: 77.94
# Elapsed time: 22.38 seconds
# Epoch 102/200 - Train loss: 0.1170 - Val loss: 0.1823 - Train acc: 97.14% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 21.91 seconds
# Epoch 103/200 - Train loss: 0.1172 - Val loss: 0.1831 - Train acc: 97.11% - Val acc: 95.83% - Test F1-score: 77.77
# Elapsed time: 22.42 seconds
# Epoch 104/200 - Train loss: 0.1171 - Val loss: 0.1831 - Train acc: 97.14% - Val acc: 95.79% - Test F1-score: 77.84
# Elapsed time: 22.23 seconds
# Epoch 105/200 - Train loss: 0.1176 - Val loss: 0.1835 - Train acc: 97.11% - Val acc: 95.73% - Test F1-score: 77.88
# Elapsed time: 22.17 seconds
# Epoch 106/200 - Train loss: 0.1168 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.78% - Test F1-score: 77.84
# Elapsed time: 22.21 seconds
# Epoch 107/200 - Train loss: 0.1171 - Val loss: 0.1841 - Train acc: 97.12% - Val acc: 95.72% - Test F1-score: 77.88
# Elapsed time: 22.13 seconds
# Epoch 108/200 - Train loss: 0.1167 - Val loss: 0.1833 - Train acc: 97.14% - Val acc: 95.78% - Test F1-score: 78.15
# Elapsed time: 22.25 seconds
# Epoch 109/200 - Train loss: 0.1169 - Val loss: 0.1826 - Train acc: 97.16% - Val acc: 95.85% - Test F1-score: 78.00
# Elapsed time: 22.23 seconds
# Epoch 110/200 - Train loss: 0.1169 - Val loss: 0.1832 - Train acc: 97.13% - Val acc: 95.80% - Test F1-score: 77.95
# Elapsed time: 22.27 seconds
# Epoch 111/200 - Train loss: 0.1173 - Val loss: 0.1838 - Train acc: 97.11% - Val acc: 95.75% - Test F1-score: 77.98
# Elapsed time: 22.26 seconds
# Epoch 112/200 - Train loss: 0.1169 - Val loss: 0.1827 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 77.84
# Elapsed time: 22.53 seconds
# Epoch 113/200 - Train loss: 0.1167 - Val loss: 0.1828 - Train acc: 97.14% - Val acc: 95.80% - Test F1-score: 77.87
# Elapsed time: 22.92 seconds
# Epoch 114/200 - Train loss: 0.1168 - Val loss: 0.1844 - Train acc: 97.13% - Val acc: 95.75% - Test F1-score: 77.92
# Elapsed time: 22.26 seconds
# Epoch 115/200 - Train loss: 0.1167 - Val loss: 0.1833 - Train acc: 97.14% - Val acc: 95.82% - Test F1-score: 77.99
# Elapsed time: 22.33 seconds
# Epoch 116/200 - Train loss: 0.1168 - Val loss: 0.1829 - Train acc: 97.15% - Val acc: 95.82% - Test F1-score: 78.20
# Elapsed time: 22.33 seconds
# Epoch 117/200 - Train loss: 0.1171 - Val loss: 0.1837 - Train acc: 97.11% - Val acc: 95.75% - Test F1-score: 77.95
# Elapsed time: 22.52 seconds
# Epoch 118/200 - Train loss: 0.1170 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 78.06
# Elapsed time: 22.16 seconds
# Epoch 119/200 - Train loss: 0.1168 - Val loss: 0.1832 - Train acc: 97.12% - Val acc: 95.79% - Test F1-score: 77.82
# Elapsed time: 22.40 seconds
# Epoch 120/200 - Train loss: 0.1167 - Val loss: 0.1831 - Train acc: 97.15% - Val acc: 95.83% - Test F1-score: 78.00
# Elapsed time: 22.29 seconds
# Epoch 121/200 - Train loss: 0.1169 - Val loss: 0.1830 - Train acc: 97.12% - Val acc: 95.80% - Test F1-score: 77.99
# Elapsed time: 22.36 seconds
# Epoch 122/200 - Train loss: 0.1170 - Val loss: 0.1831 - Train acc: 97.14% - Val acc: 95.84% - Test F1-score: 77.96
# Elapsed time: 22.38 seconds
# Epoch 123/200 - Train loss: 0.1169 - Val loss: 0.1826 - Train acc: 97.13% - Val acc: 95.79% - Test F1-score: 77.85
# Elapsed time: 22.23 seconds
# Epoch 124/200 - Train loss: 0.1169 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 22.18 seconds
# Epoch 125/200 - Train loss: 0.1166 - Val loss: 0.1829 - Train acc: 97.14% - Val acc: 95.82% - Test F1-score: 77.94
# Elapsed time: 22.45 seconds
# Epoch 126/200 - Train loss: 0.1168 - Val loss: 0.1832 - Train acc: 97.13% - Val acc: 95.84% - Test F1-score: 77.95
# Elapsed time: 22.33 seconds
# Epoch 127/200 - Train loss: 0.1169 - Val loss: 0.1834 - Train acc: 97.11% - Val acc: 95.82% - Test F1-score: 77.91
# Elapsed time: 22.31 seconds
# Epoch 128/200 - Train loss: 0.1170 - Val loss: 0.1833 - Train acc: 97.12% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 22.39 seconds
# Epoch 129/200 - Train loss: 0.1167 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 78.06
# Elapsed time: 22.09 seconds
# Epoch 130/200 - Train loss: 0.1167 - Val loss: 0.1836 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.89
# Elapsed time: 22.26 seconds
# Epoch 131/200 - Train loss: 0.1167 - Val loss: 0.1836 - Train acc: 97.14% - Val acc: 95.83% - Test F1-score: 78.26
# Elapsed time: 22.34 seconds
# Epoch 132/200 - Train loss: 0.1167 - Val loss: 0.1852 - Train acc: 97.13% - Val acc: 95.75% - Test F1-score: 77.91
# Elapsed time: 22.26 seconds
# Epoch 133/200 - Train loss: 0.1170 - Val loss: 0.1830 - Train acc: 97.13% - Val acc: 95.85% - Test F1-score: 78.02
# Elapsed time: 22.31 seconds
# Epoch 134/200 - Train loss: 0.1165 - Val loss: 0.1833 - Train acc: 97.12% - Val acc: 95.82% - Test F1-score: 77.98
# Elapsed time: 22.29 seconds
# Epoch 135/200 - Train loss: 0.1165 - Val loss: 0.1830 - Train acc: 97.15% - Val acc: 95.84% - Test F1-score: 77.99
# Elapsed time: 22.08 seconds
# Epoch 136/200 - Train loss: 0.1167 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.85% - Test F1-score: 78.02
# Elapsed time: 22.29 seconds
# Epoch 137/200 - Train loss: 0.1171 - Val loss: 0.1835 - Train acc: 97.13% - Val acc: 95.80% - Test F1-score: 77.96
# Elapsed time: 22.25 seconds
# Epoch 138/200 - Train loss: 0.1167 - Val loss: 0.1825 - Train acc: 97.15% - Val acc: 95.81% - Test F1-score: 77.91
# Elapsed time: 22.38 seconds
# Epoch 139/200 - Train loss: 0.1169 - Val loss: 0.1828 - Train acc: 97.12% - Val acc: 95.85% - Test F1-score: 77.96
# Elapsed time: 22.36 seconds
# Epoch 140/200 - Train loss: 0.1168 - Val loss: 0.1834 - Train acc: 97.13% - Val acc: 95.83% - Test F1-score: 78.11
# Elapsed time: 22.06 seconds
# Epoch 141/200 - Train loss: 0.1170 - Val loss: 0.1834 - Train acc: 97.15% - Val acc: 95.81% - Test F1-score: 78.07
# Elapsed time: 22.26 seconds
# Epoch 142/200 - Train loss: 0.1171 - Val loss: 0.1826 - Train acc: 97.12% - Val acc: 95.85% - Test F1-score: 78.04
# Elapsed time: 22.34 seconds
# Epoch 143/200 - Train loss: 0.1166 - Val loss: 0.1832 - Train acc: 97.10% - Val acc: 95.82% - Test F1-score: 77.93
# Elapsed time: 22.28 seconds
# Epoch 144/200 - Train loss: 0.1167 - Val loss: 0.1830 - Train acc: 97.13% - Val acc: 95.79% - Test F1-score: 77.78
# Elapsed time: 22.25 seconds
# Epoch 145/200 - Train loss: 0.1166 - Val loss: 0.1838 - Train acc: 97.12% - Val acc: 95.80% - Test F1-score: 78.04
# Elapsed time: 22.37 seconds
# Epoch 146/200 - Train loss: 0.1167 - Val loss: 0.1832 - Train acc: 97.12% - Val acc: 95.83% - Test F1-score: 77.93
# Elapsed time: 22.17 seconds
# Epoch 147/200 - Train loss: 0.1167 - Val loss: 0.1831 - Train acc: 97.17% - Val acc: 95.84% - Test F1-score: 78.00
# Elapsed time: 22.15 seconds
# Epoch 148/200 - Train loss: 0.1164 - Val loss: 0.1834 - Train acc: 97.16% - Val acc: 95.84% - Test F1-score: 78.01
# Elapsed time: 22.37 seconds
# Epoch 149/200 - Train loss: 0.1165 - Val loss: 0.1829 - Train acc: 97.12% - Val acc: 95.84% - Test F1-score: 77.98
# Elapsed time: 22.35 seconds
# Epoch 150/200 - Train loss: 0.1167 - Val loss: 0.1831 - Train acc: 97.12% - Val acc: 95.82% - Test F1-score: 77.93
# Elapsed time: 22.22 seconds
# Epoch 151/200 - Train loss: 0.1164 - Val loss: 0.1830 - Train acc: 97.12% - Val acc: 95.84% - Test F1-score: 77.98
# Elapsed time: 22.06 seconds
# Epoch 152/200 - Train loss: 0.1165 - Val loss: 0.1827 - Train acc: 97.14% - Val acc: 95.84% - Test F1-score: 77.99
# Elapsed time: 22.35 seconds
# Epoch 153/200 - Train loss: 0.1163 - Val loss: 0.1851 - Train acc: 97.14% - Val acc: 95.80% - Test F1-score: 78.05
# Elapsed time: 22.20 seconds
# Epoch 154/200 - Train loss: 0.1165 - Val loss: 0.1832 - Train acc: 97.14% - Val acc: 95.84% - Test F1-score: 77.97
# Elapsed time: 22.32 seconds
# Epoch 155/200 - Train loss: 0.1165 - Val loss: 0.1849 - Train acc: 97.14% - Val acc: 95.76% - Test F1-score: 77.95
# Elapsed time: 22.31 seconds
# Epoch 156/200 - Train loss: 0.1166 - Val loss: 0.1857 - Train acc: 97.13% - Val acc: 95.75% - Test F1-score: 77.96
# Elapsed time: 22.25 seconds
# Epoch 157/200 - Train loss: 0.1165 - Val loss: 0.1835 - Train acc: 97.13% - Val acc: 95.75% - Test F1-score: 77.93
# Elapsed time: 22.23 seconds
# Epoch 158/200 - Train loss: 0.1168 - Val loss: 0.1838 - Train acc: 97.09% - Val acc: 95.85% - Test F1-score: 77.99
# Elapsed time: 22.17 seconds
# Epoch 159/200 - Train loss: 0.1165 - Val loss: 0.1841 - Train acc: 97.12% - Val acc: 95.75% - Test F1-score: 77.93
# Elapsed time: 22.40 seconds
# Epoch 160/200 - Train loss: 0.1168 - Val loss: 0.1832 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 78.26
# Elapsed time: 22.32 seconds
# Epoch 161/200 - Train loss: 0.1164 - Val loss: 0.1830 - Train acc: 97.13% - Val acc: 95.85% - Test F1-score: 77.98
# Elapsed time: 22.15 seconds
# Epoch 162/200 - Train loss: 0.1164 - Val loss: 0.1848 - Train acc: 97.14% - Val acc: 95.77% - Test F1-score: 77.98
# Elapsed time: 22.15 seconds
# Epoch 163/200 - Train loss: 0.1165 - Val loss: 0.1837 - Train acc: 97.16% - Val acc: 95.81% - Test F1-score: 78.11
# Elapsed time: 22.26 seconds
# Epoch 164/200 - Train loss: 0.1165 - Val loss: 0.1834 - Train acc: 97.17% - Val acc: 95.83% - Test F1-score: 77.97
# Elapsed time: 22.30 seconds
# Epoch 165/200 - Train loss: 0.1165 - Val loss: 0.1837 - Train acc: 97.17% - Val acc: 95.82% - Test F1-score: 77.94
# Elapsed time: 22.23 seconds
# Epoch 166/200 - Train loss: 0.1165 - Val loss: 0.1832 - Train acc: 97.17% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 22.31 seconds
# Epoch 167/200 - Train loss: 0.1164 - Val loss: 0.1858 - Train acc: 97.11% - Val acc: 95.69% - Test F1-score: 77.97
# Elapsed time: 22.29 seconds
# Epoch 168/200 - Train loss: 0.1165 - Val loss: 0.1835 - Train acc: 97.12% - Val acc: 95.84% - Test F1-score: 78.02
# Elapsed time: 21.99 seconds
# Epoch 169/200 - Train loss: 0.1166 - Val loss: 0.1832 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 77.94
# Elapsed time: 22.29 seconds
# Epoch 170/200 - Train loss: 0.1165 - Val loss: 0.1828 - Train acc: 97.17% - Val acc: 95.84% - Test F1-score: 77.96
# Elapsed time: 22.29 seconds
# Epoch 171/200 - Train loss: 0.1166 - Val loss: 0.1831 - Train acc: 97.09% - Val acc: 95.85% - Test F1-score: 78.02
# Elapsed time: 22.21 seconds
# Epoch 172/200 - Train loss: 0.1165 - Val loss: 0.1835 - Train acc: 97.15% - Val acc: 95.82% - Test F1-score: 77.97
# Elapsed time: 22.19 seconds
# Epoch 173/200 - Train loss: 0.1165 - Val loss: 0.1836 - Train acc: 97.12% - Val acc: 95.84% - Test F1-score: 77.94
# Elapsed time: 22.26 seconds
# Epoch 174/200 - Train loss: 0.1171 - Val loss: 0.1831 - Train acc: 97.12% - Val acc: 95.84% - Test F1-score: 78.02
# Elapsed time: 22.33 seconds
# Epoch 175/200 - Train loss: 0.1163 - Val loss: 0.1830 - Train acc: 97.15% - Val acc: 95.82% - Test F1-score: 77.95
# Elapsed time: 22.22 seconds
# Epoch 176/200 - Train loss: 0.1166 - Val loss: 0.1835 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 77.87
# Elapsed time: 22.34 seconds
# Epoch 177/200 - Train loss: 0.1164 - Val loss: 0.1830 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 22.17 seconds
# Epoch 178/200 - Train loss: 0.1166 - Val loss: 0.1829 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.90
# Elapsed time: 22.28 seconds
# Epoch 179/200 - Train loss: 0.1164 - Val loss: 0.1840 - Train acc: 97.16% - Val acc: 95.85% - Test F1-score: 78.31
# Elapsed time: 21.94 seconds
# Epoch 180/200 - Train loss: 0.1166 - Val loss: 0.1831 - Train acc: 97.15% - Val acc: 95.84% - Test F1-score: 77.99
# Elapsed time: 22.09 seconds
# Epoch 181/200 - Train loss: 0.1164 - Val loss: 0.1829 - Train acc: 97.14% - Val acc: 95.83% - Test F1-score: 77.96
# Elapsed time: 22.22 seconds
# Epoch 182/200 - Train loss: 0.1164 - Val loss: 0.1827 - Train acc: 97.15% - Val acc: 95.84% - Test F1-score: 77.96
# Elapsed time: 22.22 seconds
# Epoch 183/200 - Train loss: 0.1164 - Val loss: 0.1830 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 78.08
# Elapsed time: 22.33 seconds
# Epoch 184/200 - Train loss: 0.1163 - Val loss: 0.1889 - Train acc: 97.14% - Val acc: 95.77% - Test F1-score: 78.00
# Elapsed time: 22.15 seconds
# Epoch 185/200 - Train loss: 0.1164 - Val loss: 0.1867 - Train acc: 97.14% - Val acc: 95.75% - Test F1-score: 77.98
# Elapsed time: 22.32 seconds
# Epoch 186/200 - Train loss: 0.1164 - Val loss: 0.1832 - Train acc: 97.16% - Val acc: 95.79% - Test F1-score: 77.93
# Elapsed time: 22.12 seconds
# Epoch 187/200 - Train loss: 0.1165 - Val loss: 0.1830 - Train acc: 97.15% - Val acc: 95.82% - Test F1-score: 77.92
# Elapsed time: 22.62 seconds
# Epoch 188/200 - Train loss: 0.1167 - Val loss: 0.1832 - Train acc: 97.15% - Val acc: 95.84% - Test F1-score: 77.97
# Elapsed time: 22.28 seconds
# Epoch 189/200 - Train loss: 0.1167 - Val loss: 0.1833 - Train acc: 97.15% - Val acc: 95.84% - Test F1-score: 77.96
# Elapsed time: 21.91 seconds
# Epoch 190/200 - Train loss: 0.1162 - Val loss: 0.1831 - Train acc: 97.15% - Val acc: 95.85% - Test F1-score: 78.00
# Elapsed time: 21.93 seconds
# Epoch 191/200 - Train loss: 0.1166 - Val loss: 0.1834 - Train acc: 97.12% - Val acc: 95.80% - Test F1-score: 77.82
# Elapsed time: 22.03 seconds
# Epoch 192/200 - Train loss: 0.1170 - Val loss: 0.1837 - Train acc: 97.13% - Val acc: 95.74% - Test F1-score: 77.94
# Elapsed time: 22.03 seconds
# Epoch 193/200 - Train loss: 0.1164 - Val loss: 0.1827 - Train acc: 97.13% - Val acc: 95.82% - Test F1-score: 77.91
# Elapsed time: 22.13 seconds
# Epoch 194/200 - Train loss: 0.1170 - Val loss: 0.1828 - Train acc: 97.15% - Val acc: 95.81% - Test F1-score: 77.92
# Elapsed time: 21.71 seconds
# Epoch 195/200 - Train loss: 0.1163 - Val loss: 0.1833 - Train acc: 97.16% - Val acc: 95.82% - Test F1-score: 77.93
# Elapsed time: 21.22 seconds
# Epoch 196/200 - Train loss: 0.1166 - Val loss: 0.1828 - Train acc: 97.16% - Val acc: 95.83% - Test F1-score: 77.91
# Elapsed time: 21.24 seconds
# Epoch 197/200 - Train loss: 0.1164 - Val loss: 0.1832 - Train acc: 97.18% - Val acc: 95.85% - Test F1-score: 77.97
# Elapsed time: 21.78 seconds
# Epoch 198/200 - Train loss: 0.1169 - Val loss: 0.1838 - Train acc: 97.11% - Val acc: 95.84% - Test F1-score: 77.95
# Elapsed time: 21.85 seconds
# Epoch 199/200 - Train loss: 0.1168 - Val loss: 0.1846 - Train acc: 97.12% - Val acc: 95.75% - Test F1-score: 78.11
# Elapsed time: 21.83 seconds
# Epoch 200/200 - Train loss: 0.1164 - Val loss: 0.1836 - Train acc: 97.14% - Val acc: 95.85% - Test F1-score: 78.00
# Elapsed time: 21.49 seconds
# Figure saved as training_validation_results_temp_bsm_mm_018.png

# %%
# %matplotlib inline

evaluate_model(model, test_loader, loss_fn, model_name, figure_name, combo=combo)
# Out:
# Validation loss: 0.1907
# Validation accuracy: 95.97%
# Model saved as model_temp_bsm_mm_018.ckpt
#                   precision    recall  f1-score   support
#
#             corn       0.98      0.98      0.98      3818
#       horsebeans       0.75      0.77      0.76        92
#           meadow       0.99      0.99      0.99     10508
#    spring_barley       0.64      0.55      0.59        78
#      spring_peas       0.73      0.75      0.74        55
#       sunflowers       0.90      0.86      0.88       254
#    winter_barley       0.90      0.91      0.91       817
#       winter_oat       0.40      0.16      0.23        87
#  winter_rapeseed       0.98      0.95      0.97       762
# winter_triticale       0.73      0.59      0.66       537
#     winter_wheat       0.93      0.96      0.94      4198
#
#         accuracy                           0.96     21206
#        macro avg       0.81      0.77      0.79     21206
#     weighted avg       0.96      0.96      0.96     21206
# Figure saved as CM_temp_bsm_mm_018.png
# 95.97181338992333

# %%
# %matplotlib inline

targets, outputs = gen_features(model,test_loader, combo =combo, linear_classif= linear_classif)
tsne_plot(tsne_fig_name,targets, outputs)
# Out:
# 10 / 332
# 20 / 332
# 30 / 332
# 40 / 332
# 50 / 332
# 60 / 332
# 70 / 332
# 80 / 332
# 90 / 332
# 100 / 332
# 110 / 332
# 120 / 332
# 130 / 332
# 140 / 332
# 150 / 332
# 160 / 332
# 170 / 332
# 180 / 332
# 190 / 332
# 200 / 332
# 210 / 332
# 220 / 332
# 230 / 332
# 240 / 332
# 250 / 332
# 260 / 332
# 270 / 332
# 280 / 332
# 290 / 332
# 300 / 332
# 310 / 332
# 320 / 332
# 330 / 332
# 332 / 332
# generating t-SNE plot...
# Figure saved as Tsne_temp_bsm_mm_018.png
# done!
