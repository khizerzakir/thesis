# %%
import subprocess
import sys
sys.path.insert(0,'..')
from pathlib import Path
import os
import random

import torch
import torch.nn as nn
from torch.nn.functional import one_hot
from torch import Tensor
from typing import Union

import matplotlib.pylab as plt

import time
import numpy as np
import torch as th
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler

from focal_loss import FocalLoss
from utils import _axat, _atxa, _mvmt
import seaborn as sns


def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package],
                         stdout=subprocess.DEVNULL,
                         stderr=subprocess.DEVNULL
                         )
required_packages = [
    "geoopt",
    "pyriemann",
]
for package in required_packages:
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"{package} is not installed. Installing...")
        install(package)

import geoopt
from pyriemann.utils.covariance import covariances, normalize


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.manifold import TSNE
import pandas as pd


use_cuda = th.cuda.is_available()
device = th.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# geoopt is already installed.
# pyriemann is already installed.
# cuda:0

# %% [markdown]
# ## Defining Flags and Variables

# %%
# Flags and Parameters
# root_dir = r"/kaggle/input/normalized-data"
# npz_file = "98_p_norm_data.npz"
root_dir = r'/kaggle/input/d/khizerzakir/bzh-data'
npz_file = 'bzh_data.npz'
folder_name = "mm_bzh_001"
os.makedirs(folder_name, exist_ok=True)
batch_size = 64  # batch size
n_classes = 7
random_seed = 42
test_size = 0.2
temp = False  # Whether the data is in temporal mode
val = True # Whether to create a validation loader
combo = False  # Whether the data is in combo mode

model_name = "model_Spec_bsm_mm_bzh_001"
figure_name = "CM_Spec_bsm_mm_bzh_001"
tsne_fig_name ="Tsne_Spec_bsm_mm_bzh_001"
plot_figure_name = "training_validation_results_Spec_bsm_mm_bzh_001"

# for model
lr=1e-2
epochs=200
gamma_value=0.95
loss = "focal"
gamma_loss = 2
step_size=30
step_lr = False
linear_classif = False

# %% [markdown]
# ## Model, Dataset, and Classifier definition

# %%
class BusemanSimilarityClassifier(nn.Module):
    def busemann_spd(self, logM):
        """
        Compute the Busemann similarity for Symmetric Positive Definite (SPD) matrices.
        
        :param logM: Logarithm of SPD matrices, shape (b, n, n)
        :return: Similarity scores, shape (b, n_proto)
        """
        return logM.reshape(logM.shape[0], -1) @ self.proto.reshape(self.proto.shape[0], -1).T
    def __init__(self,dim1,n_proto,n_classes,optim_proto=True):
        super().__init__()
        self.n_proto = n_proto
        self.n_classes = n_classes
        self.dim1 = dim1
        
        self.manifold = geoopt.Stiefel()

        # Random projection directions, shape (d-1, num_projections)
        theta = np.random.normal(size=(self.n_proto, self.dim1))
        theta = th.nn.functional.normalize(th.from_numpy(theta), p=2, dim=-1).type(th.float64).to(device)
        #self.D = theta[:,None] * th.eye(theta.shape[-1],dtype=th.float64, device=device)
        self.register_parameter("theta_proto", geoopt.ManifoldParameter(theta, geoopt.Sphere()))
        #self.theta_proto=theta

        ## Random orthogonal matrices
        Z = th.randn((self.n_proto, self.dim1, self.dim1), dtype=th.float64, device=device)
        self.Q = th.svd(Z)[0]
        self.manifold.assert_check_point_on_manifold(self.Q)
        self.register_parameter("Q_proto", geoopt.ManifoldParameter(self.Q, self.manifold))
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        # linear layer
        self.linear = nn.Linear(self.n_proto, self.n_classes).double()

    def forward(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        y = self.linear(self.busemann_spd(x))#.view(sim_embedding.shape[0], -1))
        return y
    
    def embed(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        return self.busemann_spd(x)

# %%
class LogEucRResNet(nn.Module):
    def __init__(self, inputdim=10, dim1=7, n_proto=8, classes=7, embed_only=False, linear_classif=False):
        super().__init__()
        self.inputdim = inputdim
        self.dim1 = dim1
        self.n_proto = n_proto
        self.classes = classes
        self.embed_only = embed_only
        self.linear_classif = linear_classif

        self.manifold_Stiefel = geoopt.Stiefel()
        self.manifold_SPD = geoopt.SymmetricPositiveDefinite("LEM")
        
        # init first bimap
        bm1 = th.randn((1, self.inputdim, self.dim1), dtype=th.float64)
        bm1 = th.svd(bm1)[0]
        self.register_parameter("bimap1", geoopt.ManifoldParameter(bm1, self.manifold_Stiefel))
        
        P = th.randn((1, self.dim1, self.dim1), dtype=th.float64)
        P = th.svd(P)[0]

        self.register_parameter("P1", geoopt.ManifoldParameter(P, self.manifold_Stiefel))

        self.classiflayer=BusemanSimilarityClassifier(self.dim1,self.n_proto, classes)
        self.fc_layer = nn.Linear(self.dim1 * self.dim1, self.classes).double()
        self.softmax =  nn.Softmax(dim=-1)

        self.spectrum_map = nn.Sequential(
            nn.Conv1d(1, 10, 5, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(10).double(),
            nn.Conv1d(10, 5, 3, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(5).double(),
            nn.Conv1d(5, 1, 3, padding="same").double(),
        )
        
    def forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs) # spectral map
        v1 = _mvmt(self.P1, f_eigs, self.P1)            
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)     
        x = log_x + v1
        if self.embed_only:
            return x.reshape(x.shape[0],-1)
        elif self.linear_classif:
            return self.softmax(self.fc_layer(x.reshape(x.shape[0],-1)))
        else:
            return self.softmax(self.classiflayer(x)) # Buseman Similarity Classifier when single modality is used
    def partial_forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs)
        v1 = _mvmt(self.P1, f_eigs, self.P1)
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)
        x = log_x + v1
        return self.classiflayer.embed(x)
            
class LogEucRResNet_Combo(nn.Module):
    def __init__(self, inputdim_temp=71, dim1_temp=50, inputdim_spec=10, dim1_spec=7, n_proto=8, classes=7, buseman_classif=True):
        super().__init__()
        self.classes = classes
        self.buseman_classif = buseman_classif
        self.model_temp = LogEucRResNet(inputdim_temp, dim1_temp, n_proto, embed_only=True)
        self.model_spectral = LogEucRResNet(inputdim_spec, dim1_spec, n_proto, embed_only=True)
        
        self.classiflayer = BusemanSimilarityClassifier(dim1_temp+1,n_proto,classes)
        self.fc_layer = nn.Linear(dim1_temp*dim1_temp+dim1_spec*dim1_spec,classes).double()        
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, x1, x2):
        out_1 = self.model_temp(x1) # probabilities
        out_2 = self.model_spectral(x2) # probabilities
        x = th.concat((out_1, out_2), dim=1)
        #print(x.shape)
        if self.buseman_classif:
            return self.softmax(self.classiflayer(x))
        else:
            return self.softmax(self.fc_layer(x))
        
    def partial_forward(self, x1, x2):
        out_1 = self.model_temp.partial_forward(x1)
        out_2 = self.model_spectral.partial_forward(x2)
        x = th.concat((out_1, out_2), dim=1)
        return self.classiflayer.embed(x)

# %%
class TS_COV(Dataset):
    def __init__(self, root_dir, np_file, estimator='scm', combo=True, temp=False):
        self.root_dir = root_dir
        self.np_file = np_file
        self.estimator = estimator
        self.combo = combo
        self.temp = temp
        self.x, self.y, self.class_names = self.load_data()
        #self.cov = normalize(self.calculate_covariances(),'corr')
        self.x1 = self.calculate_covariances_36()
        self.x2 = self.calculate_covariances_10()
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x1, x2= self.x1[idx], self.x2[idx]
        y_sample = self.y[idx]
        class_name = self.class_names[y_sample]
        x1 = th.from_numpy(np.asarray([x1])).double()
        x2 = th.from_numpy(np.asarray([x2])).double()
        x1,x2 = x1.reshape(1, 71, 71), x2.reshape(1, 10, 10)
        y = th.from_numpy(np.array(y_sample)).long()
        if self.combo:
            return x1,x2, y
        elif self.temp:
            return x1, y
        else:
            return x2, y

    def load_data(self):
        file_path = os.path.join(self.root_dir, self.np_file)
        data = np.load(file_path, allow_pickle= True)
        x = data['x']
        y = data['y']
        class_names = data['class_names']
        return x, y, class_names

    def calculate_covariances_10(self):
        x_transposed = np.transpose(self.x, (0, 2, 1))
        cov = covariances(x_transposed, estimator=self.estimator)
        return cov
    def calculate_covariances_36(self):
        cov = covariances(self.x, estimator=self.estimator)
        return cov

# %% [markdown]
# ## Helper functions

# %%
def initialize_model(combo=True, linear_classif=True, temp=False, device=device):
    if combo:
        if linear_classif:
            model = LogEucRResNet_Combo(buseman_classif=False).to(device)
            print("Combo model with linear classifier")
        else:
            model = LogEucRResNet_Combo(buseman_classif=True).to(device)
            print("Combo model with Buseman classifier")
    elif temp:
        if linear_classif:
            inputdim = 71
            dim1 = 50
            model = LogEucRResNet(inputdim, dim1, linear_classif=True).to(device)
            print("Single modality - Temp model with linear classifier")
        else:
            inputdim = 71
            dim1 = 50
            model = LogEucRResNet(inputdim, dim1, linear_classif=False).to(device)
            print("Single modality - Temp model with Buseman classifier")
    else:
        if linear_classif:
            inputdim = 10
            dim1 = 7
            model = LogEucRResNet(inputdim, dim1, linear_classif=True).to(device)
            print("Single modality - Spectral model with linear classifier")
        else:
            inputdim = 10
            dim1 = 7
            model = LogEucRResNet(inputdim, dim1, linear_classif=False).to(device)
            print("Single modality - Spectral model with Buseman classifier")

    # Get number of trainable parameters
    model.eval()
    trainable_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Trainable total parameters: {trainable_total_params}')
    return model

# calculate the weights for the classes
def calculate_class_weights(labels):
    class_sample_count = np.array([len(np.where(labels == t)[0]) for t in np.unique(labels)])
    weight = 1 - class_sample_count / len(labels)
    return th.from_numpy(weight).double()
# data loaders
def create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=True):
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(train_indices))
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(test_indices), shuffle=False)
    
    if val:
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(val_indices))
        return train_loader, val_loader, test_loader
    else:
        return train_loader, test_loader
    
# plotting data distribution
def plot_class_distribution(train_loader, val_loader, test_loader, n_classes, combo=False):
    class_names = train_loader.dataset.class_names
    
    def count_labels(loader, n_classes):
        counts = np.zeros(n_classes)
        for batch in loader:
            if combo:
                _, _, labels = batch  # x1, x2, labels
            else:
                _, labels = batch  # x, labels
            for l in labels:
                counts[l] += 1
        return counts

    train_counts = count_labels(train_loader, n_classes)
    
    if val_loader is not None:
        val_counts = count_labels(val_loader, n_classes)
    else:
        val_counts = np.zeros(n_classes)
    
    test_counts = count_labels(test_loader, n_classes)

    # Bar plot
    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes) - test_size, train_counts, 0.2, label='Train')
    if val_loader is not None:
        plt.bar(np.arange(n_classes), val_counts, 0.2, label='Validation')
    plt.bar(np.arange(n_classes) + 0.2, test_counts, 0.2, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes), train_counts, alpha=0.5, label='Train')
    plt.bar(np.arange(n_classes), val_counts, alpha=0.5, label='Validation')
    plt.bar(np.arange(n_classes), test_counts, alpha=0.5, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Histogram of Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Histogram of Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

# %%
def train_one_epoch(model, train_loader, loss_fn, optimizer, device, combo=False):
    model.train()
    loss_train, acc_train = [], []
    
    for batch in train_loader:
        if combo:
            x1, x2, y = batch
            x1 = x1.to(device)
            x2 = x2.to(device)
            inputs = (x1, x2)
        else:
            x, y = batch
            x = x.to(device)
            inputs = (x,)
        y = y.to(device).long()
        optimizer.zero_grad()
        
        # Forward pass
        out = model(*inputs)
        l = loss_fn(out, y)
        
        acc, loss = (out.argmax(1) == y).cpu().numpy().sum() / out.shape[0], l.cpu().data.numpy()
        loss_train.append(loss)
        acc_train.append(acc)
        l.backward()
        optimizer.step()

    acc_train = np.asarray(acc_train).mean()
    loss_train = np.asarray(loss_train).mean()
    
    return loss_train, acc_train

def validate_one_epoch(model, val_loader, loss_fn, device, combo=False):
    model.eval()
    loss_val, acc_val_list = [], []
    y_true, y_pred = [], []

    for batch in val_loader:
        if combo:
            x1, x2, y = batch
            x1 = x1.to(device)
            x2 = x2.to(device)
            inputs = (x1, x2)
        else:
            x, y = batch
            x = x.to(device)
            inputs = (x,)
        y = y.to(device).long()
        
        with th.no_grad():
            # Forward pass
            out = model(*inputs)
            l = loss_fn(out, y)
        
        loss_val.append(l.cpu().data.numpy())
        predicted_labels = out.argmax(1)
        y_true.extend(list(y.cpu().numpy()))
        y_pred.extend(list(predicted_labels.cpu().numpy()))
        acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
        acc_val_list.append(acc)
    
    acc_val = np.asarray(acc_val_list).mean()
    loss_val = np.asarray(loss_val).mean()
    f1_test = f1_score(y_true, y_pred, average='macro')
    
    return loss_val, acc_val, f1_test, y_true, y_pred

def train_model(model, train_loader, val_loader, loss_fn, optimizer, scheduler, epochs, folder_name, combo=False):
    t1, t2, t3, t4, t5 = [], [], [], [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    min_val_loss = float('inf')
    best_epoch = 0

    for epoch in range(epochs):
        start_time = time.time()  # Start time of the epoch

        # Training phase
        loss_train, acc_train = train_one_epoch(model, train_loader, loss_fn, optimizer, device, combo)
        scheduler.step()

        t1.append(loss_train)
        t2.append(100 * acc_train)

        # Validation phase
        loss_val, acc_val, f1_test, y_true, y_pred = validate_one_epoch(model, val_loader, loss_fn, device, combo)

       
        t3.append(loss_val)
        t4.append(100 * acc_val)
        t5.append(100 * f1_test)
        
        print('Epoch {}/{} - Train loss: {:.4f} - Val loss: {:.4f} - Train acc: {:.2f}% - Val acc: {:.2f}% - Test F1-score: {:.2f}'.format(
            epoch + 1, epochs, loss_train, loss_val, 100 * acc_train, 100 * acc_val, 100 * f1_test))

        elapsed_time = time.time() - start_time
        print('Elapsed time: {:.2f} seconds'.format(elapsed_time))
        
        # Save the best model
        if loss_val < min_val_loss:
            min_val_loss = loss_val
            best_epoch = epoch + 1

            ckpt = {
                'epoch': best_epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict() if scheduler is not None else None,
                'train_loss_history': t1,
                'train_accuracy_history': t2,
                'val_loss_history': t3,
                'val_accuracy_history': t4,
                'y_true': y_true,
                'y_pred': y_pred,
                'loss': min_val_loss
            }
            
            best_model_path = os.path.join(folder_name, 'best_model.pth')
            th.save(ckpt, best_model_path)
            print(f'Best model checkpoint saved at {best_model_path}')

    # Save training results to a CSV file
    results_df = pd.DataFrame({
        'epoch': np.arange(1, epochs + 1),
        'train_loss': t1,
        'train_acc': t2,
        'val_loss': t3,
        'val_acc': t4,
        'f1_score': t5

    })
    results_df.to_csv(os.path.join(folder_name, 'training_results.csv'), index=False)

    return t1, t2, t3, t4, t5, best_epoch, best_model_path

# %%
def plot_training_results(t1, t2, t3, t4, t5, folder_name, figure_name, best_epoch):
    print(f'Best epoch: {best_epoch}')
    plt.figure(figsize=(12, 8))
    plt.title("Training and Validation Loss and Accuracy")

    # Plot training and validation loss
    p1, = plt.plot(t1, label='Train loss', color='blue')
    p2, = plt.plot(t3, label='Validation loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0, 1)

    ax2 = plt.twinx()

    # Plot training and validation accuracy
    p3, = ax2.plot(t2, label='Train accuracy', color='orange')
    p4, = ax2.plot(t4, label='Validation accuracy', color='green')
    ax2.set_ylabel('Accuracy (%)')

    # Plot test F1-score
    p5, = ax2.plot(t5, label='F1-score-Validation', linestyle='dashed', color='purple')

    # Combine legends
    lines = [p1, p2, p3, p4, p5]
    labels = [line.get_label() for line in lines]
    plt.legend(lines, labels, loc='center left', bbox_to_anchor=(1.1, 0.5))

    # Save the figure with the provided name
    plot_name = os.path.join(folder_name, figure_name)
    plt.savefig(f'{plot_name}.png', bbox_inches='tight', pad_inches=0.2, dpi=500)
    print(f'Figure saved as {figure_name}.png')
    plt.show()

# %%
def evaluate_model(best_model_path, data_loader, loss_fn, model_name, figure_name, folder_name, combo=False, temp=False, linear_classif=False, device=device):

    # Load the best model
    model = initialize_model(combo, linear_classif, temp, device)
    ckpt = th.load(best_model_path)
    model.load_state_dict(ckpt['model_state_dict'])
    epoch = ckpt['epoch']
    print(f'Model loaded from the best epoch {epoch}')
    print('Model loaded')
    
    loss_val, acc_val = [], []
    y_true, y_pred = [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    model.eval()
    for batch in data_loader:
        if combo:
            x1, x2, y = batch
            x1 = x1.to(device)
            x2 = x2.to(device)
            inputs = (x1, x2)
        else:
            x, y = batch
            x = x.to(device)
            inputs = (x,)
        y = y.to(device).long()
        
        with th.no_grad():
            # Forward pass
            out = model(*inputs)
            l = loss_fn(out, y)
        
        predicted_labels = out.argmax(1)
        y_true.extend(list(y.cpu().numpy()))
        y_pred.extend(list(predicted_labels.cpu().numpy()))
        acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
        loss_val.append(l.cpu().data.numpy())
        acc_val.append(acc)

    acc_val = np.asarray(acc_val).mean()
    loss_val = np.asarray(loss_val).mean()

    print('Validation loss: {:.4f}'.format(loss_val))
    print('Validation accuracy: {:.2f}%'.format(100 * acc_val))

    # Save the model
    model_filename = os.path.join(folder_name, f'{model_name}.ckpt')
    th.save(model.state_dict(), model_filename)
    print(f'Model saved as {model_name}.ckpt')

    # Print and save classification report
    cf_report = classification_report(y_true, y_pred, digits=2, target_names=data_loader.dataset.class_names)
    print(cf_report)
    cf_report_filename = os.path.join(folder_name, f'{model_name}_classification_report.txt')
    with open(cf_report_filename, 'w') as f:
        f.write(cf_report)
    print(f'Classification report saved as {cf_report_filename}')

    # Compute and plot confusion matrix
    cmatrix = confusion_matrix(y_true, y_pred)
    Ncmatrix = cmatrix.astype('float') / cmatrix.sum(axis=1)[:, np.newaxis]

    group_counts = ['{0:0.0f}'.format(value) for value in cmatrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in Ncmatrix.flatten()]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(len(data_loader.dataset.class_names), len(data_loader.dataset.class_names))

    # Plot and save the confusion matrix figure
    plt.figure(figsize=(10, 8))
    sns.heatmap(Ncmatrix, annot=labels, fmt='', cmap='Reds', xticklabels=data_loader.dataset.class_names, yticklabels=data_loader.dataset.class_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label\n Acc={:.2f}%'.format(100 * acc_val))
    
    plot_name = os.path.join(folder_name, f'{figure_name}.png')
    plt.savefig(plot_name, bbox_inches='tight', pad_inches=0.2, dpi=500)
    plt.show()
    print(f'Figure saved as {figure_name}.png')

    return 100 * acc_val

# %%
# tsn-e plot

def gen_features(net, dataloader, combo=False, linear_classif = True):
    net.eval()
    targets_list = []
    outputs_list = []

    with th.no_grad():
        for idx, batch in enumerate(dataloader):
            if combo:
                x1, x2, targets = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, targets = batch
                x = x.to(device)
                inputs = (x,)
            targets = targets.to(device)
            targets_np = targets.cpu().numpy()
            
            if linear_classif:
                outputs = net.forward(*inputs)
                outputs_np = outputs.data.cpu().numpy()
            else:
                if combo:
                    outputs = net.forward(*inputs)
                else:
                    outputs = net.partial_forward(*inputs)
                outputs_np = outputs.data.cpu().numpy()
            
            targets_list.append(targets_np[:, np.newaxis])
            outputs_list.append(outputs_np)

            if ((idx + 1) % 10 == 0) or (idx + 1 == len(dataloader)):
                print(idx + 1, '/', len(dataloader))

    targets = np.concatenate(targets_list, axis=0)
    outputs = np.concatenate(outputs_list, axis=0).astype(np.float64)

    return targets, outputs

def tsne_plot(fig_name, targets, outputs):
    print('generating t-SNE plot...')
    # tsne_output = bh_sne(outputs)
    tsne = TSNE(random_state=42, perplexity=50)
    tsne_output = tsne.fit_transform(outputs)

    df = pd.DataFrame(tsne_output, columns=['x', 'y'])
    df['targets'] = targets

    plt.rcParams['figure.figsize'] = 10, 10
    sns.scatterplot(
        x='x', y='y',
        hue='targets',
        palette=sns.color_palette("Paired", 11),
        data=df,
        marker='o',
        legend="full",
        alpha=0.5
    )

    plt.xticks([])
    plt.yticks([])
    plt.xlabel('')
    plt.ylabel('')
    plt.legend(loc='best')
    plt.title('t-SNE plot of the embeddings: After training')


    plot_name = os.path.join(folder_name, f'{fig_name}.png')
    plt.savefig(plot_name, bbox_inches='tight', pad_inches=0.2, dpi=500)
    plt.show()
    print(f'Figure saved as {fig_name}.png')
    print('done!')

# %% [markdown]
# # Start

# %%
# %matplotlib inline
# Initialize dataset
dataset = TS_COV(root_dir=root_dir, np_file=npz_file, estimator='scm', combo=combo, temp=temp)

# Split data into train, validation, and test sets
if val is not None:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                    test_size=test_size, stratify=dataset.y, random_state=random_seed)
    train_indices, val_indices = train_test_split(train_indices,
                                                   test_size=test_size, stratify=dataset.y[train_indices], random_state=random_seed)
else:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                   test_size=test_size, stratify=dataset.y, random_state=random_seed)
    val_indices = None

# Calculate class weights
weights = calculate_class_weights(dataset.y)
weights = weights.to(device)

# Create data loaders
if val:
    train_loader, val_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
else:
    train_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
    val_loader = None

# Plot class distribution
plot_class_distribution(train_loader, val_loader, test_loader, n_classes=n_classes, combo=combo)

# %%
# access one matri
if combo:
    for x1,x2, y in train_loader:
        print(x1.shape)
        print(x2.shape)
        print(y.shape)
        break
else:
    for x, y in train_loader:
        print(x.shape)
        print(y.shape)
        break
# Out:
# torch.Size([64, 1, 10, 10])
# torch.Size([64])

# %%
# initialize the model
model = initialize_model(combo, linear_classif, temp, device)
# model.load_state_dict(th.load('model_temp_linear_mm_209.ckpt'))
model.eval()
# Out:
# Single modality - Spectral model with Buseman classifier
# Trainable total parameters: 1241
# /opt/conda/lib/python3.10/site-packages/geoopt/manifolds/symmetric_positive_definite.py:52: UserWarning: SPDMetric.LEM is not fully implemented and results may be not as you expect
#   warnings.warn(
# LogEucRResNet(
#   (manifold_Stiefel): Stiefel(canonical) manifold
#   (manifold_SPD): SymmetricPositiveDefinite(default_metric=SPDMetric.LEM) manifold
#   (classiflayer): BusemanSimilarityClassifier(
#     (manifold): Stiefel(canonical) manifold
#     (linear): Linear(in_features=8, out_features=7, bias=True)
#   )
#   (fc_layer): Linear(in_features=49, out_features=7, bias=True)
#   (softmax): Softmax(dim=-1)
#   (spectrum_map): Sequential(
#     (0): Conv1d(1, 10, kernel_size=(5,), stride=(1,), padding=same)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv1d(10, 5, kernel_size=(3,), stride=(1,), padding=same)
#     (4): LeakyReLU(negative_slope=0.01)
#     (5): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv1d(5, 1, kernel_size=(3,), stride=(1,), padding=same)
#   )
# )

# %%
#setup loss and optimizer

if loss == "focal":
    loss_fn = FocalLoss(gamma=gamma_loss,weights=weights)
else:
    loss_fn = nn.CrossEntropyLoss(weights=weights)
#opti = MixOptimizer(model.parameters(),lr=lr)
opti = geoopt.optim.RiemannianAdam(model.parameters(), lr=lr)
if step_lr:
    scheduler = lr_scheduler.StepLR(opti, step_size, gamma_value)
else:
    scheduler = lr_scheduler.ExponentialLR(opti, gamma=gamma_value)

# %%
# %matplotlib inline

if val:
    t1, t2, t3, t4, t5, best_epoch, best_model_path = train_model(model, train_loader, val_loader, loss_fn, opti, scheduler, epochs, folder_name, combo=combo)
else:
    t1, t2, t3, t4, t5, best_epoch, best_model_path = train_model(model, train_loader, test_loader, loss_fn, opti, scheduler, epochs, folder_name, combo=combo)
# Out:
# Epoch 1/200 - Train loss: 0.6258 - Val loss: 0.3947 - Train acc: 56.71% - Val acc: 67.34% - Test F1-score: 57.35
# Elapsed time: 26.82 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 2/200 - Train loss: 0.3722 - Val loss: 0.3508 - Train acc: 67.80% - Val acc: 69.37% - Test F1-score: 61.21
# Elapsed time: 26.46 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 3/200 - Train loss: 0.3269 - Val loss: 0.2989 - Train acc: 69.73% - Val acc: 71.51% - Test F1-score: 63.15
# Elapsed time: 26.42 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 4/200 - Train loss: 0.3110 - Val loss: 0.3057 - Train acc: 70.60% - Val acc: 69.99% - Test F1-score: 62.45
# Elapsed time: 26.34 seconds
# Epoch 5/200 - Train loss: 0.3040 - Val loss: 0.2925 - Train acc: 71.36% - Val acc: 71.77% - Test F1-score: 62.66
# Elapsed time: 25.95 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 6/200 - Train loss: 0.2975 - Val loss: 0.2839 - Train acc: 71.60% - Val acc: 72.47% - Test F1-score: 64.73
# Elapsed time: 25.66 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 7/200 - Train loss: 0.2926 - Val loss: 0.2938 - Train acc: 71.95% - Val acc: 71.21% - Test F1-score: 61.91
# Elapsed time: 25.42 seconds
# Epoch 8/200 - Train loss: 0.2909 - Val loss: 0.2893 - Train acc: 71.96% - Val acc: 72.83% - Test F1-score: 63.74
# Elapsed time: 26.53 seconds
# Epoch 9/200 - Train loss: 0.2881 - Val loss: 0.2817 - Train acc: 72.39% - Val acc: 73.17% - Test F1-score: 65.63
# Elapsed time: 26.33 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 10/200 - Train loss: 0.2843 - Val loss: 0.2830 - Train acc: 72.62% - Val acc: 73.49% - Test F1-score: 64.74
# Elapsed time: 26.07 seconds
# Epoch 11/200 - Train loss: 0.2829 - Val loss: 0.2713 - Train acc: 72.65% - Val acc: 73.05% - Test F1-score: 65.20
# Elapsed time: 25.45 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 12/200 - Train loss: 0.2814 - Val loss: 0.2658 - Train acc: 72.85% - Val acc: 73.82% - Test F1-score: 65.67
# Elapsed time: 24.98 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 13/200 - Train loss: 0.2801 - Val loss: 0.2952 - Train acc: 72.95% - Val acc: 71.97% - Test F1-score: 63.62
# Elapsed time: 25.15 seconds
# Epoch 14/200 - Train loss: 0.2782 - Val loss: 0.2655 - Train acc: 73.09% - Val acc: 73.80% - Test F1-score: 65.93
# Elapsed time: 25.09 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 15/200 - Train loss: 0.2777 - Val loss: 0.2760 - Train acc: 73.25% - Val acc: 72.42% - Test F1-score: 65.55
# Elapsed time: 25.10 seconds
# Epoch 16/200 - Train loss: 0.2754 - Val loss: 0.2720 - Train acc: 73.39% - Val acc: 73.33% - Test F1-score: 63.69
# Elapsed time: 25.05 seconds
# Epoch 17/200 - Train loss: 0.2737 - Val loss: 0.2649 - Train acc: 73.44% - Val acc: 73.59% - Test F1-score: 64.76
# Elapsed time: 24.93 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 18/200 - Train loss: 0.2732 - Val loss: 0.2822 - Train acc: 73.31% - Val acc: 73.36% - Test F1-score: 66.05
# Elapsed time: 25.24 seconds
# Epoch 19/200 - Train loss: 0.2731 - Val loss: 0.2662 - Train acc: 73.28% - Val acc: 73.36% - Test F1-score: 64.27
# Elapsed time: 25.44 seconds
# Epoch 20/200 - Train loss: 0.2710 - Val loss: 0.2620 - Train acc: 73.52% - Val acc: 74.06% - Test F1-score: 65.83
# Elapsed time: 25.27 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 21/200 - Train loss: 0.2707 - Val loss: 0.2618 - Train acc: 73.63% - Val acc: 73.47% - Test F1-score: 66.89
# Elapsed time: 25.38 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 22/200 - Train loss: 0.2703 - Val loss: 0.2609 - Train acc: 73.37% - Val acc: 73.07% - Test F1-score: 66.45
# Elapsed time: 25.93 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 23/200 - Train loss: 0.2685 - Val loss: 0.2673 - Train acc: 73.68% - Val acc: 73.76% - Test F1-score: 64.55
# Elapsed time: 25.67 seconds
# Epoch 24/200 - Train loss: 0.2680 - Val loss: 0.2613 - Train acc: 73.54% - Val acc: 74.16% - Test F1-score: 66.93
# Elapsed time: 25.40 seconds
# Epoch 25/200 - Train loss: 0.2688 - Val loss: 0.2649 - Train acc: 73.71% - Val acc: 74.19% - Test F1-score: 65.48
# Elapsed time: 25.25 seconds
# Epoch 26/200 - Train loss: 0.2664 - Val loss: 0.2580 - Train acc: 73.93% - Val acc: 74.05% - Test F1-score: 66.35
# Elapsed time: 25.39 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 27/200 - Train loss: 0.2655 - Val loss: 0.2717 - Train acc: 73.83% - Val acc: 73.98% - Test F1-score: 65.61
# Elapsed time: 25.21 seconds
# Epoch 28/200 - Train loss: 0.2656 - Val loss: 0.2605 - Train acc: 73.73% - Val acc: 74.05% - Test F1-score: 65.47
# Elapsed time: 25.25 seconds
# Epoch 29/200 - Train loss: 0.2640 - Val loss: 0.2628 - Train acc: 74.04% - Val acc: 73.70% - Test F1-score: 66.00
# Elapsed time: 25.77 seconds
# Epoch 30/200 - Train loss: 0.2646 - Val loss: 0.2644 - Train acc: 74.01% - Val acc: 73.86% - Test F1-score: 65.74
# Elapsed time: 25.22 seconds
# Epoch 31/200 - Train loss: 0.2639 - Val loss: 0.2697 - Train acc: 74.05% - Val acc: 73.89% - Test F1-score: 65.64
# Elapsed time: 26.33 seconds
# Epoch 32/200 - Train loss: 0.2628 - Val loss: 0.2696 - Train acc: 74.10% - Val acc: 71.90% - Test F1-score: 64.84
# Elapsed time: 26.28 seconds
# Epoch 33/200 - Train loss: 0.2624 - Val loss: 0.2580 - Train acc: 74.26% - Val acc: 74.24% - Test F1-score: 66.32
# Elapsed time: 26.34 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 34/200 - Train loss: 0.2616 - Val loss: 0.2553 - Train acc: 74.10% - Val acc: 74.66% - Test F1-score: 67.15
# Elapsed time: 25.68 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 35/200 - Train loss: 0.2618 - Val loss: 0.2607 - Train acc: 74.19% - Val acc: 73.66% - Test F1-score: 66.25
# Elapsed time: 25.16 seconds
# Epoch 36/200 - Train loss: 0.2613 - Val loss: 0.2632 - Train acc: 74.10% - Val acc: 73.20% - Test F1-score: 66.25
# Elapsed time: 24.72 seconds
# Epoch 37/200 - Train loss: 0.2605 - Val loss: 0.2540 - Train acc: 74.27% - Val acc: 74.59% - Test F1-score: 66.74
# Elapsed time: 24.81 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 38/200 - Train loss: 0.2598 - Val loss: 0.2597 - Train acc: 74.35% - Val acc: 73.74% - Test F1-score: 66.39
# Elapsed time: 25.09 seconds
# Epoch 39/200 - Train loss: 0.2592 - Val loss: 0.2606 - Train acc: 74.36% - Val acc: 73.22% - Test F1-score: 65.78
# Elapsed time: 25.63 seconds
# Epoch 40/200 - Train loss: 0.2590 - Val loss: 0.2548 - Train acc: 74.28% - Val acc: 74.26% - Test F1-score: 66.78
# Elapsed time: 24.94 seconds
# Epoch 41/200 - Train loss: 0.2588 - Val loss: 0.2575 - Train acc: 74.42% - Val acc: 74.41% - Test F1-score: 65.76
# Elapsed time: 25.69 seconds
# Epoch 42/200 - Train loss: 0.2589 - Val loss: 0.2563 - Train acc: 74.46% - Val acc: 74.08% - Test F1-score: 67.04
# Elapsed time: 25.63 seconds
# Epoch 43/200 - Train loss: 0.2583 - Val loss: 0.2549 - Train acc: 74.42% - Val acc: 74.34% - Test F1-score: 65.92
# Elapsed time: 25.53 seconds
# Epoch 44/200 - Train loss: 0.2577 - Val loss: 0.2548 - Train acc: 74.51% - Val acc: 74.41% - Test F1-score: 66.02
# Elapsed time: 26.28 seconds
# Epoch 45/200 - Train loss: 0.2576 - Val loss: 0.2551 - Train acc: 74.51% - Val acc: 74.37% - Test F1-score: 66.54
# Elapsed time: 26.07 seconds
# Epoch 46/200 - Train loss: 0.2571 - Val loss: 0.2528 - Train acc: 74.47% - Val acc: 74.30% - Test F1-score: 66.78
# Elapsed time: 24.88 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 47/200 - Train loss: 0.2563 - Val loss: 0.2539 - Train acc: 74.59% - Val acc: 74.42% - Test F1-score: 66.67
# Elapsed time: 24.96 seconds
# Epoch 48/200 - Train loss: 0.2565 - Val loss: 0.2551 - Train acc: 74.50% - Val acc: 74.43% - Test F1-score: 66.80
# Elapsed time: 25.01 seconds
# Epoch 49/200 - Train loss: 0.2562 - Val loss: 0.2519 - Train acc: 74.70% - Val acc: 74.55% - Test F1-score: 66.81
# Elapsed time: 24.64 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 50/200 - Train loss: 0.2560 - Val loss: 0.2541 - Train acc: 74.58% - Val acc: 74.59% - Test F1-score: 66.79
# Elapsed time: 24.40 seconds
# Epoch 51/200 - Train loss: 0.2555 - Val loss: 0.2512 - Train acc: 74.63% - Val acc: 74.41% - Test F1-score: 67.02
# Elapsed time: 24.91 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 52/200 - Train loss: 0.2555 - Val loss: 0.2588 - Train acc: 74.64% - Val acc: 74.33% - Test F1-score: 66.82
# Elapsed time: 25.65 seconds
# Epoch 53/200 - Train loss: 0.2556 - Val loss: 0.2508 - Train acc: 74.59% - Val acc: 74.67% - Test F1-score: 67.07
# Elapsed time: 25.88 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 54/200 - Train loss: 0.2549 - Val loss: 0.2535 - Train acc: 74.63% - Val acc: 73.88% - Test F1-score: 66.73
# Elapsed time: 25.68 seconds
# Epoch 55/200 - Train loss: 0.2547 - Val loss: 0.2526 - Train acc: 74.68% - Val acc: 74.49% - Test F1-score: 66.34
# Elapsed time: 24.99 seconds
# Epoch 56/200 - Train loss: 0.2545 - Val loss: 0.2511 - Train acc: 74.63% - Val acc: 74.70% - Test F1-score: 66.64
# Elapsed time: 25.19 seconds
# Epoch 57/200 - Train loss: 0.2543 - Val loss: 0.2506 - Train acc: 74.64% - Val acc: 74.63% - Test F1-score: 66.76
# Elapsed time: 25.20 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 58/200 - Train loss: 0.2540 - Val loss: 0.2549 - Train acc: 74.68% - Val acc: 74.06% - Test F1-score: 66.86
# Elapsed time: 24.89 seconds
# Epoch 59/200 - Train loss: 0.2540 - Val loss: 0.2500 - Train acc: 74.64% - Val acc: 74.68% - Test F1-score: 67.14
# Elapsed time: 24.87 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 60/200 - Train loss: 0.2537 - Val loss: 0.2512 - Train acc: 74.74% - Val acc: 74.61% - Test F1-score: 67.37
# Elapsed time: 26.03 seconds
# Epoch 61/200 - Train loss: 0.2538 - Val loss: 0.2545 - Train acc: 74.71% - Val acc: 74.62% - Test F1-score: 66.75
# Elapsed time: 25.14 seconds
# Epoch 62/200 - Train loss: 0.2537 - Val loss: 0.2508 - Train acc: 74.76% - Val acc: 74.68% - Test F1-score: 67.03
# Elapsed time: 25.19 seconds
# Epoch 63/200 - Train loss: 0.2532 - Val loss: 0.2508 - Train acc: 74.73% - Val acc: 74.62% - Test F1-score: 66.55
# Elapsed time: 26.16 seconds
# Epoch 64/200 - Train loss: 0.2533 - Val loss: 0.2512 - Train acc: 74.72% - Val acc: 74.47% - Test F1-score: 66.58
# Elapsed time: 26.48 seconds
# Epoch 65/200 - Train loss: 0.2533 - Val loss: 0.2509 - Train acc: 74.80% - Val acc: 74.50% - Test F1-score: 67.08
# Elapsed time: 27.16 seconds
# Epoch 66/200 - Train loss: 0.2530 - Val loss: 0.2497 - Train acc: 74.68% - Val acc: 74.59% - Test F1-score: 67.11
# Elapsed time: 26.26 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 67/200 - Train loss: 0.2528 - Val loss: 0.2498 - Train acc: 74.75% - Val acc: 74.73% - Test F1-score: 66.99
# Elapsed time: 26.07 seconds
# Epoch 68/200 - Train loss: 0.2528 - Val loss: 0.2498 - Train acc: 74.73% - Val acc: 74.72% - Test F1-score: 67.21
# Elapsed time: 26.67 seconds
# Epoch 69/200 - Train loss: 0.2527 - Val loss: 0.2497 - Train acc: 74.74% - Val acc: 74.68% - Test F1-score: 67.20
# Elapsed time: 26.01 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 70/200 - Train loss: 0.2527 - Val loss: 0.2503 - Train acc: 74.78% - Val acc: 74.79% - Test F1-score: 67.18
# Elapsed time: 24.99 seconds
# Epoch 71/200 - Train loss: 0.2524 - Val loss: 0.2496 - Train acc: 74.77% - Val acc: 74.58% - Test F1-score: 67.24
# Elapsed time: 25.37 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 72/200 - Train loss: 0.2521 - Val loss: 0.2495 - Train acc: 74.85% - Val acc: 74.76% - Test F1-score: 67.13
# Elapsed time: 26.12 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 73/200 - Train loss: 0.2522 - Val loss: 0.2490 - Train acc: 74.79% - Val acc: 74.60% - Test F1-score: 67.27
# Elapsed time: 26.94 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 74/200 - Train loss: 0.2522 - Val loss: 0.2495 - Train acc: 74.77% - Val acc: 74.67% - Test F1-score: 67.05
# Elapsed time: 25.94 seconds
# Epoch 75/200 - Train loss: 0.2521 - Val loss: 0.2506 - Train acc: 74.88% - Val acc: 74.27% - Test F1-score: 67.17
# Elapsed time: 25.73 seconds
# Epoch 76/200 - Train loss: 0.2519 - Val loss: 0.2496 - Train acc: 74.79% - Val acc: 74.65% - Test F1-score: 67.29
# Elapsed time: 24.91 seconds
# Epoch 77/200 - Train loss: 0.2519 - Val loss: 0.2508 - Train acc: 74.70% - Val acc: 74.80% - Test F1-score: 66.94
# Elapsed time: 25.68 seconds
# Epoch 78/200 - Train loss: 0.2516 - Val loss: 0.2514 - Train acc: 74.81% - Val acc: 74.38% - Test F1-score: 67.47
# Elapsed time: 25.13 seconds
# Epoch 79/200 - Train loss: 0.2517 - Val loss: 0.2495 - Train acc: 74.76% - Val acc: 74.80% - Test F1-score: 67.28
# Elapsed time: 25.36 seconds
# Epoch 80/200 - Train loss: 0.2514 - Val loss: 0.2496 - Train acc: 74.81% - Val acc: 74.59% - Test F1-score: 67.26
# Elapsed time: 25.25 seconds
# Epoch 81/200 - Train loss: 0.2515 - Val loss: 0.2504 - Train acc: 74.88% - Val acc: 74.82% - Test F1-score: 67.22
# Elapsed time: 24.40 seconds
# Epoch 82/200 - Train loss: 0.2515 - Val loss: 0.2496 - Train acc: 74.85% - Val acc: 74.59% - Test F1-score: 67.32
# Elapsed time: 24.50 seconds
# Epoch 83/200 - Train loss: 0.2515 - Val loss: 0.2506 - Train acc: 74.86% - Val acc: 74.76% - Test F1-score: 67.01
# Elapsed time: 25.09 seconds
# Epoch 84/200 - Train loss: 0.2515 - Val loss: 0.2499 - Train acc: 74.84% - Val acc: 74.60% - Test F1-score: 67.33
# Elapsed time: 24.81 seconds
# Epoch 85/200 - Train loss: 0.2512 - Val loss: 0.2496 - Train acc: 74.84% - Val acc: 74.74% - Test F1-score: 67.19
# Elapsed time: 25.10 seconds
# Epoch 86/200 - Train loss: 0.2511 - Val loss: 0.2492 - Train acc: 74.83% - Val acc: 74.77% - Test F1-score: 67.21
# Elapsed time: 24.73 seconds
# Epoch 87/200 - Train loss: 0.2513 - Val loss: 0.2491 - Train acc: 74.86% - Val acc: 74.58% - Test F1-score: 67.37
# Elapsed time: 24.86 seconds
# Epoch 88/200 - Train loss: 0.2512 - Val loss: 0.2492 - Train acc: 74.86% - Val acc: 74.77% - Test F1-score: 67.20
# Elapsed time: 25.45 seconds
# Epoch 89/200 - Train loss: 0.2512 - Val loss: 0.2493 - Train acc: 74.84% - Val acc: 74.79% - Test F1-score: 67.15
# Elapsed time: 25.06 seconds
# Epoch 90/200 - Train loss: 0.2512 - Val loss: 0.2489 - Train acc: 74.86% - Val acc: 74.75% - Test F1-score: 67.29
# Elapsed time: 25.22 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 91/200 - Train loss: 0.2511 - Val loss: 0.2487 - Train acc: 74.89% - Val acc: 74.58% - Test F1-score: 67.27
# Elapsed time: 25.44 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 92/200 - Train loss: 0.2510 - Val loss: 0.2488 - Train acc: 74.75% - Val acc: 74.65% - Test F1-score: 67.24
# Elapsed time: 24.88 seconds
# Epoch 93/200 - Train loss: 0.2509 - Val loss: 0.2493 - Train acc: 74.84% - Val acc: 74.65% - Test F1-score: 67.30
# Elapsed time: 25.10 seconds
# Epoch 94/200 - Train loss: 0.2509 - Val loss: 0.2489 - Train acc: 74.93% - Val acc: 74.61% - Test F1-score: 67.33
# Elapsed time: 25.56 seconds
# Epoch 95/200 - Train loss: 0.2509 - Val loss: 0.2491 - Train acc: 74.79% - Val acc: 74.54% - Test F1-score: 67.21
# Elapsed time: 25.28 seconds
# Epoch 96/200 - Train loss: 0.2509 - Val loss: 0.2490 - Train acc: 74.94% - Val acc: 74.64% - Test F1-score: 67.36
# Elapsed time: 24.70 seconds
# Epoch 97/200 - Train loss: 0.2510 - Val loss: 0.2498 - Train acc: 74.94% - Val acc: 74.59% - Test F1-score: 67.40
# Elapsed time: 24.90 seconds
# Epoch 98/200 - Train loss: 0.2509 - Val loss: 0.2489 - Train acc: 74.89% - Val acc: 74.65% - Test F1-score: 67.27
# Elapsed time: 25.09 seconds
# Epoch 99/200 - Train loss: 0.2507 - Val loss: 0.2488 - Train acc: 74.86% - Val acc: 74.76% - Test F1-score: 67.35
# Elapsed time: 25.44 seconds
# Epoch 100/200 - Train loss: 0.2508 - Val loss: 0.2489 - Train acc: 74.92% - Val acc: 74.59% - Test F1-score: 67.32
# Elapsed time: 26.22 seconds
# Epoch 101/200 - Train loss: 0.2508 - Val loss: 0.2494 - Train acc: 74.88% - Val acc: 74.68% - Test F1-score: 66.95
# Elapsed time: 25.69 seconds
# Epoch 102/200 - Train loss: 0.2506 - Val loss: 0.2490 - Train acc: 74.93% - Val acc: 74.63% - Test F1-score: 67.31
# Elapsed time: 25.25 seconds
# Epoch 103/200 - Train loss: 0.2506 - Val loss: 0.2488 - Train acc: 74.90% - Val acc: 74.65% - Test F1-score: 67.35
# Elapsed time: 25.69 seconds
# Epoch 104/200 - Train loss: 0.2507 - Val loss: 0.2484 - Train acc: 74.88% - Val acc: 74.81% - Test F1-score: 67.29
# Elapsed time: 25.98 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 105/200 - Train loss: 0.2506 - Val loss: 0.2487 - Train acc: 74.98% - Val acc: 74.68% - Test F1-score: 67.39
# Elapsed time: 25.95 seconds
# Epoch 106/200 - Train loss: 0.2507 - Val loss: 0.2487 - Train acc: 74.87% - Val acc: 74.76% - Test F1-score: 67.39
# Elapsed time: 26.23 seconds
# Epoch 107/200 - Train loss: 0.2506 - Val loss: 0.2488 - Train acc: 74.92% - Val acc: 74.72% - Test F1-score: 67.22
# Elapsed time: 26.39 seconds
# Epoch 108/200 - Train loss: 0.2505 - Val loss: 0.2490 - Train acc: 74.95% - Val acc: 74.65% - Test F1-score: 67.34
# Elapsed time: 27.19 seconds
# Epoch 109/200 - Train loss: 0.2506 - Val loss: 0.2486 - Train acc: 74.91% - Val acc: 74.68% - Test F1-score: 67.29
# Elapsed time: 26.93 seconds
# Epoch 110/200 - Train loss: 0.2505 - Val loss: 0.2486 - Train acc: 74.81% - Val acc: 74.70% - Test F1-score: 67.41
# Elapsed time: 26.59 seconds
# Epoch 111/200 - Train loss: 0.2505 - Val loss: 0.2487 - Train acc: 74.96% - Val acc: 74.66% - Test F1-score: 67.39
# Elapsed time: 27.08 seconds
# Epoch 112/200 - Train loss: 0.2505 - Val loss: 0.2489 - Train acc: 74.93% - Val acc: 74.68% - Test F1-score: 67.27
# Elapsed time: 26.94 seconds
# Epoch 113/200 - Train loss: 0.2506 - Val loss: 0.2485 - Train acc: 74.93% - Val acc: 74.69% - Test F1-score: 67.29
# Elapsed time: 27.21 seconds
# Epoch 114/200 - Train loss: 0.2505 - Val loss: 0.2487 - Train acc: 74.91% - Val acc: 74.68% - Test F1-score: 67.25
# Elapsed time: 27.50 seconds
# Epoch 115/200 - Train loss: 0.2503 - Val loss: 0.2490 - Train acc: 74.97% - Val acc: 74.67% - Test F1-score: 67.37
# Elapsed time: 26.99 seconds
# Epoch 116/200 - Train loss: 0.2505 - Val loss: 0.2487 - Train acc: 74.88% - Val acc: 74.62% - Test F1-score: 67.27
# Elapsed time: 27.27 seconds
# Epoch 117/200 - Train loss: 0.2505 - Val loss: 0.2488 - Train acc: 74.92% - Val acc: 74.59% - Test F1-score: 67.27
# Elapsed time: 27.69 seconds
# Epoch 118/200 - Train loss: 0.2504 - Val loss: 0.2487 - Train acc: 74.93% - Val acc: 74.76% - Test F1-score: 67.31
# Elapsed time: 26.16 seconds
# Epoch 119/200 - Train loss: 0.2504 - Val loss: 0.2485 - Train acc: 74.98% - Val acc: 74.71% - Test F1-score: 67.32
# Elapsed time: 25.94 seconds
# Epoch 120/200 - Train loss: 0.2505 - Val loss: 0.2485 - Train acc: 74.88% - Val acc: 74.68% - Test F1-score: 67.34
# Elapsed time: 27.03 seconds
# Epoch 121/200 - Train loss: 0.2504 - Val loss: 0.2488 - Train acc: 74.89% - Val acc: 74.82% - Test F1-score: 67.35
# Elapsed time: 27.42 seconds
# Epoch 122/200 - Train loss: 0.2504 - Val loss: 0.2487 - Train acc: 74.90% - Val acc: 74.66% - Test F1-score: 67.30
# Elapsed time: 26.88 seconds
# Epoch 123/200 - Train loss: 0.2504 - Val loss: 0.2486 - Train acc: 74.88% - Val acc: 74.72% - Test F1-score: 67.27
# Elapsed time: 26.49 seconds
# Epoch 124/200 - Train loss: 0.2504 - Val loss: 0.2485 - Train acc: 74.86% - Val acc: 74.79% - Test F1-score: 67.33
# Elapsed time: 26.04 seconds
# Epoch 125/200 - Train loss: 0.2504 - Val loss: 0.2485 - Train acc: 74.90% - Val acc: 74.67% - Test F1-score: 67.35
# Elapsed time: 26.37 seconds
# Epoch 126/200 - Train loss: 0.2504 - Val loss: 0.2487 - Train acc: 74.94% - Val acc: 74.74% - Test F1-score: 67.27
# Elapsed time: 27.06 seconds
# Epoch 127/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.94% - Val acc: 74.77% - Test F1-score: 67.26
# Elapsed time: 26.89 seconds
# Epoch 128/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.90% - Val acc: 74.72% - Test F1-score: 67.36
# Elapsed time: 26.01 seconds
# Epoch 129/200 - Train loss: 0.2504 - Val loss: 0.2485 - Train acc: 74.87% - Val acc: 74.64% - Test F1-score: 67.28
# Elapsed time: 26.91 seconds
# Epoch 130/200 - Train loss: 0.2502 - Val loss: 0.2489 - Train acc: 74.94% - Val acc: 74.76% - Test F1-score: 67.32
# Elapsed time: 27.02 seconds
# Epoch 131/200 - Train loss: 0.2503 - Val loss: 0.2486 - Train acc: 74.90% - Val acc: 74.71% - Test F1-score: 67.32
# Elapsed time: 26.35 seconds
# Epoch 132/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.93% - Val acc: 74.75% - Test F1-score: 67.27
# Elapsed time: 26.60 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 133/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.90% - Val acc: 74.74% - Test F1-score: 67.29
# Elapsed time: 26.75 seconds
# Epoch 134/200 - Train loss: 0.2503 - Val loss: 0.2483 - Train acc: 74.88% - Val acc: 74.67% - Test F1-score: 67.28
# Elapsed time: 26.55 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 135/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.91% - Val acc: 74.70% - Test F1-score: 67.31
# Elapsed time: 25.97 seconds
# Epoch 136/200 - Train loss: 0.2504 - Val loss: 0.2486 - Train acc: 74.94% - Val acc: 74.74% - Test F1-score: 67.33
# Elapsed time: 27.92 seconds
# Epoch 137/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.91% - Val acc: 74.77% - Test F1-score: 67.30
# Elapsed time: 27.04 seconds
# Epoch 138/200 - Train loss: 0.2504 - Val loss: 0.2490 - Train acc: 74.89% - Val acc: 74.72% - Test F1-score: 67.27
# Elapsed time: 27.50 seconds
# Epoch 139/200 - Train loss: 0.2502 - Val loss: 0.2485 - Train acc: 74.91% - Val acc: 74.77% - Test F1-score: 67.32
# Elapsed time: 27.30 seconds
# Epoch 140/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.93% - Val acc: 74.72% - Test F1-score: 67.26
# Elapsed time: 25.78 seconds
# Epoch 141/200 - Train loss: 0.2503 - Val loss: 0.2483 - Train acc: 74.93% - Val acc: 74.81% - Test F1-score: 67.35
# Elapsed time: 26.78 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 142/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.96% - Val acc: 74.73% - Test F1-score: 67.31
# Elapsed time: 26.71 seconds
# Epoch 143/200 - Train loss: 0.2503 - Val loss: 0.2483 - Train acc: 74.93% - Val acc: 74.69% - Test F1-score: 67.33
# Elapsed time: 26.00 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 144/200 - Train loss: 0.2504 - Val loss: 0.2488 - Train acc: 74.92% - Val acc: 74.72% - Test F1-score: 67.33
# Elapsed time: 26.33 seconds
# Epoch 145/200 - Train loss: 0.2502 - Val loss: 0.2488 - Train acc: 74.90% - Val acc: 74.68% - Test F1-score: 67.31
# Elapsed time: 26.16 seconds
# Epoch 146/200 - Train loss: 0.2503 - Val loss: 0.2483 - Train acc: 74.88% - Val acc: 74.78% - Test F1-score: 67.29
# Elapsed time: 26.29 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 147/200 - Train loss: 0.2502 - Val loss: 0.2487 - Train acc: 74.95% - Val acc: 74.63% - Test F1-score: 67.32
# Elapsed time: 27.30 seconds
# Epoch 148/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.94% - Val acc: 74.78% - Test F1-score: 67.35
# Elapsed time: 26.96 seconds
# Epoch 149/200 - Train loss: 0.2503 - Val loss: 0.2487 - Train acc: 74.91% - Val acc: 74.79% - Test F1-score: 67.28
# Elapsed time: 26.31 seconds
# Epoch 150/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.88% - Val acc: 74.77% - Test F1-score: 67.30
# Elapsed time: 26.28 seconds
# Epoch 151/200 - Train loss: 0.2502 - Val loss: 0.2488 - Train acc: 74.90% - Val acc: 74.68% - Test F1-score: 67.29
# Elapsed time: 26.59 seconds
# Epoch 152/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.96% - Val acc: 74.77% - Test F1-score: 67.36
# Elapsed time: 27.16 seconds
# Epoch 153/200 - Train loss: 0.2504 - Val loss: 0.2484 - Train acc: 74.98% - Val acc: 74.70% - Test F1-score: 67.33
# Elapsed time: 27.16 seconds
# Epoch 154/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.93% - Val acc: 74.71% - Test F1-score: 67.29
# Elapsed time: 27.57 seconds
# Epoch 155/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.98% - Val acc: 74.74% - Test F1-score: 67.31
# Elapsed time: 27.38 seconds
# Epoch 156/200 - Train loss: 0.2503 - Val loss: 0.2487 - Train acc: 74.94% - Val acc: 74.66% - Test F1-score: 67.30
# Elapsed time: 27.66 seconds
# Epoch 157/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.95% - Val acc: 74.76% - Test F1-score: 67.32
# Elapsed time: 27.51 seconds
# Epoch 158/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.96% - Val acc: 74.72% - Test F1-score: 67.32
# Elapsed time: 27.90 seconds
# Epoch 159/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.90% - Val acc: 74.75% - Test F1-score: 67.30
# Elapsed time: 28.03 seconds
# Epoch 160/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.94% - Val acc: 74.75% - Test F1-score: 67.33
# Elapsed time: 27.26 seconds
# Epoch 161/200 - Train loss: 0.2503 - Val loss: 0.2487 - Train acc: 74.90% - Val acc: 74.80% - Test F1-score: 67.36
# Elapsed time: 26.49 seconds
# Epoch 162/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.96% - Val acc: 74.77% - Test F1-score: 67.36
# Elapsed time: 26.71 seconds
# Epoch 163/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.95% - Val acc: 74.72% - Test F1-score: 67.31
# Elapsed time: 26.69 seconds
# Epoch 164/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.90% - Val acc: 74.77% - Test F1-score: 67.31
# Elapsed time: 27.41 seconds
# Epoch 165/200 - Train loss: 0.2502 - Val loss: 0.2485 - Train acc: 74.89% - Val acc: 74.75% - Test F1-score: 67.29
# Elapsed time: 27.50 seconds
# Epoch 166/200 - Train loss: 0.2502 - Val loss: 0.2485 - Train acc: 74.90% - Val acc: 74.73% - Test F1-score: 67.32
# Elapsed time: 27.90 seconds
# Epoch 167/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.98% - Val acc: 74.79% - Test F1-score: 67.31
# Elapsed time: 27.92 seconds
# Epoch 168/200 - Train loss: 0.2502 - Val loss: 0.2485 - Train acc: 74.93% - Val acc: 74.75% - Test F1-score: 67.30
# Elapsed time: 27.63 seconds
# Epoch 169/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.97% - Val acc: 74.75% - Test F1-score: 67.33
# Elapsed time: 26.90 seconds
# Epoch 170/200 - Train loss: 0.2502 - Val loss: 0.2482 - Train acc: 74.96% - Val acc: 74.77% - Test F1-score: 67.29
# Elapsed time: 27.14 seconds
# Best model checkpoint saved at mm_bzh_001/best_model.pth
# Epoch 171/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.91% - Val acc: 74.70% - Test F1-score: 67.32
# Elapsed time: 27.17 seconds
# Epoch 172/200 - Train loss: 0.2503 - Val loss: 0.2486 - Train acc: 74.95% - Val acc: 74.76% - Test F1-score: 67.30
# Elapsed time: 27.38 seconds
# Epoch 173/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.90% - Val acc: 74.76% - Test F1-score: 67.33
# Elapsed time: 27.55 seconds
# Epoch 174/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.96% - Val acc: 74.81% - Test F1-score: 67.37
# Elapsed time: 27.55 seconds
# Epoch 175/200 - Train loss: 0.2502 - Val loss: 0.2483 - Train acc: 74.96% - Val acc: 74.76% - Test F1-score: 67.31
# Elapsed time: 28.24 seconds
# Epoch 176/200 - Train loss: 0.2502 - Val loss: 0.2487 - Train acc: 74.90% - Val acc: 74.73% - Test F1-score: 67.31
# Elapsed time: 28.20 seconds
# Epoch 177/200 - Train loss: 0.2502 - Val loss: 0.2489 - Train acc: 74.90% - Val acc: 74.75% - Test F1-score: 67.30
# Elapsed time: 27.81 seconds
# Epoch 178/200 - Train loss: 0.2503 - Val loss: 0.2486 - Train acc: 74.96% - Val acc: 74.73% - Test F1-score: 67.32
# Elapsed time: 26.92 seconds
# Epoch 179/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.94% - Val acc: 74.74% - Test F1-score: 67.31
# Elapsed time: 27.03 seconds
# Epoch 180/200 - Train loss: 0.2503 - Val loss: 0.2485 - Train acc: 74.91% - Val acc: 74.73% - Test F1-score: 67.31
# Elapsed time: 26.98 seconds
# Epoch 181/200 - Train loss: 0.2503 - Val loss: 0.2483 - Train acc: 74.94% - Val acc: 74.71% - Test F1-score: 67.31
# Elapsed time: 27.36 seconds
# Epoch 182/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.89% - Val acc: 74.76% - Test F1-score: 67.33
# Elapsed time: 28.21 seconds
# Epoch 183/200 - Train loss: 0.2502 - Val loss: 0.2482 - Train acc: 74.91% - Val acc: 74.74% - Test F1-score: 67.30
# Elapsed time: 28.14 seconds
# Epoch 184/200 - Train loss: 0.2502 - Val loss: 0.2483 - Train acc: 74.94% - Val acc: 74.75% - Test F1-score: 67.33
# Elapsed time: 28.62 seconds
# Epoch 185/200 - Train loss: 0.2503 - Val loss: 0.2484 - Train acc: 74.91% - Val acc: 74.72% - Test F1-score: 67.30
# Elapsed time: 28.20 seconds
# Epoch 186/200 - Train loss: 0.2503 - Val loss: 0.2489 - Train acc: 74.92% - Val acc: 74.76% - Test F1-score: 67.34
# Elapsed time: 28.13 seconds
# Epoch 187/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.93% - Val acc: 74.73% - Test F1-score: 67.33
# Elapsed time: 28.32 seconds
# Epoch 188/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.91% - Val acc: 74.76% - Test F1-score: 67.31
# Elapsed time: 28.50 seconds
# Epoch 189/200 - Train loss: 0.2504 - Val loss: 0.2483 - Train acc: 74.93% - Val acc: 74.75% - Test F1-score: 67.31
# Elapsed time: 28.40 seconds
# Epoch 190/200 - Train loss: 0.2501 - Val loss: 0.2485 - Train acc: 74.93% - Val acc: 74.71% - Test F1-score: 67.26
# Elapsed time: 27.77 seconds
# Epoch 191/200 - Train loss: 0.2502 - Val loss: 0.2482 - Train acc: 74.94% - Val acc: 74.79% - Test F1-score: 67.34
# Elapsed time: 28.15 seconds
# Epoch 192/200 - Train loss: 0.2502 - Val loss: 0.2488 - Train acc: 74.94% - Val acc: 74.77% - Test F1-score: 67.32
# Elapsed time: 28.85 seconds
# Epoch 193/200 - Train loss: 0.2501 - Val loss: 0.2489 - Train acc: 74.89% - Val acc: 74.74% - Test F1-score: 67.30
# Elapsed time: 28.36 seconds
# Epoch 194/200 - Train loss: 0.2502 - Val loss: 0.2482 - Train acc: 74.92% - Val acc: 74.77% - Test F1-score: 67.33
# Elapsed time: 28.68 seconds
# Epoch 195/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.92% - Val acc: 74.73% - Test F1-score: 67.31
# Elapsed time: 28.28 seconds
# Epoch 196/200 - Train loss: 0.2501 - Val loss: 0.2487 - Train acc: 74.92% - Val acc: 74.76% - Test F1-score: 67.33
# Elapsed time: 28.87 seconds
# Epoch 197/200 - Train loss: 0.2503 - Val loss: 0.2486 - Train acc: 74.95% - Val acc: 74.70% - Test F1-score: 67.33
# Elapsed time: 28.41 seconds
# Epoch 198/200 - Train loss: 0.2502 - Val loss: 0.2486 - Train acc: 74.97% - Val acc: 74.74% - Test F1-score: 67.32
# Elapsed time: 28.54 seconds
# Epoch 199/200 - Train loss: 0.2502 - Val loss: 0.2485 - Train acc: 74.93% - Val acc: 74.76% - Test F1-score: 67.29
# Elapsed time: 28.79 seconds
# Epoch 200/200 - Train loss: 0.2502 - Val loss: 0.2484 - Train acc: 74.94% - Val acc: 74.75% - Test F1-score: 67.32
# Elapsed time: 28.47 seconds

# %%
plot_training_results(t1, t2, t3, t4, t5,folder_name, plot_figure_name, best_epoch)
# Out:
# Best epoch: 170
# Figure saved as training_validation_results_Spec_bsm_mm_bzh_001.png

# %%
# %matplotlib inline
acc_val = evaluate_model(best_model_path, test_loader, loss_fn, model_name, figure_name, folder_name, combo=combo, temp=temp, linear_classif=linear_classif, device=device)
# Out:
# /opt/conda/lib/python3.10/site-packages/geoopt/manifolds/symmetric_positive_definite.py:52: UserWarning: SPDMetric.LEM is not fully implemented and results may be not as you expect
#   warnings.warn(
# Single modality - Spectral model with Buseman classifier
# Trainable total parameters: 1241
# Model loaded from the best epoch 170
# Model loaded
# Validation loss: 0.2479
# Validation accuracy: 75.04%
# Model saved as model_Spec_bsm_mm_bzh_001.ckpt
#                    precision    recall  f1-score   support
#
#            barley       0.81      0.73      0.77      1196
#             wheat       0.86      0.89      0.88      3399
#          rapeseed       0.94      0.94      0.94       647
#              corn       0.93      0.93      0.93      6267
#          orchards       0.00      0.00      0.00       111
# permanent meadows       0.57      0.51      0.53      5223
# temporary meadows       0.65      0.71      0.68      7678
#
#          accuracy                           0.75     24521
#         macro avg       0.68      0.67      0.67     24521
#      weighted avg       0.75      0.75      0.75     24521
#
# Classification report saved as mm_bzh_001/model_Spec_bsm_mm_bzh_001_classification_report.txt
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Figure saved as CM_Spec_bsm_mm_bzh_001.png

# %%
# path = r"C:\Users\Khizer Zakir\OneDrive - Université Bretagne Sud\thesis\Covariance_Thesis\notebooks\my_model\mm_21\model_combo_linear_mm_216.ckpt"
# # Load the best model
# ckpt = th.load(path)
# print(ckpt.keys())
# bimap = ckpt['model_temp.bimap1']
# array = bimap.squeeze().numpy()

# # Plot the array
# plt.figure(figsize=(6, 6))
# plt.imshow(array, cmap='viridis')  # Use a suitable colormap
# plt.colorbar()
# plt.title('Tensor Visualization')
# plt.show()

# %%
# %matplotlib inline

targets, outputs = gen_features(model,test_loader, combo =combo, linear_classif=linear_classif)
tsne_plot(tsne_fig_name,targets, outputs)
# Out:
# 10 / 384
# 20 / 384
# 30 / 384
# 40 / 384
# 50 / 384
# 60 / 384
# 70 / 384
# 80 / 384
# 90 / 384
# 100 / 384
# 110 / 384
# 120 / 384
# 130 / 384
# 140 / 384
# 150 / 384
# 160 / 384
# 170 / 384
# 180 / 384
# 190 / 384
# 200 / 384
# 210 / 384
# 220 / 384
# 230 / 384
# 240 / 384
# 250 / 384
# 260 / 384
# 270 / 384
# 280 / 384
# 290 / 384
# 300 / 384
# 310 / 384
# 320 / 384
# 330 / 384
# 340 / 384
# 350 / 384
# 360 / 384
# 370 / 384
# 380 / 384
# 384 / 384
# generating t-SNE plot...
# /tmp/ipykernel_154/1489538537.py:53: UserWarning: The palette list has more values (11) than needed (7), which may not be intended.
#   sns.scatterplot(
# Figure saved as Tsne_Spec_bsm_mm_bzh_001.png
# done!
