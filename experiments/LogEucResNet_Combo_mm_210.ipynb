# %%
import subprocess
import sys
sys.path.insert(0,'..')
from pathlib import Path
import os
import random

import torch
import torch.nn as nn
from torch.nn.functional import one_hot
from torch import Tensor
from typing import Union

import matplotlib.pylab as plt

import time
import numpy as np
import torch as th
import torch.nn as nn
from torch.utils import data
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler, WeightedRandomSampler
import torch.optim.lr_scheduler as lr_scheduler

from focal_loss import FocalLoss
from utils import _axat, _atxa, _mvmt
import seaborn as sns


def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package],
                         stdout=subprocess.DEVNULL,
                         stderr=subprocess.DEVNULL
                         )
required_packages = [
    "geoopt",
    "pyriemann",
]
for package in required_packages:
    try:
        __import__(package)
        print(f"{package} is already installed.")
    except ImportError:
        print(f"{package} is not installed. Installing...")
        install(package)

import geoopt
from pyriemann.utils.covariance import covariances, normalize


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.manifold import TSNE
import pandas as pd


use_cuda = th.cuda.is_available()
device = th.device("cuda:0" if use_cuda else "cpu")
print(device)
# Out:
# geoopt is already installed.
# pyriemann is already installed.
# cuda:0

# %%
# Flags and Parameters
root_dir = r"/kaggle/input/normalized-data/"
npz_file = "98_p_norm_data.npz"
batch_size = 64
n_classes = 11
random_seed = 42
test_size = 0.2
temp = False  # Whether the data is in temporal mode
val = True  # Whether to create a validation loader
combo = True  # Whether the data is in combo mode

model_name = "model_combo_linear_mm_210"
figure_name = "CM_combo_linear_mm_210"
tsne_fig_name ="Tsne_combo_linear_mm_210"
plot_figure_name = "training_validation_results_combo_linear_mm_210"
# for model
lr=1e-2
epochs=200
gamma_value=0.95
loss = "focal"
gamma_loss = 3
step_size=30
step_lr = False
linear_classif = True

# %%
class BusemanSimilarityClassifier(nn.Module):
    def busemann_spd(self, logM):
        """
        Compute the Busemann similarity for Symmetric Positive Definite (SPD) matrices.
        
        :param logM: Logarithm of SPD matrices, shape (b, n, n)
        :return: Similarity scores, shape (b, n_proto)
        """
        return logM.reshape(logM.shape[0], -1) @ self.proto.reshape(self.proto.shape[0], -1).T
    def __init__(self,dim1,n_proto,n_classes,optim_proto=True):
        super().__init__()
        self.n_proto = n_proto
        self.n_classes = n_classes
        self.dim1 = dim1
        
        self.manifold = geoopt.Stiefel()

        # Random projection directions, shape (d-1, num_projections)
        theta = np.random.normal(size=(self.n_proto, self.dim1))
        theta = th.nn.functional.normalize(th.from_numpy(theta), p=2, dim=-1).type(th.float64).to(device)
        #self.D = theta[:,None] * th.eye(theta.shape[-1],dtype=th.float64, device=device)
        self.register_parameter("theta_proto", geoopt.ManifoldParameter(theta, geoopt.Sphere()))
        #self.theta_proto=theta

        ## Random orthogonal matrices
        Z = th.randn((self.n_proto, self.dim1, self.dim1), dtype=th.float64, device=device)
        self.Q = th.svd(Z)[0]
        self.manifold.assert_check_point_on_manifold(self.Q)
        self.register_parameter("Q_proto", geoopt.ManifoldParameter(self.Q, self.manifold))
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        # linear layer
        self.linear = nn.Linear(self.n_proto, self.n_classes).double()

    def forward(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        y = self.linear(self.busemann_spd(x))#.view(sim_embedding.shape[0], -1))
        return y
    
    def embed(self, x):
        self.proto = _mvmt(self.Q_proto, self.theta_proto, self.Q_proto)
        return self.busemann_spd(x)

# %% [markdown]
# # Model definition

# %%
class LogEucRResNet(nn.Module):
    def __init__(self, inputdim=10, dim1=7, n_proto=12, classes=11, embed_only=False, linear_classif=False):
        super().__init__()
        self.inputdim = inputdim
        self.dim1 = dim1
        self.n_proto = n_proto
        self.classes = classes
        self.embed_only = embed_only
        self.linear_classif = linear_classif

        self.manifold_Stiefel = geoopt.Stiefel()
        self.manifold_SPD = geoopt.SymmetricPositiveDefinite("LEM")
        
        # init first bimap
        bm1 = th.randn((1, self.inputdim, self.dim1), dtype=th.float64)
        bm1 = th.svd(bm1)[0]
        self.register_parameter("bimap1", geoopt.ManifoldParameter(bm1, self.manifold_Stiefel))
        
        P = th.randn((1, self.dim1, self.dim1), dtype=th.float64)
        P = th.svd(P)[0]

        self.register_parameter("P1", geoopt.ManifoldParameter(P, self.manifold_Stiefel))

        self.classiflayer=BusemanSimilarityClassifier(self.dim1,self.n_proto, classes)
        self.fc_layer = nn.Linear(self.dim1 * self.dim1, self.classes).double()
        self.softmax =  nn.Softmax(dim=-1)

        self.spectrum_map = nn.Sequential(
            nn.Conv1d(1, 30, 5, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(30).double(),
            nn.Conv1d(30, 10, 3, padding="same").double(),
            nn.LeakyReLU(),
            nn.BatchNorm1d(10).double(),
            nn.Conv1d(10, 1, 3, padding="same").double(),
        )
        
    def forward(self, x):
        x = _atxa(self.bimap1, x)
        evecs, eigs, _ = th.svd(x)
        f_eigs = self.spectrum_map(eigs) # spectral map
        v1 = _mvmt(self.P1, f_eigs, self.P1)            
        v1 = self.manifold_SPD.proju(x, v1)
        eigs = th.clamp(eigs, 1e-8, 1e8)
        log_x = _mvmt(evecs, th.log(eigs), evecs)     
        x = log_x + v1
        if self.embed_only:
            return x.reshape(x.shape[0],-1)
        elif self.linear_classif:
            return self.softmax(self.fc_layer(x.reshape(x.shape[0],-1)))
        else:
            return self.softmax(self.classiflayer(x)) # Buseman Similarity Classifier when single modality is used
            
class LogEucRResNet_Combo(nn.Module):
    def __init__(self, inputdim_temp=36, dim1_temp=24, inputdim_spec=10, dim1_spec=7, n_proto=12, classes=11, buseman_classif=True):
        super().__init__()
        self.classes = classes
        self.buseman_classif = buseman_classif
        self.model_temp = LogEucRResNet(inputdim_temp, dim1_temp, n_proto, embed_only=True)
        self.model_spectral = LogEucRResNet(inputdim_spec, dim1_spec, n_proto, embed_only=True)
        
        self.classiflayer = BusemanSimilarityClassifier(dim1_temp+1,n_proto,classes)
        self.fc_layer = nn.Linear(dim1_temp*dim1_temp+dim1_spec*dim1_spec,classes).double()        
        self.softmax = nn.Softmax(dim=-1)
        
    def forward(self, x1, x2):
        out_1 = self.model_temp(x1) # probabilities
        out_2 = self.model_spectral(x2) # probabilities
        x = th.concat((out_1, out_2), dim=1)
        #print(x.shape)
        if self.buseman_classif:
            return self.softmax(self.classiflayer(x))
        else:
            return self.softmax(self.fc_layer(x))

# %%
def initialize_model(combo=True, linear_classif=True, device):
    if combo:
        if linear_classif:
            model = LogEucRResNet_Combo(buseman_classif=False).to(device)
        else:
            model = LogEucRResNet_Combo(buseman_classif=True).to(device)
    else:
        if linear_classif:
            model = LogEucRResNet(linear_classif=True).to(device)
        else:
            model = LogEucRResNet(linear_classif=False).to(device)

    # Get number of trainable parameters
    model.eval()
    trainable_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Trainable total parameters: {trainable_total_params}')
    return model

# %%
class TS_COV(Dataset):
    def __init__(self, root_dir, np_file, estimator='scm', combo=True, temp=False):
        self.root_dir = root_dir
        self.np_file = np_file
        self.estimator = estimator
        self.combo = combo
        self.temp = temp
        self.x, self.y, self.class_names = self.load_data()
        #self.cov = normalize(self.calculate_covariances(),'corr')
        self.x1 = self.calculate_covariances_36()
        self.x2 = self.calculate_covariances_10()
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x1, x2= self.x1[idx], self.x2[idx]
        y_sample = self.y[idx]
        class_name = self.class_names[y_sample]
        x1 = th.from_numpy(np.asarray([x1])).double()
        x2 = th.from_numpy(np.asarray([x2])).double()
        x1,x2 = x1.reshape(1, 36, 36), x2.reshape(1, 10, 10)
        y = th.from_numpy(np.array(y_sample)).long()
        if self.combo:
            return x1,x2, y
        elif self.temp:
            return x1, y
        else:
            return x2, y

    def load_data(self):
        file_path = os.path.join(self.root_dir, self.np_file)
        data = np.load(file_path, allow_pickle= True)
        x = data['series']
        y = data['labels']
        class_names = data['class_names']
        return x, y, class_names

    def calculate_covariances_10(self):
        x_transposed = np.transpose(self.x, (0, 2, 1))
        cov = covariances(x_transposed, estimator=self.estimator)
        return cov
    def calculate_covariances_36(self):
        cov = covariances(self.x, estimator=self.estimator)
        return cov

# %%
def calculate_class_weights(labels):
    class_sample_count = np.array([len(np.where(labels == t)[0]) for t in np.unique(labels)])
    weight = 1 - class_sample_count / len(labels)
    return th.from_numpy(weight).double()

def create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=True):
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(train_indices))
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(test_indices), shuffle=False)
    
    if val:
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=SubsetRandomSampler(val_indices))
        return train_loader, val_loader, test_loader
    else:
        return train_loader, test_loader

def plot_class_distribution(train_loader, val_loader, test_loader, n_classes, combo=False):
    class_names = train_loader.dataset.class_names
    
    def count_labels(loader, n_classes):
        counts = np.zeros(n_classes)
        for batch in loader:
            if combo:
                _, _, labels = batch  # x1, x2, labels
            else:
                _, labels = batch  # x, labels
            for l in labels:
                counts[l] += 1
        return counts

    train_counts = count_labels(train_loader, n_classes)
    
    if val_loader is not None:
        val_counts = count_labels(val_loader, n_classes)
    else:
        val_counts = np.zeros(n_classes)
    
    test_counts = count_labels(test_loader, n_classes)

    # Bar plot
    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes) - test_size, train_counts, 0.2, label='Train')
    if val_loader is not None:
        plt.bar(np.arange(n_classes), val_counts, 0.2, label='Validation')
    plt.bar(np.arange(n_classes) + 0.2, test_counts, 0.2, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

    plt.figure(figsize=(12, 6))
    plt.bar(np.arange(n_classes), train_counts, alpha=0.5, label='Train')
    plt.bar(np.arange(n_classes), val_counts, alpha=0.5, label='Validation')
    plt.bar(np.arange(n_classes), test_counts, alpha=0.5, label='Test')
    plt.xlabel('Classes')
    plt.ylabel('Count')
    plt.yscale('log')
    if val_loader is not None:
        plt.title('Histogram of Class Distribution in Train, Validation, and Test Sets')
    else:
        plt.title('Histogram of Class Distribution in Train and Test Sets')
    plt.xticks(np.arange(n_classes), class_names, rotation=45)
    plt.legend(loc='best')
    plt.show()

# %%
def train_model(model, train_loader, val_loader, loss_fn, optimizer, scheduler, epochs, combo=False):
    t1, t2, t3, t4, t5 = [], [], [], [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    for epoch in range(epochs):
        start_time = time.time()  # Start time of the epoch
        model.train()

        # Training phase
        loss_train, acc_train = [], []
        for batch in train_loader:
            if combo:
                x1, x2, y = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, y = batch
                x = x.to(device)
                inputs = (x,)
            y = y.to(device).long()
            optimizer.zero_grad()
            
            # Forward pass
            out = model(*inputs)
                
            l = loss_fn(out, y)
            
            acc, loss = (out.argmax(1) == y).cpu().numpy().sum() / out.shape[0], l.cpu().data.numpy()
            loss_train.append(loss)
            acc_train.append(acc)
            l.backward()
            optimizer.step()
        scheduler.step()

        acc_train = np.asarray(acc_train).mean()
        loss_train = np.asarray(loss_train).mean()
        t1.append(loss_train)
        t2.append(100 * acc_train)

        # Validation phase
        loss_val, acc_val_list = [], []
        y_true, y_pred = [], []
        model.eval()
        for batch in val_loader:
            if combo:
                x1, x2, y = batch
                x1 = x1.to(device)
                x2 = x2.to(device)
                inputs = (x1, x2)
            else:
                x, y = batch
                x = x.to(device)
                inputs = (x,)
            y = y.to(device).long()
            with th.no_grad():
                # Forward pass
                out = model(*inputs)
                    
                l = loss_fn(out, y)
                
            loss_val.append(l.cpu().data.numpy())
            predicted_labels = out.argmax(1)
            y_true.extend(list(y.cpu().numpy()))
            y_pred.extend(list(predicted_labels.cpu().numpy()))
            acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
            
            acc_val_list.append(acc)
        acc_val = np.asarray(acc_val_list).mean()
        loss_val = np.asarray(loss_val).mean()    
   
        t3.append(100 * acc_val)
        t4.append(loss_val)
        f1_test = f1_score(y_true, y_pred, average='macro')
        t5.append(100 * f1_test)
        print('Epoch {}/{} - Train loss: {:.4f} - Val loss: {:.4f} - Train acc: {:.2f}% - Val acc: {:.2f}% - Test F1-score: {:.2f}'.format(
            epoch + 1, epochs, loss_train, loss_val, 100 * acc_train, 100 * acc_val, 100 * f1_test))

        elapsed_time = time.time() - start_time
        print('Elapsed time: {:.2f} seconds'.format(elapsed_time))

    return t1, t2, t3, t4, t5

# %%
def plot_training_results(t1, t2, t3, t4, t5, figure_name):
    plt.figure(figsize=(12, 8))
    plt.title("Training and Validation Loss and Accuracy")

    # Plot training and validation loss
    p1, = plt.plot(t1, label='Train loss', color='blue')
    p2, = plt.plot(t4, label='Validation loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    ax2 = plt.twinx()

    # Plot training and validation accuracy
    p3, = ax2.plot(t2, label='Train accuracy', color='orange')
    p4, = ax2.plot(t3, label='Validation accuracy', color='green')
    ax2.set_ylabel('Accuracy (%)')

    # Plot test F1-score
    p5, = ax2.plot(t5, label='F1-score', linestyle='dashed', color='purple')

    # Combine legends
    lines = [p1, p2, p3, p4, p5]
    labels = [line.get_label() for line in lines]
    #plt.legend(lines, labels, loc='upper right')
    plt.legend(lines, labels, loc='center left', bbox_to_anchor=(1.1, 0.5))

    # Save the figure with the provided name
    plt.savefig(f'{figure_name}.png')
    print(f'Figure saved as {figure_name}.png')
    plt.show()

# %%
def evaluate_model(model, data_loader, loss_fn, model_name, figure_name, combo=False):
    loss_val, acc_val = [], []
    y_true, y_pred = [], []
    device = th.device("cuda" if th.cuda.is_available() else "cpu")

    model.eval()
    for batch in data_loader:
        if combo:
            x1, x2, y = batch
            x1 = x1.to(device)
            x2 = x2.to(device)
            inputs = (x1, x2)
        else:
            x, y = batch
            x = x.to(device)
            inputs = (x,)
        y = y.to(device).long()
        
        with th.no_grad():
            # Forward pass
            out = model(*inputs)
            l = loss_fn(out, y)
        
        predicted_labels = out.argmax(1)
        y_true.extend(list(y.cpu().numpy()))
        y_pred.extend(list(predicted_labels.cpu().numpy()))
        acc = (predicted_labels == y).cpu().numpy().sum() / out.shape[0]
        loss_val.append(l.cpu().data.numpy())
        acc_val.append(acc)

    acc_val = np.asarray(acc_val).mean()
    loss_val = np.asarray(loss_val).mean()

    print('Validation loss: {:.4f}'.format(loss_val))
    print('Validation accuracy: {:.2f}%'.format(100 * acc_val))

    # Save the model
    th.save(model.state_dict(), f'{model_name}.ckpt')
    print(f'Model saved as {model_name}.ckpt')

    # Print classification report
    print(classification_report(y_true, y_pred, digits=2, target_names=data_loader.dataset.class_names))
    cmatrix = confusion_matrix(y_true, y_pred)
    Ncmatrix = cmatrix.astype('float') / cmatrix.sum(axis=1)[:, np.newaxis]

    group_counts = ['{0:0.0f}'.format(value) for value in cmatrix.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in Ncmatrix.flatten()]
    labels = [f'{v1}\n{v2}' for v1, v2 in zip(group_counts, group_percentages)]
    labels = np.asarray(labels).reshape(n_classes, n_classes)

    # Plot and save the confusion matrix figure
    plt.figure(figsize=(10, 8))
    sns.heatmap(Ncmatrix, annot=labels, fmt='', cmap='Reds', xticklabels=data_loader.dataset.class_names, yticklabels=data_loader.dataset.class_names)
    plt.ylabel('True label')
    plt.xlabel('Predicted label\n Acc={:.2f}%'.format(100 * acc_val))
    
    plt.savefig(f'{figure_name}.png')
    plt.show()
    print(f'Figure saved as {figure_name}.png')

    return 100 * acc_val

# %%
# %matplotlib inline
# Initialize dataset
dataset = TS_COV(root_dir=root_dir, np_file=npz_file, estimator='scm', combo=combo, temp=temp)

# Split data into train, validation, and test sets
if val is not None:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                    test_size=test_size, stratify=dataset.y, random_state=random_seed)
    train_indices, val_indices = train_test_split(train_indices,
                                                   test_size=test_size, stratify=dataset.y[train_indices], random_state=random_seed)
else:
    train_indices, test_indices = train_test_split(list(range(len(dataset))),
                                                   test_size=test_size, stratify=dataset.y, random_state=random_seed)
    val_indices = None

# Calculate class weights
weights = calculate_class_weights(dataset.y)
weights = weights.to(device)

# Create data loaders
if val:
    train_loader, val_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
else:
    train_loader, test_loader = create_data_loaders(dataset, train_indices, val_indices, test_indices, batch_size, val=val)
    val_loader = None

# Plot class distribution
plot_class_distribution(train_loader, val_loader, test_loader, n_classes=n_classes, combo=combo)

# %%
# access one matri
if combo:
    for x1,x2, y in train_loader:
        print(x1.shape)
        print(x2.shape)
        print(y.shape)
        break
else:
    for x, y in train_loader:
        print(x.shape)
        print(y.shape)
        break
# Out:
# torch.Size([64, 1, 36, 36])
# torch.Size([64, 1, 10, 10])
# torch.Size([64])

# %%
model = initialize_model(combo, linear_classif, device)

# %%
#setup loss and optimizer

if loss = "focal":
    loss_fn = FocalLoss(gamma=gamma_loss,weights=weights)
else:
    #loss_fn = nn.CrossEntropyLoss(weights=weights)
#opti = MixOptimizer(model.parameters(),lr=lr)
opti = geoopt.optim.RiemannianAdam(model.parameters(), lr=lr)
if step_lr:
    scheduler = lr_scheduler.StepLR(opti, step_size, gamma_value)
else:
    scheduler = lr_scheduler.ExponentialLR(opti, gamma=gamma_value)

# %%
if val:
    t1, t2, t3, t4, t5 = train_model(model, train_loader, val_loader, loss_fn, opti, scheduler, epochs, combo=combo)
else:
    t1, t2, t3, t4, t5 = train_model(model, train_loader, test_loader, loss_fn, opti, scheduler, epochs, combo=combo)
# Out:
# Epoch 1/200 - Train loss: 0.4625 - Val loss: 0.3630 - Train acc: 88.20% - Val acc: 91.28% - Test F1-score: 65.21
# Elapsed time: 30.10 seconds
# Epoch 2/200 - Train loss: 0.3245 - Val loss: 0.3054 - Train acc: 91.71% - Val acc: 93.36% - Test F1-score: 73.12
# Elapsed time: 27.69 seconds
# Epoch 3/200 - Train loss: 0.3117 - Val loss: 0.3179 - Train acc: 92.67% - Val acc: 92.53% - Test F1-score: 71.85
# Elapsed time: 27.50 seconds
# Epoch 4/200 - Train loss: 0.3036 - Val loss: 0.3149 - Train acc: 93.12% - Val acc: 93.02% - Test F1-score: 72.05
# Elapsed time: 27.69 seconds
# Epoch 5/200 - Train loss: 0.2880 - Val loss: 0.3456 - Train acc: 93.54% - Val acc: 93.09% - Test F1-score: 72.80
# Elapsed time: 27.58 seconds
# Epoch 6/200 - Train loss: 0.2861 - Val loss: 0.2754 - Train acc: 93.63% - Val acc: 93.98% - Test F1-score: 76.28
# Elapsed time: 27.60 seconds
# Epoch 7/200 - Train loss: 0.2466 - Val loss: 0.2981 - Train acc: 94.17% - Val acc: 94.60% - Test F1-score: 75.97
# Elapsed time: 27.82 seconds
# Epoch 8/200 - Train loss: 0.2550 - Val loss: 0.2850 - Train acc: 94.17% - Val acc: 94.88% - Test F1-score: 77.66
# Elapsed time: 27.53 seconds
# Epoch 9/200 - Train loss: 0.2224 - Val loss: 0.3533 - Train acc: 94.71% - Val acc: 92.57% - Test F1-score: 75.42
# Elapsed time: 27.70 seconds
# Epoch 10/200 - Train loss: 0.2206 - Val loss: 0.2691 - Train acc: 94.52% - Val acc: 94.20% - Test F1-score: 76.08
# Elapsed time: 28.35 seconds
# Epoch 11/200 - Train loss: 0.2034 - Val loss: 0.2681 - Train acc: 94.74% - Val acc: 94.57% - Test F1-score: 76.52
# Elapsed time: 28.10 seconds
# Epoch 12/200 - Train loss: 0.1922 - Val loss: 0.3572 - Train acc: 94.85% - Val acc: 94.58% - Test F1-score: 73.89
# Elapsed time: 28.22 seconds
# Epoch 13/200 - Train loss: 0.1813 - Val loss: 0.2433 - Train acc: 95.04% - Val acc: 93.53% - Test F1-score: 76.01
# Elapsed time: 28.11 seconds
# Epoch 14/200 - Train loss: 0.1672 - Val loss: 0.2623 - Train acc: 95.13% - Val acc: 94.11% - Test F1-score: 76.35
# Elapsed time: 27.98 seconds
# Epoch 15/200 - Train loss: 0.1627 - Val loss: 0.2598 - Train acc: 95.07% - Val acc: 94.98% - Test F1-score: 76.92
# Elapsed time: 27.88 seconds
# Epoch 16/200 - Train loss: 0.1509 - Val loss: 0.2442 - Train acc: 95.28% - Val acc: 93.94% - Test F1-score: 75.96
# Elapsed time: 27.76 seconds
# Epoch 17/200 - Train loss: 0.1520 - Val loss: 0.2219 - Train acc: 95.15% - Val acc: 94.47% - Test F1-score: 78.50
# Elapsed time: 28.07 seconds
# Epoch 18/200 - Train loss: 0.1346 - Val loss: 0.2150 - Train acc: 95.43% - Val acc: 95.24% - Test F1-score: 78.33
# Elapsed time: 27.90 seconds
# Epoch 19/200 - Train loss: 0.1260 - Val loss: 0.2248 - Train acc: 95.52% - Val acc: 94.85% - Test F1-score: 76.29
# Elapsed time: 27.80 seconds
# Epoch 20/200 - Train loss: 0.1191 - Val loss: 0.2107 - Train acc: 95.46% - Val acc: 93.36% - Test F1-score: 76.17
# Elapsed time: 28.17 seconds
# Epoch 21/200 - Train loss: 0.1128 - Val loss: 0.2198 - Train acc: 95.52% - Val acc: 94.41% - Test F1-score: 76.90
# Elapsed time: 27.73 seconds
# Epoch 22/200 - Train loss: 0.1082 - Val loss: 0.2268 - Train acc: 95.69% - Val acc: 94.26% - Test F1-score: 75.99
# Elapsed time: 28.20 seconds
# Epoch 23/200 - Train loss: 0.1063 - Val loss: 0.2023 - Train acc: 95.61% - Val acc: 95.14% - Test F1-score: 76.56
# Elapsed time: 27.82 seconds
# Epoch 24/200 - Train loss: 0.1012 - Val loss: 0.2041 - Train acc: 95.70% - Val acc: 93.85% - Test F1-score: 77.53
# Elapsed time: 27.79 seconds
# Epoch 25/200 - Train loss: 0.0927 - Val loss: 0.2013 - Train acc: 95.78% - Val acc: 95.50% - Test F1-score: 77.66
# Elapsed time: 28.30 seconds
# Epoch 26/200 - Train loss: 0.0871 - Val loss: 0.1716 - Train acc: 95.95% - Val acc: 95.62% - Test F1-score: 79.02
# Elapsed time: 27.90 seconds
# Epoch 27/200 - Train loss: 0.0845 - Val loss: 0.1756 - Train acc: 95.95% - Val acc: 94.99% - Test F1-score: 78.07
# Elapsed time: 28.18 seconds
# Epoch 28/200 - Train loss: 0.0795 - Val loss: 0.1749 - Train acc: 95.93% - Val acc: 94.84% - Test F1-score: 77.35
# Elapsed time: 27.76 seconds
# Epoch 29/200 - Train loss: 0.0755 - Val loss: 0.1774 - Train acc: 96.00% - Val acc: 94.87% - Test F1-score: 77.58
# Elapsed time: 27.86 seconds
# Epoch 30/200 - Train loss: 0.0727 - Val loss: 0.1633 - Train acc: 96.07% - Val acc: 95.69% - Test F1-score: 79.48
# Elapsed time: 28.12 seconds
# Epoch 31/200 - Train loss: 0.0693 - Val loss: 0.1849 - Train acc: 96.12% - Val acc: 92.85% - Test F1-score: 76.21
# Elapsed time: 27.91 seconds
# Epoch 32/200 - Train loss: 0.0690 - Val loss: 0.1566 - Train acc: 96.17% - Val acc: 95.64% - Test F1-score: 79.01
# Elapsed time: 28.38 seconds
# Epoch 33/200 - Train loss: 0.0625 - Val loss: 0.1636 - Train acc: 96.21% - Val acc: 94.41% - Test F1-score: 77.11
# Elapsed time: 28.45 seconds
# Epoch 34/200 - Train loss: 0.0607 - Val loss: 0.1582 - Train acc: 96.22% - Val acc: 95.24% - Test F1-score: 78.58
# Elapsed time: 28.57 seconds
# Epoch 35/200 - Train loss: 0.0593 - Val loss: 0.1604 - Train acc: 96.30% - Val acc: 96.00% - Test F1-score: 79.41
# Elapsed time: 28.28 seconds
# Epoch 36/200 - Train loss: 0.0561 - Val loss: 0.1554 - Train acc: 96.39% - Val acc: 95.62% - Test F1-score: 79.12
# Elapsed time: 28.27 seconds
# Epoch 37/200 - Train loss: 0.0548 - Val loss: 0.1649 - Train acc: 96.42% - Val acc: 94.78% - Test F1-score: 78.28
# Elapsed time: 28.37 seconds
# Epoch 38/200 - Train loss: 0.0520 - Val loss: 0.1589 - Train acc: 96.44% - Val acc: 95.57% - Test F1-score: 78.71
# Elapsed time: 27.93 seconds
# Epoch 39/200 - Train loss: 0.0503 - Val loss: 0.1543 - Train acc: 96.50% - Val acc: 95.29% - Test F1-score: 78.30
# Elapsed time: 28.06 seconds
# Epoch 40/200 - Train loss: 0.0483 - Val loss: 0.1548 - Train acc: 96.62% - Val acc: 95.28% - Test F1-score: 78.44
# Elapsed time: 28.64 seconds
# Epoch 41/200 - Train loss: 0.0462 - Val loss: 0.1572 - Train acc: 96.63% - Val acc: 94.69% - Test F1-score: 78.22
# Elapsed time: 28.39 seconds
# Epoch 42/200 - Train loss: 0.0453 - Val loss: 0.1520 - Train acc: 96.60% - Val acc: 95.59% - Test F1-score: 78.99
# Elapsed time: 28.44 seconds
# Epoch 43/200 - Train loss: 0.0441 - Val loss: 0.1526 - Train acc: 96.69% - Val acc: 95.09% - Test F1-score: 78.61
# Elapsed time: 28.14 seconds
# Epoch 44/200 - Train loss: 0.0433 - Val loss: 0.1473 - Train acc: 96.69% - Val acc: 95.53% - Test F1-score: 78.85
# Elapsed time: 27.59 seconds
# Epoch 45/200 - Train loss: 0.0415 - Val loss: 0.1471 - Train acc: 96.77% - Val acc: 95.76% - Test F1-score: 79.11
# Elapsed time: 28.18 seconds
# Epoch 46/200 - Train loss: 0.0408 - Val loss: 0.1474 - Train acc: 96.78% - Val acc: 95.91% - Test F1-score: 79.18
# Elapsed time: 27.92 seconds
# Epoch 47/200 - Train loss: 0.0393 - Val loss: 0.1519 - Train acc: 96.90% - Val acc: 95.26% - Test F1-score: 78.12
# Elapsed time: 28.28 seconds
# Epoch 48/200 - Train loss: 0.0383 - Val loss: 0.1500 - Train acc: 96.93% - Val acc: 95.81% - Test F1-score: 79.49
# Elapsed time: 27.99 seconds
# Epoch 49/200 - Train loss: 0.0385 - Val loss: 0.1471 - Train acc: 96.87% - Val acc: 95.89% - Test F1-score: 79.11
# Elapsed time: 27.90 seconds
# Epoch 50/200 - Train loss: 0.0366 - Val loss: 0.1444 - Train acc: 96.92% - Val acc: 95.66% - Test F1-score: 78.90
# Elapsed time: 28.27 seconds
# Epoch 51/200 - Train loss: 0.0363 - Val loss: 0.1459 - Train acc: 97.01% - Val acc: 95.35% - Test F1-score: 78.15
# Elapsed time: 28.19 seconds
# Epoch 52/200 - Train loss: 0.0355 - Val loss: 0.1437 - Train acc: 97.05% - Val acc: 95.88% - Test F1-score: 79.91
# Elapsed time: 28.02 seconds
# Epoch 53/200 - Train loss: 0.0346 - Val loss: 0.1411 - Train acc: 97.09% - Val acc: 95.82% - Test F1-score: 79.59
# Elapsed time: 27.94 seconds
# Epoch 54/200 - Train loss: 0.0346 - Val loss: 0.1440 - Train acc: 97.12% - Val acc: 95.74% - Test F1-score: 78.97
# Elapsed time: 27.84 seconds
# Epoch 55/200 - Train loss: 0.0339 - Val loss: 0.1466 - Train acc: 97.14% - Val acc: 95.25% - Test F1-score: 78.75
# Elapsed time: 28.12 seconds
# Epoch 56/200 - Train loss: 0.0335 - Val loss: 0.1470 - Train acc: 97.13% - Val acc: 95.81% - Test F1-score: 78.65
# Elapsed time: 28.07 seconds
# Epoch 57/200 - Train loss: 0.0327 - Val loss: 0.1441 - Train acc: 97.23% - Val acc: 95.96% - Test F1-score: 79.62
# Elapsed time: 28.71 seconds
# Epoch 58/200 - Train loss: 0.0319 - Val loss: 0.1442 - Train acc: 97.19% - Val acc: 95.57% - Test F1-score: 78.90
# Elapsed time: 28.35 seconds
# Epoch 59/200 - Train loss: 0.0319 - Val loss: 0.1424 - Train acc: 97.20% - Val acc: 95.79% - Test F1-score: 79.77
# Elapsed time: 28.00 seconds
# Epoch 60/200 - Train loss: 0.0313 - Val loss: 0.1439 - Train acc: 97.29% - Val acc: 95.79% - Test F1-score: 79.77
# Elapsed time: 28.91 seconds
# Epoch 61/200 - Train loss: 0.0309 - Val loss: 0.1402 - Train acc: 97.27% - Val acc: 96.17% - Test F1-score: 80.56
# Elapsed time: 28.39 seconds
# Epoch 62/200 - Train loss: 0.0305 - Val loss: 0.1442 - Train acc: 97.36% - Val acc: 95.76% - Test F1-score: 79.12
# Elapsed time: 28.20 seconds
# Epoch 63/200 - Train loss: 0.0304 - Val loss: 0.1410 - Train acc: 97.29% - Val acc: 95.75% - Test F1-score: 79.41
# Elapsed time: 28.04 seconds
# Epoch 64/200 - Train loss: 0.0300 - Val loss: 0.1422 - Train acc: 97.33% - Val acc: 95.99% - Test F1-score: 79.52
# Elapsed time: 28.40 seconds
# Epoch 65/200 - Train loss: 0.0297 - Val loss: 0.1422 - Train acc: 97.36% - Val acc: 95.76% - Test F1-score: 79.32
# Elapsed time: 28.75 seconds
# Epoch 66/200 - Train loss: 0.0294 - Val loss: 0.1425 - Train acc: 97.37% - Val acc: 95.86% - Test F1-score: 79.81
# Elapsed time: 28.31 seconds
# Epoch 67/200 - Train loss: 0.0291 - Val loss: 0.1418 - Train acc: 97.44% - Val acc: 95.87% - Test F1-score: 79.64
# Elapsed time: 27.88 seconds
# Epoch 68/200 - Train loss: 0.0287 - Val loss: 0.1435 - Train acc: 97.39% - Val acc: 95.80% - Test F1-score: 78.80
# Elapsed time: 28.49 seconds
# Epoch 69/200 - Train loss: 0.0285 - Val loss: 0.1426 - Train acc: 97.43% - Val acc: 96.04% - Test F1-score: 79.50
# Elapsed time: 28.35 seconds
# Epoch 70/200 - Train loss: 0.0283 - Val loss: 0.1428 - Train acc: 97.44% - Val acc: 95.71% - Test F1-score: 79.30
# Elapsed time: 28.03 seconds
# Epoch 71/200 - Train loss: 0.0279 - Val loss: 0.1422 - Train acc: 97.47% - Val acc: 95.99% - Test F1-score: 79.91
# Elapsed time: 27.95 seconds
# Epoch 72/200 - Train loss: 0.0279 - Val loss: 0.1419 - Train acc: 97.52% - Val acc: 95.76% - Test F1-score: 79.06
# Elapsed time: 27.84 seconds
# Epoch 73/200 - Train loss: 0.0277 - Val loss: 0.1437 - Train acc: 97.49% - Val acc: 95.69% - Test F1-score: 79.29
# Elapsed time: 28.05 seconds
# Epoch 74/200 - Train loss: 0.0275 - Val loss: 0.1424 - Train acc: 97.51% - Val acc: 95.89% - Test F1-score: 79.09
# Elapsed time: 27.95 seconds
# Epoch 75/200 - Train loss: 0.0272 - Val loss: 0.1436 - Train acc: 97.54% - Val acc: 96.02% - Test F1-score: 79.53
# Elapsed time: 28.07 seconds
# Epoch 76/200 - Train loss: 0.0273 - Val loss: 0.1417 - Train acc: 97.51% - Val acc: 95.94% - Test F1-score: 79.31
# Elapsed time: 28.15 seconds
# Epoch 77/200 - Train loss: 0.0268 - Val loss: 0.1431 - Train acc: 97.51% - Val acc: 96.04% - Test F1-score: 79.51
# Elapsed time: 28.17 seconds
# Epoch 78/200 - Train loss: 0.0267 - Val loss: 0.1449 - Train acc: 97.53% - Val acc: 96.04% - Test F1-score: 79.76
# Elapsed time: 28.10 seconds
# Epoch 79/200 - Train loss: 0.0268 - Val loss: 0.1424 - Train acc: 97.57% - Val acc: 95.92% - Test F1-score: 79.43
# Elapsed time: 28.02 seconds
# Epoch 80/200 - Train loss: 0.0264 - Val loss: 0.1484 - Train acc: 97.60% - Val acc: 95.97% - Test F1-score: 79.48
# Elapsed time: 28.12 seconds
# Epoch 81/200 - Train loss: 0.0264 - Val loss: 0.1417 - Train acc: 97.60% - Val acc: 95.89% - Test F1-score: 79.59
# Elapsed time: 28.12 seconds
# Epoch 82/200 - Train loss: 0.0262 - Val loss: 0.1418 - Train acc: 97.63% - Val acc: 95.91% - Test F1-score: 79.41
# Elapsed time: 28.03 seconds
# Epoch 83/200 - Train loss: 0.0261 - Val loss: 0.1421 - Train acc: 97.58% - Val acc: 96.08% - Test F1-score: 79.71
# Elapsed time: 27.89 seconds
# Epoch 84/200 - Train loss: 0.0261 - Val loss: 0.1427 - Train acc: 97.62% - Val acc: 95.89% - Test F1-score: 79.15
# Elapsed time: 27.81 seconds
# Epoch 85/200 - Train loss: 0.0260 - Val loss: 0.1425 - Train acc: 97.59% - Val acc: 95.96% - Test F1-score: 79.43
# Elapsed time: 27.73 seconds
# Epoch 86/200 - Train loss: 0.0258 - Val loss: 0.1424 - Train acc: 97.67% - Val acc: 95.96% - Test F1-score: 79.69
# Elapsed time: 28.13 seconds
# Epoch 87/200 - Train loss: 0.0256 - Val loss: 0.1419 - Train acc: 97.63% - Val acc: 96.01% - Test F1-score: 79.43
# Elapsed time: 27.59 seconds
# Epoch 88/200 - Train loss: 0.0258 - Val loss: 0.1422 - Train acc: 97.66% - Val acc: 95.84% - Test F1-score: 79.28
# Elapsed time: 27.87 seconds
# Epoch 89/200 - Train loss: 0.0255 - Val loss: 0.1417 - Train acc: 97.62% - Val acc: 95.99% - Test F1-score: 79.46
# Elapsed time: 27.51 seconds
# Epoch 90/200 - Train loss: 0.0256 - Val loss: 0.1423 - Train acc: 97.65% - Val acc: 96.06% - Test F1-score: 79.65
# Elapsed time: 27.50 seconds
# Epoch 91/200 - Train loss: 0.0255 - Val loss: 0.1422 - Train acc: 97.63% - Val acc: 95.86% - Test F1-score: 79.36
# Elapsed time: 27.88 seconds
# Epoch 92/200 - Train loss: 0.0253 - Val loss: 0.1426 - Train acc: 97.65% - Val acc: 95.85% - Test F1-score: 79.14
# Elapsed time: 27.78 seconds
# Epoch 93/200 - Train loss: 0.0253 - Val loss: 0.1420 - Train acc: 97.67% - Val acc: 95.98% - Test F1-score: 79.25
# Elapsed time: 27.77 seconds
# Epoch 94/200 - Train loss: 0.0251 - Val loss: 0.1420 - Train acc: 97.69% - Val acc: 96.01% - Test F1-score: 79.73
# Elapsed time: 27.81 seconds
# Epoch 95/200 - Train loss: 0.0251 - Val loss: 0.1425 - Train acc: 97.69% - Val acc: 96.01% - Test F1-score: 79.43
# Elapsed time: 27.84 seconds
# Epoch 96/200 - Train loss: 0.0251 - Val loss: 0.1423 - Train acc: 97.67% - Val acc: 95.99% - Test F1-score: 79.32
# Elapsed time: 28.02 seconds
# Epoch 97/200 - Train loss: 0.0249 - Val loss: 0.1417 - Train acc: 97.70% - Val acc: 95.98% - Test F1-score: 79.39
# Elapsed time: 27.77 seconds
# Epoch 98/200 - Train loss: 0.0249 - Val loss: 0.1421 - Train acc: 97.68% - Val acc: 95.92% - Test F1-score: 79.33
# Elapsed time: 27.77 seconds
# Epoch 99/200 - Train loss: 0.0250 - Val loss: 0.1424 - Train acc: 97.67% - Val acc: 96.04% - Test F1-score: 79.58
# Elapsed time: 27.71 seconds
# Epoch 100/200 - Train loss: 0.0249 - Val loss: 0.1423 - Train acc: 97.70% - Val acc: 95.91% - Test F1-score: 79.20
# Elapsed time: 27.96 seconds
# Epoch 101/200 - Train loss: 0.0248 - Val loss: 0.1417 - Train acc: 97.72% - Val acc: 95.93% - Test F1-score: 79.32
# Elapsed time: 28.01 seconds
# Epoch 102/200 - Train loss: 0.0247 - Val loss: 0.1415 - Train acc: 97.70% - Val acc: 96.05% - Test F1-score: 79.50
# Elapsed time: 27.96 seconds
# Epoch 103/200 - Train loss: 0.0247 - Val loss: 0.1417 - Train acc: 97.73% - Val acc: 95.96% - Test F1-score: 79.36
# Elapsed time: 28.16 seconds
# Epoch 104/200 - Train loss: 0.0247 - Val loss: 0.1434 - Train acc: 97.70% - Val acc: 95.92% - Test F1-score: 79.40
# Elapsed time: 27.88 seconds
# Epoch 105/200 - Train loss: 0.0245 - Val loss: 0.1430 - Train acc: 97.73% - Val acc: 95.95% - Test F1-score: 79.33
# Elapsed time: 27.90 seconds
# Epoch 106/200 - Train loss: 0.0246 - Val loss: 0.1425 - Train acc: 97.70% - Val acc: 96.04% - Test F1-score: 79.53
# Elapsed time: 27.95 seconds
# Epoch 107/200 - Train loss: 0.0245 - Val loss: 0.1434 - Train acc: 97.70% - Val acc: 95.95% - Test F1-score: 79.40
# Elapsed time: 28.30 seconds
# Epoch 108/200 - Train loss: 0.0246 - Val loss: 0.1444 - Train acc: 97.71% - Val acc: 96.00% - Test F1-score: 79.60
# Elapsed time: 27.68 seconds
# Epoch 109/200 - Train loss: 0.0244 - Val loss: 0.1437 - Train acc: 97.73% - Val acc: 95.93% - Test F1-score: 79.51
# Elapsed time: 27.56 seconds
# Epoch 110/200 - Train loss: 0.0244 - Val loss: 0.1421 - Train acc: 97.73% - Val acc: 96.02% - Test F1-score: 79.55
# Elapsed time: 27.36 seconds
# Epoch 111/200 - Train loss: 0.0244 - Val loss: 0.1421 - Train acc: 97.77% - Val acc: 95.91% - Test F1-score: 79.37
# Elapsed time: 27.23 seconds
# Epoch 112/200 - Train loss: 0.0243 - Val loss: 0.1422 - Train acc: 97.73% - Val acc: 95.98% - Test F1-score: 79.54
# Elapsed time: 27.09 seconds
# Epoch 113/200 - Train loss: 0.0243 - Val loss: 0.1453 - Train acc: 97.72% - Val acc: 95.88% - Test F1-score: 79.46
# Elapsed time: 27.41 seconds
# Epoch 114/200 - Train loss: 0.0244 - Val loss: 0.1430 - Train acc: 97.73% - Val acc: 95.94% - Test F1-score: 79.47
# Elapsed time: 27.95 seconds
# Epoch 115/200 - Train loss: 0.0244 - Val loss: 0.1418 - Train acc: 97.73% - Val acc: 96.06% - Test F1-score: 79.74
# Elapsed time: 28.40 seconds
# Epoch 116/200 - Train loss: 0.0243 - Val loss: 0.1457 - Train acc: 97.71% - Val acc: 95.97% - Test F1-score: 79.79
# Elapsed time: 27.87 seconds
# Epoch 117/200 - Train loss: 0.0244 - Val loss: 0.1464 - Train acc: 97.73% - Val acc: 96.01% - Test F1-score: 79.77
# Elapsed time: 28.07 seconds
# Epoch 118/200 - Train loss: 0.0243 - Val loss: 0.1427 - Train acc: 97.73% - Val acc: 95.98% - Test F1-score: 79.37
# Elapsed time: 28.16 seconds
# Epoch 119/200 - Train loss: 0.0243 - Val loss: 0.1416 - Train acc: 97.77% - Val acc: 96.02% - Test F1-score: 79.73
# Elapsed time: 28.04 seconds
# Epoch 120/200 - Train loss: 0.0242 - Val loss: 0.1421 - Train acc: 97.75% - Val acc: 95.99% - Test F1-score: 79.53
# Elapsed time: 29.21 seconds
# Epoch 121/200 - Train loss: 0.0241 - Val loss: 0.1425 - Train acc: 97.74% - Val acc: 95.94% - Test F1-score: 79.36
# Elapsed time: 27.87 seconds
# Epoch 122/200 - Train loss: 0.0243 - Val loss: 0.1419 - Train acc: 97.75% - Val acc: 95.99% - Test F1-score: 79.56
# Elapsed time: 28.39 seconds
# Epoch 123/200 - Train loss: 0.0242 - Val loss: 0.1432 - Train acc: 97.73% - Val acc: 95.99% - Test F1-score: 79.70
# Elapsed time: 28.52 seconds
# Epoch 124/200 - Train loss: 0.0242 - Val loss: 0.1427 - Train acc: 97.77% - Val acc: 95.92% - Test F1-score: 79.45
# Elapsed time: 28.21 seconds
# Epoch 125/200 - Train loss: 0.0242 - Val loss: 0.1428 - Train acc: 97.74% - Val acc: 96.06% - Test F1-score: 79.71
# Elapsed time: 28.13 seconds
# Epoch 126/200 - Train loss: 0.0240 - Val loss: 0.1424 - Train acc: 97.79% - Val acc: 95.96% - Test F1-score: 79.40
# Elapsed time: 28.46 seconds
# Epoch 127/200 - Train loss: 0.0241 - Val loss: 0.1422 - Train acc: 97.76% - Val acc: 96.00% - Test F1-score: 79.58
# Elapsed time: 28.30 seconds
# Epoch 128/200 - Train loss: 0.0241 - Val loss: 0.1420 - Train acc: 97.75% - Val acc: 96.02% - Test F1-score: 79.66
# Elapsed time: 28.12 seconds
# Epoch 129/200 - Train loss: 0.0241 - Val loss: 0.1432 - Train acc: 97.76% - Val acc: 95.98% - Test F1-score: 79.77
# Elapsed time: 28.25 seconds
# Epoch 130/200 - Train loss: 0.0242 - Val loss: 0.1424 - Train acc: 97.76% - Val acc: 96.02% - Test F1-score: 79.65
# Elapsed time: 28.43 seconds
# Epoch 131/200 - Train loss: 0.0240 - Val loss: 0.1425 - Train acc: 97.76% - Val acc: 96.08% - Test F1-score: 79.80
# Elapsed time: 28.74 seconds
# Epoch 132/200 - Train loss: 0.0241 - Val loss: 0.1422 - Train acc: 97.73% - Val acc: 96.01% - Test F1-score: 79.63
# Elapsed time: 28.38 seconds
# Epoch 133/200 - Train loss: 0.0241 - Val loss: 0.1428 - Train acc: 97.76% - Val acc: 95.99% - Test F1-score: 79.50
# Elapsed time: 28.18 seconds
# Epoch 134/200 - Train loss: 0.0241 - Val loss: 0.1424 - Train acc: 97.73% - Val acc: 96.02% - Test F1-score: 79.68
# Elapsed time: 27.55 seconds
# Epoch 135/200 - Train loss: 0.0241 - Val loss: 0.1432 - Train acc: 97.74% - Val acc: 95.88% - Test F1-score: 79.62
# Elapsed time: 27.50 seconds
# Epoch 136/200 - Train loss: 0.0241 - Val loss: 0.1418 - Train acc: 97.76% - Val acc: 96.04% - Test F1-score: 79.73
# Elapsed time: 27.60 seconds
# Epoch 137/200 - Train loss: 0.0241 - Val loss: 0.1419 - Train acc: 97.75% - Val acc: 95.99% - Test F1-score: 79.47
# Elapsed time: 27.32 seconds
# Epoch 138/200 - Train loss: 0.0243 - Val loss: 0.1428 - Train acc: 97.78% - Val acc: 95.99% - Test F1-score: 79.54
# Elapsed time: 27.73 seconds
# Epoch 139/200 - Train loss: 0.0241 - Val loss: 0.1422 - Train acc: 97.72% - Val acc: 96.01% - Test F1-score: 79.62
# Elapsed time: 27.62 seconds
# Epoch 140/200 - Train loss: 0.0240 - Val loss: 0.1426 - Train acc: 97.75% - Val acc: 96.06% - Test F1-score: 79.80
# Elapsed time: 27.69 seconds
# Epoch 141/200 - Train loss: 0.0240 - Val loss: 0.1424 - Train acc: 97.79% - Val acc: 96.03% - Test F1-score: 79.72
# Elapsed time: 27.71 seconds
# Epoch 142/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.76% - Val acc: 95.99% - Test F1-score: 79.52
# Elapsed time: 27.50 seconds
# Epoch 143/200 - Train loss: 0.0241 - Val loss: 0.1422 - Train acc: 97.75% - Val acc: 96.08% - Test F1-score: 79.86
# Elapsed time: 27.75 seconds
# Epoch 144/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.77% - Val acc: 96.06% - Test F1-score: 79.81
# Elapsed time: 27.46 seconds
# Epoch 145/200 - Train loss: 0.0240 - Val loss: 0.1428 - Train acc: 97.76% - Val acc: 95.94% - Test F1-score: 79.40
# Elapsed time: 27.42 seconds
# Epoch 146/200 - Train loss: 0.0241 - Val loss: 0.1423 - Train acc: 97.76% - Val acc: 96.05% - Test F1-score: 79.75
# Elapsed time: 27.88 seconds
# Epoch 147/200 - Train loss: 0.0239 - Val loss: 0.1420 - Train acc: 97.79% - Val acc: 95.95% - Test F1-score: 79.66
# Elapsed time: 28.04 seconds
# Epoch 148/200 - Train loss: 0.0240 - Val loss: 0.1421 - Train acc: 97.76% - Val acc: 96.02% - Test F1-score: 79.68
# Elapsed time: 28.16 seconds
# Epoch 149/200 - Train loss: 0.0239 - Val loss: 0.1424 - Train acc: 97.76% - Val acc: 96.09% - Test F1-score: 79.86
# Elapsed time: 28.21 seconds
# Epoch 150/200 - Train loss: 0.0240 - Val loss: 0.1423 - Train acc: 97.76% - Val acc: 96.03% - Test F1-score: 79.73
# Elapsed time: 28.06 seconds
# Epoch 151/200 - Train loss: 0.0239 - Val loss: 0.1417 - Train acc: 97.75% - Val acc: 96.01% - Test F1-score: 79.58
# Elapsed time: 27.99 seconds
# Epoch 152/200 - Train loss: 0.0239 - Val loss: 0.1425 - Train acc: 97.75% - Val acc: 96.01% - Test F1-score: 79.54
# Elapsed time: 27.60 seconds
# Epoch 153/200 - Train loss: 0.0239 - Val loss: 0.1425 - Train acc: 97.73% - Val acc: 95.98% - Test F1-score: 79.38
# Elapsed time: 27.98 seconds
# Epoch 154/200 - Train loss: 0.0240 - Val loss: 0.1423 - Train acc: 97.79% - Val acc: 96.05% - Test F1-score: 79.74
# Elapsed time: 27.74 seconds
# Epoch 155/200 - Train loss: 0.0239 - Val loss: 0.1421 - Train acc: 97.76% - Val acc: 96.02% - Test F1-score: 79.61
# Elapsed time: 27.72 seconds
# Epoch 156/200 - Train loss: 0.0240 - Val loss: 0.1427 - Train acc: 97.75% - Val acc: 96.01% - Test F1-score: 79.65
# Elapsed time: 27.99 seconds
# Epoch 157/200 - Train loss: 0.0240 - Val loss: 0.1417 - Train acc: 97.78% - Val acc: 95.99% - Test F1-score: 79.46
# Elapsed time: 27.46 seconds
# Epoch 158/200 - Train loss: 0.0239 - Val loss: 0.1430 - Train acc: 97.74% - Val acc: 95.98% - Test F1-score: 79.51
# Elapsed time: 27.99 seconds
# Epoch 159/200 - Train loss: 0.0240 - Val loss: 0.1424 - Train acc: 97.72% - Val acc: 95.98% - Test F1-score: 79.54
# Elapsed time: 27.80 seconds
# Epoch 160/200 - Train loss: 0.0241 - Val loss: 0.1422 - Train acc: 97.75% - Val acc: 96.01% - Test F1-score: 79.66
# Elapsed time: 27.45 seconds
# Epoch 161/200 - Train loss: 0.0239 - Val loss: 0.1419 - Train acc: 97.77% - Val acc: 95.98% - Test F1-score: 79.53
# Elapsed time: 27.51 seconds
# Epoch 162/200 - Train loss: 0.0238 - Val loss: 0.1434 - Train acc: 97.75% - Val acc: 96.00% - Test F1-score: 79.49
# Elapsed time: 27.17 seconds
# Epoch 163/200 - Train loss: 0.0240 - Val loss: 0.1418 - Train acc: 97.74% - Val acc: 96.01% - Test F1-score: 79.68
# Elapsed time: 27.38 seconds
# Epoch 164/200 - Train loss: 0.0240 - Val loss: 0.1422 - Train acc: 97.77% - Val acc: 95.93% - Test F1-score: 79.49
# Elapsed time: 27.47 seconds
# Epoch 165/200 - Train loss: 0.0240 - Val loss: 0.1418 - Train acc: 97.77% - Val acc: 96.05% - Test F1-score: 79.76
# Elapsed time: 27.30 seconds
# Epoch 166/200 - Train loss: 0.0239 - Val loss: 0.1423 - Train acc: 97.77% - Val acc: 95.99% - Test F1-score: 79.49
# Elapsed time: 27.44 seconds
# Epoch 167/200 - Train loss: 0.0239 - Val loss: 0.1430 - Train acc: 97.75% - Val acc: 95.91% - Test F1-score: 79.43
# Elapsed time: 27.70 seconds
# Epoch 168/200 - Train loss: 0.0240 - Val loss: 0.1427 - Train acc: 97.75% - Val acc: 95.94% - Test F1-score: 79.62
# Elapsed time: 27.46 seconds
# Epoch 169/200 - Train loss: 0.0239 - Val loss: 0.1416 - Train acc: 97.77% - Val acc: 96.04% - Test F1-score: 79.75
# Elapsed time: 27.45 seconds
# Epoch 170/200 - Train loss: 0.0239 - Val loss: 0.1422 - Train acc: 97.75% - Val acc: 96.00% - Test F1-score: 79.53
# Elapsed time: 27.43 seconds
# Epoch 171/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.76% - Val acc: 96.01% - Test F1-score: 79.50
# Elapsed time: 27.63 seconds
# Epoch 172/200 - Train loss: 0.0240 - Val loss: 0.1420 - Train acc: 97.76% - Val acc: 96.00% - Test F1-score: 79.59
# Elapsed time: 27.51 seconds
# Epoch 173/200 - Train loss: 0.0243 - Val loss: 0.1411 - Train acc: 97.75% - Val acc: 96.05% - Test F1-score: 79.76
# Elapsed time: 28.19 seconds
# Epoch 174/200 - Train loss: 0.0240 - Val loss: 0.1429 - Train acc: 97.76% - Val acc: 96.06% - Test F1-score: 79.78
# Elapsed time: 27.44 seconds
# Epoch 175/200 - Train loss: 0.0240 - Val loss: 0.1417 - Train acc: 97.78% - Val acc: 96.02% - Test F1-score: 79.68
# Elapsed time: 27.84 seconds
# Epoch 176/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.75% - Val acc: 95.93% - Test F1-score: 79.54
# Elapsed time: 27.45 seconds
# Epoch 177/200 - Train loss: 0.0238 - Val loss: 0.1425 - Train acc: 97.77% - Val acc: 96.05% - Test F1-score: 79.75
# Elapsed time: 27.52 seconds
# Epoch 178/200 - Train loss: 0.0240 - Val loss: 0.1422 - Train acc: 97.78% - Val acc: 96.06% - Test F1-score: 79.82
# Elapsed time: 27.53 seconds
# Epoch 179/200 - Train loss: 0.0239 - Val loss: 0.1418 - Train acc: 97.79% - Val acc: 96.00% - Test F1-score: 79.53
# Elapsed time: 27.54 seconds
# Epoch 180/200 - Train loss: 0.0239 - Val loss: 0.1422 - Train acc: 97.78% - Val acc: 96.00% - Test F1-score: 79.54
# Elapsed time: 27.84 seconds
# Epoch 181/200 - Train loss: 0.0239 - Val loss: 0.1421 - Train acc: 97.79% - Val acc: 96.00% - Test F1-score: 79.63
# Elapsed time: 27.45 seconds
# Epoch 182/200 - Train loss: 0.0240 - Val loss: 0.1421 - Train acc: 97.79% - Val acc: 95.98% - Test F1-score: 79.39
# Elapsed time: 27.71 seconds
# Epoch 183/200 - Train loss: 0.0238 - Val loss: 0.1416 - Train acc: 97.75% - Val acc: 96.03% - Test F1-score: 79.70
# Elapsed time: 27.37 seconds
# Epoch 184/200 - Train loss: 0.0239 - Val loss: 0.1424 - Train acc: 97.75% - Val acc: 96.04% - Test F1-score: 79.74
# Elapsed time: 27.64 seconds
# Epoch 185/200 - Train loss: 0.0239 - Val loss: 0.1420 - Train acc: 97.76% - Val acc: 95.99% - Test F1-score: 79.58
# Elapsed time: 27.67 seconds
# Epoch 186/200 - Train loss: 0.0240 - Val loss: 0.1419 - Train acc: 97.79% - Val acc: 95.99% - Test F1-score: 79.48
# Elapsed time: 28.21 seconds
# Epoch 187/200 - Train loss: 0.0238 - Val loss: 0.1427 - Train acc: 97.78% - Val acc: 96.01% - Test F1-score: 79.53
# Elapsed time: 27.85 seconds
# Epoch 188/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.74% - Val acc: 95.99% - Test F1-score: 79.58
# Elapsed time: 28.10 seconds
# Epoch 189/200 - Train loss: 0.0238 - Val loss: 0.1431 - Train acc: 97.77% - Val acc: 95.95% - Test F1-score: 79.68
# Elapsed time: 28.05 seconds
# Epoch 190/200 - Train loss: 0.0239 - Val loss: 0.1423 - Train acc: 97.81% - Val acc: 96.04% - Test F1-score: 79.71
# Elapsed time: 28.37 seconds
# Epoch 191/200 - Train loss: 0.0239 - Val loss: 0.1414 - Train acc: 97.74% - Val acc: 96.02% - Test F1-score: 79.66
# Elapsed time: 27.69 seconds
# Epoch 192/200 - Train loss: 0.0240 - Val loss: 0.1449 - Train acc: 97.76% - Val acc: 95.95% - Test F1-score: 79.71
# Elapsed time: 27.31 seconds
# Epoch 193/200 - Train loss: 0.0239 - Val loss: 0.1420 - Train acc: 97.76% - Val acc: 96.04% - Test F1-score: 79.72
# Elapsed time: 27.63 seconds
# Epoch 194/200 - Train loss: 0.0238 - Val loss: 0.1426 - Train acc: 97.76% - Val acc: 96.05% - Test F1-score: 79.75
# Elapsed time: 27.10 seconds
# Epoch 195/200 - Train loss: 0.0239 - Val loss: 0.1426 - Train acc: 97.77% - Val acc: 96.02% - Test F1-score: 79.67
# Elapsed time: 27.49 seconds
# Epoch 196/200 - Train loss: 0.0239 - Val loss: 0.1415 - Train acc: 97.77% - Val acc: 95.99% - Test F1-score: 79.52
# Elapsed time: 27.72 seconds
# Epoch 197/200 - Train loss: 0.0238 - Val loss: 0.1423 - Train acc: 97.77% - Val acc: 95.90% - Test F1-score: 79.38
# Elapsed time: 27.22 seconds
# Epoch 198/200 - Train loss: 0.0239 - Val loss: 0.1425 - Train acc: 97.75% - Val acc: 95.97% - Test F1-score: 79.47
# Elapsed time: 27.71 seconds
# Epoch 199/200 - Train loss: 0.0239 - Val loss: 0.1419 - Train acc: 97.76% - Val acc: 96.06% - Test F1-score: 79.81
# Elapsed time: 26.94 seconds
# Epoch 200/200 - Train loss: 0.0238 - Val loss: 0.1424 - Train acc: 97.76% - Val acc: 96.05% - Test F1-score: 79.75
# Elapsed time: 27.64 seconds

# %%
plot_figure_name = "training_validation_results_combo_linear_mm_210"
plot_training_results(t1, t2, t3, t4, t5, plot_figure_name)
# Out:
# Figure saved as training_validation_results_combo_linear_mm_210.png

# %%
evaluate_model(model, test_loader, loss_fn, model_name, figure_name, combo=combo)
# Out:
# Validation loss: 0.1646
# Validation accuracy: 96.01%
# Model saved as model_combo_linear_mm_210.ckpt
#                   precision    recall  f1-score   support
#
#             corn       0.98      0.98      0.98      3818
#       horsebeans       0.63      0.71      0.67        92
#           meadow       0.99      0.99      0.99     10508
#    spring_barley       0.51      0.51      0.51        78
#      spring_peas       0.78      0.73      0.75        55
#       sunflowers       0.88      0.88      0.88       254
#    winter_barley       0.91      0.93      0.92       817
#       winter_oat       0.39      0.34      0.37        87
#  winter_rapeseed       0.98      0.94      0.96       762
# winter_triticale       0.75      0.69      0.72       537
#     winter_wheat       0.94      0.96      0.95      4198
#
#         accuracy                           0.96     21206
#        macro avg       0.79      0.79      0.79     21206
#     weighted avg       0.96      0.96      0.96     21206
# Figure saved as CM_combo_linear_mm_210.png
# 96.01417031763417

# %% [markdown]
# Compute some TSNE visualization of the embedding

# %%
def gen_features(net, dataloader, combo=False, temp=True):
    net.eval()
    targets_list = []
    outputs_list = []

    with th.no_grad():
        for idx, (x1, x2, targets) in enumerate(dataloader):
            x1 = x1.to(device)
            x2 = x2.to(device)
            targets = targets.to(device)
            targets_np = targets.data.cpu().numpy()

            # Conditional forward pass
            if combo:
                outputs = net(x1, x2)
            elif temp:
                outputs = net(x1)
            else:
                outputs = net(x2)

            outputs_np = outputs.data.cpu().numpy()
            
            targets_list.append(targets_np[:, np.newaxis])
            outputs_list.append(outputs_np)
            
            if ((idx + 1) % 10 == 0) or (idx + 1 == len(dataloader)):
                print(idx + 1, '/', len(dataloader))

    targets = np.concatenate(targets_list, axis=0)
    outputs = np.concatenate(outputs_list, axis=0).astype(np.float64)

    return targets, outputs

def tsne_plot(fig_name, targets, outputs):
    print('generating t-SNE plot...')
    # tsne_output = bh_sne(outputs)
    tsne = TSNE(random_state=42, perplexity=50)
    tsne_output = tsne.fit_transform(outputs)

    df = pd.DataFrame(tsne_output, columns=['x', 'y'])
    df['targets'] = targets

    plt.rcParams['figure.figsize'] = 10, 10
    sns.scatterplot(
        x='x', y='y',
        hue='targets',
        palette=sns.color_palette("Paired", 11),
        data=df,
        marker='o',
        legend="full",
        alpha=0.5
    )

    plt.xticks([])
    plt.yticks([])
    plt.xlabel('')
    plt.ylabel('')
    plt.legend(loc='best')
    plt.title('t-SNE plot of the embeddings: After training')

    plt.savefig(f'{fig_name}.png')
    plt.show()
    print(f'Figure saved as {fig_name}.png')
    print('done!')

# %%
targets, outputs = gen_features(model,test_loader, combo =combo)
tsne_plot(tsne_fig_name,targets, outputs)
# Out:
# 10 / 332
# 20 / 332
# 30 / 332
# 40 / 332
# 50 / 332
# 60 / 332
# 70 / 332
# 80 / 332
# 90 / 332
# 100 / 332
# 110 / 332
# 120 / 332
# 130 / 332
# 140 / 332
# 150 / 332
# 160 / 332
# 170 / 332
# 180 / 332
# 190 / 332
# 200 / 332
# 210 / 332
# 220 / 332
# 230 / 332
# 240 / 332
# 250 / 332
# 260 / 332
# 270 / 332
# 280 / 332
# 290 / 332
# 300 / 332
# 310 / 332
# 320 / 332
# 330 / 332
# 332 / 332
# generating t-SNE plot...
# Figure saved as Tsne_combo_linear_mm_210.png
# done!
